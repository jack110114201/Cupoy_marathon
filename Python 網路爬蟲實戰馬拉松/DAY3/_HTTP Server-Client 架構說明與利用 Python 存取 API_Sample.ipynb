# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"19078382100","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":320356134,"name":"byxiaobian/valine","url":"https://api.github.com/repos/byxiaobian/valine"},"payload":{"push_id":8487043799,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"76e67b96768cc19b4859471b444fc9ebebd0918c","before":"34a97bdf4eed7e8bfb7f462deb36513712595a95","commits":[{"sha":"76e67b96768cc19b4859471b444fc9ebebd0918c","author":{"email":"AutoWakeUp@email.com","name":"AutoWakeUp"},"message":"Successfully Wake","distinct":true,"url":"https://api.github.com/repos/byxiaobian/valine/commits/76e67b96768cc19b4859471b444fc9ebebd0918c"}]},"public":true,"created_at":"2021-11-28T08:07:46Z"},{"id":"19078382101","type":"CreateEvent","actor":{"id":94282586,"login":"np1918","display_login":"np1918","gravatar_id":"","url":"https://api.github.com/users/np1918","avatar_url":"https://avatars.githubusercontent.com/u/94282586?"},"repo":{"id":432654429,"name":"np1918/secure_connect","url":"https://api.github.com/repos/np1918/secure_connect"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":"A secure chat application using cryptographic algorithms","pusher_type":"user"},"public":true,"created_at":"2021-11-28T08:07:46Z"},{"id":"19078382095","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":398574857,"name":"YNSTT/CRC_2400","url":"https://api.github.com/repos/YNSTT/CRC_2400"},"payload":{"push_id":8487043774,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"60c7e299787d6c6bf266e4f310bdffff0babe15c","before":"30894f20749e367b809a3b64825bd80f3cade0ef","commits":[{"sha":"60c7e299787d6c6bf266e4f310bdffff0babe15c","author":{"email":"sdc@gmail.com","name":"YNSTT"},"message":"link is updated","distinct":true,"url":"https://api.github.com/repos/YNSTT/CRC_2400/commits/60c7e299787d6c6bf266e4f310bdffff0babe15c"}]},"public":true,"created_at":"2021-11-28T08:07:46Z"},{"id":"19078382073","type":"PushEvent","actor":{"id":10810283,"login":"direwolf-github","display_login":"direwolf-github","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","avatar_url":"https://avatars.githubusercontent.com/u/10810283?"},"repo":{"id":432654403,"name":"direwolf-github/ephemeral-ci-7a8184cc","url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-7a8184cc"},"payload":{"push_id":8487043785,"size":1,"distinct_size":1,"ref":"refs/heads/branch-3b93426a","head":"8518bbb56476eb37f7de57780c043c3771d61bdc","before":"7a296ffd8ba3a25434d025ff84b33dca3c1ac21e","commits":[{"sha":"8518bbb56476eb37f7de57780c043c3771d61bdc","author":{"email":"heroku-lifecycle+direwolf-github@salesforce.com","name":"direwolf-github"},"message":"add readme.txt","distinct":true,"url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-7a8184cc/commits/8518bbb56476eb37f7de57780c043c3771d61bdc"}]},"public":true,"created_at":"2021-11-28T08:07:46Z"},{"id":"19078382071","type":"PushEvent","actor":{"id":43733305,"login":"yanonono","display_login":"yanonono","gravatar_id":"","url":"https://api.github.com/users/yanonono","avatar_url":"https://avatars.githubusercontent.com/u/43733305?"},"repo":{"id":183440182,"name":"yanonono/booth-update","url":"https://api.github.com/repos/yanonono/booth-update"},"payload":{"push_id":8487043783,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"64f80e6c485bc6db5c84114fd5046daf4f9fecf2","before":"3aecdebba23d7976a50f7ddd3da71b404f31c61b","commits":[{"sha":"64f80e6c485bc6db5c84114fd5046daf4f9fecf2","author":{"email":"yano.nono.0701+booth-github@gmail.com","name":"yano.nono"},"message":"updated at: 2021-11-28 17 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '19078382100',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 320356134,
#    'name': 'byxiaobian/valine',
#    'url': 'https://api.github.com/repos/byxiaobian/valine'},
#   'payload': {'push_id': 8487043799,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '76e67b96768cc19b4859471b444fc9ebebd0918c',
#    'before': '34a97bdf4eed7e8bfb7f462deb36513712595a95',
#    'commits': [{'sha': '76e67b96768cc19b4859471b444fc9ebebd0918c',
#      'author': {'email': 'AutoWakeUp@email.com', 'name': 'AutoWakeUp'},
#      'message': 'Successfully Wake',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/byxiaobian/valine/commits/76e67b96768cc19b4859471b444fc9ebebd0918c'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382101',
#   'type': 'CreateEvent',
#   'actor': {'id': 94282586,
#    'login': 'np1918',
#    'display_login': 'np1918',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/np1918',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94282586?'},
#   'repo': {'id': 432654429,
#    'name': 'np1918/secure_connect',
#    'url': 'https://api.github.com/repos/np1918/secure_connect'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'A secure chat application using cryptographic algorithms',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382095',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 398574857,
#    'name': 'YNSTT/CRC_2400',
#    'url': 'https://api.github.com/repos/YNSTT/CRC_2400'},
#   'payload': {'push_id': 8487043774,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '60c7e299787d6c6bf266e4f310bdffff0babe15c',
#    'before': '30894f20749e367b809a3b64825bd80f3cade0ef',
#    'commits': [{'sha': '60c7e299787d6c6bf266e4f310bdffff0babe15c',
#      'author': {'email': 'sdc@gmail.com', 'name': 'YNSTT'},
#      'message': 'link is updated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/YNSTT/CRC_2400/commits/60c7e299787d6c6bf266e4f310bdffff0babe15c'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382073',
#   'type': 'PushEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 432654403,
#    'name': 'direwolf-github/ephemeral-ci-7a8184cc',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-7a8184cc'},
#   'payload': {'push_id': 8487043785,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/branch-3b93426a',
#    'head': '8518bbb56476eb37f7de57780c043c3771d61bdc',
#    'before': '7a296ffd8ba3a25434d025ff84b33dca3c1ac21e',
#    'commits': [{'sha': '8518bbb56476eb37f7de57780c043c3771d61bdc',
#      'author': {'email': 'heroku-lifecycle+direwolf-github@salesforce.com',
#       'name': 'direwolf-github'},
#      'message': 'add readme.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-7a8184cc/commits/8518bbb56476eb37f7de57780c043c3771d61bdc'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382071',
#   'type': 'PushEvent',
#   'actor': {'id': 43733305,
#    'login': 'yanonono',
#    'display_login': 'yanonono',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yanonono',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43733305?'},
#   'repo': {'id': 183440182,
#    'name': 'yanonono/booth-update',
#    'url': 'https://api.github.com/repos/yanonono/booth-update'},
#   'payload': {'push_id': 8487043783,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '64f80e6c485bc6db5c84114fd5046daf4f9fecf2',
#    'before': '3aecdebba23d7976a50f7ddd3da71b404f31c61b',
#    'commits': [{'sha': '64f80e6c485bc6db5c84114fd5046daf4f9fecf2',
#      'author': {'email': 'yano.nono.0701+booth-github@gmail.com',
#       'name': 'yano.nono'},
#      'message': 'updated at: 2021-11-28 17:07, 【VRC布教用】トコシエコウ△236 - trash box - BOOTH',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yanonono/booth-update/commits/64f80e6c485bc6db5c84114fd5046daf4f9fecf2'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382077',
#   'type': 'PushEvent',
#   'actor': {'id': 55101399,
#    'login': 'amjad143',
#    'display_login': 'amjad143',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amjad143',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55101399?'},
#   'repo': {'id': 432654193,
#    'name': 'amjad143/Meachine-Learning-2',
#    'url': 'https://api.github.com/repos/amjad143/Meachine-Learning-2'},
#   'payload': {'push_id': 8487043786,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6f0458ec20814dc28f7f3e5eddd66b4a9ceda987',
#    'before': 'e7e67ac68787a248dcc273a55de2fcf71fbd1047',
#    'commits': [{'sha': '6f0458ec20814dc28f7f3e5eddd66b4a9ceda987',
#      'author': {'email': '55101399+amjad143@users.noreply.github.com',
#       'name': 'Amjad Khan'},
#      'message': 'Create read.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/amjad143/Meachine-Learning-2/commits/6f0458ec20814dc28f7f3e5eddd66b4a9ceda987'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382078',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 432654406,
#    'name': 'direwolf-github/ephemeral-ci-84a7a7d5',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-84a7a7d5'},
#   'payload': {'ref': 'branch-ddb034a1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382068',
#   'type': 'PushEvent',
#   'actor': {'id': 80439591,
#    'login': 'jiahaoboy',
#    'display_login': 'jiahaoboy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jiahaoboy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80439591?'},
#   'repo': {'id': 413425446,
#    'name': 'jiahaoboy/jiahaoboy.github.io',
#    'url': 'https://api.github.com/repos/jiahaoboy/jiahaoboy.github.io'},
#   'payload': {'push_id': 8487043787,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9d31203a98ba8f6fa9b10bc14cac738eb47dc801',
#    'before': '2eef92b961e4f6fc69583e967758bcbb73d75f28',
#    'commits': [{'sha': '9d31203a98ba8f6fa9b10bc14cac738eb47dc801',
#      'author': {'email': '3379515285@qq.com', 'name': '3379515285'},
#      'message': 'Site updated: 2021-11-28 16:07:33',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jiahaoboy/jiahaoboy.github.io/commits/9d31203a98ba8f6fa9b10bc14cac738eb47dc801'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382069',
#   'type': 'PushEvent',
#   'actor': {'id': 69691878,
#    'login': 'StateDocuments',
#    'display_login': 'StateDocuments',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/StateDocuments',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69691878?'},
#   'repo': {'id': 398435439,
#    'name': 'StateDocuments/mississippi-public',
#    'url': 'https://api.github.com/repos/StateDocuments/mississippi-public'},
#   'payload': {'push_id': 8487043781,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3d4acf823ba7717e1b4cb11d5e52dc1f34526927',
#    'before': '90f6abb503e143af6c89dd64fa7589f530422360',
#    'commits': [{'sha': '3d4acf823ba7717e1b4cb11d5e52dc1f34526927',
#      'author': {'email': 'elvisshoesseven@hotmail.com', 'name': 'Your Name'},
#      'message': 'JAIEngines',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/StateDocuments/mississippi-public/commits/3d4acf823ba7717e1b4cb11d5e52dc1f34526927'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382074',
#   'type': 'PushEvent',
#   'actor': {'id': 92907907,
#    'login': 'znyt',
#    'display_login': 'znyt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/znyt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92907907?'},
#   'repo': {'id': 431508869,
#    'name': 'znyt/oss26',
#    'url': 'https://api.github.com/repos/znyt/oss26'},
#   'payload': {'push_id': 8487043777,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '20b72e6008ae7fdf39a13266a803bd97f5ed172b',
#    'before': 'fe28d79319a9dd66ebde52f2847ed414bb1cd569',
#    'commits': [{'sha': '20b72e6008ae7fdf39a13266a803bd97f5ed172b',
#      'author': {'email': '92907907+znyt@users.noreply.github.com',
#       'name': 'znyt'},
#      'message': 'file upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/znyt/oss26/commits/20b72e6008ae7fdf39a13266a803bd97f5ed172b'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382070',
#   'type': 'PushEvent',
#   'actor': {'id': 50808373,
#    'login': 'natfan9',
#    'display_login': 'natfan9',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natfan9',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50808373?'},
#   'repo': {'id': 219237604,
#    'name': 'natfan9/Ovechkin-Tracker',
#    'url': 'https://api.github.com/repos/natfan9/Ovechkin-Tracker'},
#   'payload': {'push_id': 8487043768,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ea6bb69f6dd342d91708d59eed5d81e12aa73bf8',
#    'before': '43eec728cb7ee1f7875ceac453e1ff55442fd83c',
#    'commits': [{'sha': 'ea6bb69f6dd342d91708d59eed5d81e12aa73bf8',
#      'author': {'email': '50808373+natfan9@users.noreply.github.com',
#       'name': 'natfan9'},
#      'message': 'New Season Update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/natfan9/Ovechkin-Tracker/commits/ea6bb69f6dd342d91708d59eed5d81e12aa73bf8'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382063',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 20871255,
#    'login': 'bomilkar',
#    'display_login': 'bomilkar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bomilkar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20871255?'},
#   'repo': {'id': 341270,
#    'name': 'XCSoar/XCSoar',
#    'url': 'https://api.github.com/repos/XCSoar/XCSoar'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/784',
#     'repository_url': 'https://api.github.com/repos/XCSoar/XCSoar',
#     'labels_url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/784/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/784/comments',
#     'events_url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/784/events',
#     'html_url': 'https://github.com/XCSoar/XCSoar/pull/784',
#     'id': 1059148375,
#     'node_id': 'PR_kwDOAAU1Fs4uzXBL',
#     'number': 784,
#     'title': 'augment 3 InfoBoxes to provide information about thermaling efficiency',
#     'user': {'login': 'bomilkar',
#      'id': 20871255,
#      'node_id': 'MDQ6VXNlcjIwODcxMjU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/20871255?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bomilkar',
#      'html_url': 'https://github.com/bomilkar',
#      'followers_url': 'https://api.github.com/users/bomilkar/followers',
#      'following_url': 'https://api.github.com/users/bomilkar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bomilkar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bomilkar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bomilkar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bomilkar/orgs',
#      'repos_url': 'https://api.github.com/users/bomilkar/repos',
#      'events_url': 'https://api.github.com/users/bomilkar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bomilkar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/XCSoar/XCSoar/milestones/11',
#      'html_url': 'https://github.com/XCSoar/XCSoar/milestone/11',
#      'labels_url': 'https://api.github.com/repos/XCSoar/XCSoar/milestones/11/labels',
#      'id': 7421098,
#      'node_id': 'MI_kwDOAAU1Fs4AcTyq',
#      'number': 11,
#      'title': 'v7.21',
#      'description': None,
#      'creator': {'login': 'lordfolken',
#       'id': 407371,
#       'node_id': 'MDQ6VXNlcjQwNzM3MQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/407371?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/lordfolken',
#       'html_url': 'https://github.com/lordfolken',
#       'followers_url': 'https://api.github.com/users/lordfolken/followers',
#       'following_url': 'https://api.github.com/users/lordfolken/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/lordfolken/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/lordfolken/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/lordfolken/subscriptions',
#       'organizations_url': 'https://api.github.com/users/lordfolken/orgs',
#       'repos_url': 'https://api.github.com/users/lordfolken/repos',
#       'events_url': 'https://api.github.com/users/lordfolken/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/lordfolken/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 1,
#      'closed_issues': 3,
#      'state': 'open',
#      'created_at': '2021-11-23T06:44:00Z',
#      'updated_at': '2021-11-28T08:07:46Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 4,
#     'created_at': '2021-11-20T13:45:45Z',
#     'updated_at': '2021-11-28T08:07:46Z',
#     'closed_at': '2021-11-28T08:07:46Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/XCSoar/XCSoar/pulls/784',
#      'html_url': 'https://github.com/XCSoar/XCSoar/pull/784',
#      'diff_url': 'https://github.com/XCSoar/XCSoar/pull/784.diff',
#      'patch_url': 'https://github.com/XCSoar/XCSoar/pull/784.patch',
#      'merged_at': None},
#     'body': '<!--\r\n\r\nThank you for your interest in contributing to XCSoar! Please read the\r\nfollowing information to make it easier for us to review your changes.\r\n\r\nWe appreciate if you make sure to:\r\n\r\n  - Document the changes (in the NEWS.txt file, and the manual when relevant)\r\n  - Enable maintainer edits[1] (in case we need to help with the PR)\r\n  - Check your commits and their messages (so they\'re all tidy and coherent)\r\n\r\n[1] https://help.github.com/en/github/collaborating-with-issues-and-pull-requests/allowing-changes-to-a-pull-request-branch-created-from-a-fork\r\n\r\n-->\r\n\r\n\r\nBrief summary of the changes\r\n----------------------------\r\n\r\n<!--\r\nPlease note that the commit messages is where detailed descriptions of the\r\nchanges should be made - this section is just for a brief summary/overview.\r\n-->\r\nusing 3 InfoBoxes\' comment lines to better judge the quality of thermals. \r\n\r\nRelated issues and discussions\r\n------------------------------\r\n\r\n<!--\r\nPlease link any relevant issues or forum posts here, for reference.\r\n\r\nIf this PR resolves an existing issue, please write "Closes #1234" so that\r\nthe issue is closed automatically when this PR is merged.\r\n-->\r\nThis PR implements enhancements described in Issue #783 \r\n',
#     'reactions': {'url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/784/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/784/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/comments/980963504',
#     'html_url': 'https://github.com/XCSoar/XCSoar/pull/784#issuecomment-980963504',
#     'issue_url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/784',
#     'id': 980963504,
#     'node_id': 'IC_kwDOAAU1Fs46eFCw',
#     'user': {'login': 'bomilkar',
#      'id': 20871255,
#      'node_id': 'MDQ6VXNlcjIwODcxMjU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/20871255?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bomilkar',
#      'html_url': 'https://github.com/bomilkar',
#      'followers_url': 'https://api.github.com/users/bomilkar/followers',
#      'following_url': 'https://api.github.com/users/bomilkar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bomilkar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bomilkar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bomilkar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bomilkar/orgs',
#      'repos_url': 'https://api.github.com/users/bomilkar/repos',
#      'events_url': 'https://api.github.com/users/bomilkar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bomilkar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-11-28T08:07:46Z',
#     'updated_at': '2021-11-28T08:07:46Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "Average must specify a time frame. Otherwise the value is meaningless.\r\n\r\nLet's stop wasting our time.\r\n",
#     'reactions': {'url': 'https://api.github.com/repos/XCSoar/XCSoar/issues/comments/980963504/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z',
#   'org': {'id': 861328,
#    'login': 'XCSoar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/XCSoar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/861328?'}},
#  {'id': '19078382062',
#   'type': 'PushEvent',
#   'actor': {'id': 22171538,
#    'login': 'reubenpinkhasov',
#    'display_login': 'reubenpinkhasov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/reubenpinkhasov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22171538?'},
#   'repo': {'id': 431003557,
#    'name': 'ASTperfTest/repo38',
#    'url': 'https://api.github.com/repos/ASTperfTest/repo38'},
#   'payload': {'push_id': 8487043769,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/test-branch',
#    'head': 'eab5c56ab704a131184a9d5624f04a9b59e1f4e4',
#    'before': 'd86d2315f84bdcb3f8350c20f13068009edf9446',
#    'commits': [{'sha': 'eab5c56ab704a131184a9d5624f04a9b59e1f4e4',
#      'author': {'email': 'reuben.pinkhasov@checkmarx.com',
#       'name': 'reubenpinkhasov'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ASTperfTest/repo38/commits/eab5c56ab704a131184a9d5624f04a9b59e1f4e4'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z',
#   'org': {'id': 94827018,
#    'login': 'ASTperfTest',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ASTperfTest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94827018?'}},
#  {'id': '19078382048',
#   'type': 'WatchEvent',
#   'actor': {'id': 16024539,
#    'login': 'EtherTyper',
#    'display_login': 'EtherTyper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EtherTyper',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16024539?'},
#   'repo': {'id': 82930482,
#    'name': 'niv/neverwinter.nim',
#    'url': 'https://api.github.com/repos/niv/neverwinter.nim'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382060',
#   'type': 'PushEvent',
#   'actor': {'id': 16367391,
#    'login': 'hskiba',
#    'display_login': 'hskiba',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hskiba',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16367391?'},
#   'repo': {'id': 432583453,
#    'name': 'frgrisk/ec2ctl',
#    'url': 'https://api.github.com/repos/frgrisk/ec2ctl'},
#   'payload': {'push_id': 8487043776,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f95dc55e57d190b3f4a501b204df4434fcc2c24b',
#    'before': '441864c2096a44f572332b2053855f4ac1eafb8b',
#    'commits': [{'sha': 'f95dc55e57d190b3f4a501b204df4434fcc2c24b',
#      'author': {'email': 'henry.skiba@frgrisk.com', 'name': 'hskiba'},
#      'message': 'Add install note',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/frgrisk/ec2ctl/commits/f95dc55e57d190b3f4a501b204df4434fcc2c24b'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z',
#   'org': {'id': 94727575,
#    'login': 'frgrisk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/frgrisk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94727575?'}},
#  {'id': '19078382058',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 432654404,
#    'name': 'direwolf-github/ephemeral-ci-60175345',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-60175345'},
#   'payload': {'ref': 'branch-db5132a1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382038',
#   'type': 'PushEvent',
#   'actor': {'id': 95156135,
#    'login': 'johnmaunder1991',
#    'display_login': 'johnmaunder1991',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/johnmaunder1991',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95156135?'},
#   'repo': {'id': 432612765,
#    'name': 'johnmaunder1991/orthohx',
#    'url': 'https://api.github.com/repos/johnmaunder1991/orthohx'},
#   'payload': {'push_id': 8487043763,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4046ee7699f9b5b72164fd827933b8d284863deb',
#    'before': 'c82cae1bfd6d383f143d92ce3a0e71098ff1825b',
#    'commits': [{'sha': '4046ee7699f9b5b72164fd827933b8d284863deb',
#      'author': {'email': '95156135+johnmaunder1991@users.noreply.github.com',
#       'name': 'johnmaunder1991'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/johnmaunder1991/orthohx/commits/4046ee7699f9b5b72164fd827933b8d284863deb'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382037',
#   'type': 'PushEvent',
#   'actor': {'id': 92907907,
#    'login': 'znyt',
#    'display_login': 'znyt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/znyt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92907907?'},
#   'repo': {'id': 432449045,
#    'name': 'znyt/oss92',
#    'url': 'https://api.github.com/repos/znyt/oss92'},
#   'payload': {'push_id': 8487043755,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0a7345331721f8f3b4ef57567493142e0bcc62cc',
#    'before': '6174744f3c50f01cabdb567512ed50c5818248d7',
#    'commits': [{'sha': '0a7345331721f8f3b4ef57567493142e0bcc62cc',
#      'author': {'email': '92907907+znyt@users.noreply.github.com',
#       'name': 'znyt'},
#      'message': 'file upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/znyt/oss92/commits/0a7345331721f8f3b4ef57567493142e0bcc62cc'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382036',
#   'type': 'PushEvent',
#   'actor': {'id': 44322449,
#    'login': 'GoodManWEN',
#    'display_login': 'GoodManWEN',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GoodManWEN',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44322449?'},
#   'repo': {'id': 329163496,
#    'name': 'GoodManWEN/pipeit',
#    'url': 'https://api.github.com/repos/GoodManWEN/pipeit'},
#   'payload': {'push_id': 8487043766,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2eebcabff32a034643eb07bc89b6d6149032e368',
#    'before': '184d66f99900c7eefb056f24a1abb80d07c62079',
#    'commits': [{'sha': '2eebcabff32a034643eb07bc89b6d6149032e368',
#      'author': {'email': '44322449+GoodManWEN@users.noreply.github.com',
#       'name': 'GoodManWEN'},
#      'message': 'Update setup.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GoodManWEN/pipeit/commits/2eebcabff32a034643eb07bc89b6d6149032e368'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382029',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 432654403,
#    'name': 'direwolf-github/ephemeral-ci-7a8184cc',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-7a8184cc'},
#   'payload': {'ref': 'branch-3b93426a',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382035',
#   'type': 'CreateEvent',
#   'actor': {'id': 94730636,
#    'login': 'AjayLad01',
#    'display_login': 'AjayLad01',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AjayLad01',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94730636?'},
#   'repo': {'id': 432654427,
#    'name': 'AjayLad01/Algorithm',
#    'url': 'https://api.github.com/repos/AjayLad01/Algorithm'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382040',
#   'type': 'WatchEvent',
#   'actor': {'id': 76621454,
#    'login': 'Moe-hacker',
#    'display_login': 'Moe-hacker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Moe-hacker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76621454?'},
#   'repo': {'id': 204251906,
#    'name': 'unlock-music/unlock-music',
#    'url': 'https://api.github.com/repos/unlock-music/unlock-music'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z',
#   'org': {'id': 62338146,
#    'login': 'unlock-music',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/unlock-music',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62338146?'}},
#  {'id': '19078382034',
#   'type': 'WatchEvent',
#   'actor': {'id': 64574248,
#    'login': 'freysu',
#    'display_login': 'freysu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freysu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64574248?'},
#   'repo': {'id': 274912708,
#    'name': 'ZainCheung/netease-cloud-api',
#    'url': 'https://api.github.com/repos/ZainCheung/netease-cloud-api'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382026',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'push_id': 8487043747,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/revert-8487-MatteoPiovanelli-Laser-patch-6',
#    'head': 'f392e246942d86ba800b0b0b6d37a1720c628235',
#    'before': 'f392e246942d86ba800b0b0b6d37a1720c628235',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '19078382023',
#   'type': 'PushEvent',
#   'actor': {'id': 56911732,
#    'login': 'shutogeorgio',
#    'display_login': 'shutogeorgio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shutogeorgio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56911732?'},
#   'repo': {'id': 289481507,
#    'name': 'shutogeorgio/bitcoin',
#    'url': 'https://api.github.com/repos/shutogeorgio/bitcoin'},
#   'payload': {'push_id': 8487043741,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/master',
#    'head': '4f8b1f8759301d2553183e14f72444a0f1d80725',
#    'before': '200d97faf2ed0bd0cbef93dd4bbbe77cf8fe5d13',
#    'commits': [{'sha': 'fa5a886fa3a1d5bef80248a421b1e11aa991d477',
#      'author': {'email': 'falke.marco@gmail.com', 'name': 'MarcoFalke'},
#      'message': 'doc: Tidy up nMinDiskSpace comment\n\nnMinDiskSpace was removed in commit\n04cca330944f859b4ed68cb8da8a79f5206fd630\n\nAlso, remove incorrect doxygen comment.\nSee https://doxygen.bitcoincore.org/class_c_chain.html#aeb563751f7362d4308c7c2cb35b834a5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shutogeorgio/bitcoin/commits/fa5a886fa3a1d5bef80248a421b1e11aa991d477'},
#     {'sha': '166f8ec28e48aa4c0cd94544909c488df553d8ef',
#      'author': {'email': 'sebastian.falbesoner@gmail.com',
#       'name': 'Sebastian Falbesoner'},
#      'message': 'test: always rescan after importing private keys in `init_wallet` helper\n\nThis fixes the functional test feature_rbf.py for descriptor wallets.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shutogeorgio/bitcoin/commits/166f8ec28e48aa4c0cd94544909c488df553d8ef'},
#     {'sha': 'b79dbe86a9886b3539512f6c35205f4c5454a952',
#      'author': {'email': 'sebastian.falbesoner@gmail.com',
#       'name': 'Sebastian Falbesoner'},
#      'message': 'test: add feature_rbf.py --descriptors to test_runner.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shutogeorgio/bitcoin/commits/b79dbe86a9886b3539512f6c35205f4c5454a952'},
#     {'sha': '4aa06f944768bd81022ef29096a1021433cfa482',
#      'author': {'email': 'fanquake@gmail.com', 'name': 'fanquake'},
#      'message': 'Merge bitcoin/bitcoin#23600: doc: Tidy up nMinDiskSpace comment\n\nfa5a886fa3a1d5bef80248a421b1e11aa991d477 doc: Tidy up nMinDiskSpace comment (MarcoFalke)\n\nPull request description:\n\n  nMinDiskSpace was removed in commit 04cca33\n\n  Also, remove incorrect doxygen comment. See https://doxygen.bitcoincore.org/class_c_chain.html#aeb563751f7362d4308c7c2cb35b834a5\n\nACKs for top commit:\n  theStack:\n    ACK fa5a886fa3a1d5bef80248a421b1e11aa991d477\n\nTree-SHA512: d57a6a0f0a66615bebb3cca19dc831cca38be0f18a580bb88e774384c55ccc545279b6d115b86fda70528a86630065393fb692fc2997ef87f97eec2d162808bb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shutogeorgio/bitcoin/commits/4aa06f944768bd81022ef29096a1021433cfa482'},
#     {'sha': '4f8b1f8759301d2553183e14f72444a0f1d80725',
#      'author': {'email': 'fanquake@gmail.com', 'name': 'fanquake'},
#      'message': "Merge bitcoin/bitcoin#23608: test: fix `feature_rbf.py --descriptors` and add to test runner\n\nb79dbe86a9886b3539512f6c35205f4c5454a952 test: add feature_rbf.py --descriptors to test_runner.py (Sebastian Falbesoner)\n166f8ec28e48aa4c0cd94544909c488df553d8ef test: always rescan after importing private keys in `init_wallet` helper (Sebastian Falbesoner)\n\nPull request description:\n\n  The functional test feature_rbf.py currently fails on master branch, if descriptor wallets are used (argument `--descriptors`). This is due to the fact that in this case, a call to the helper `init_wallet`\n\n  https://github.com/bitcoin/bitcoin/blob/111c3e06b35b7867f2e0f740e988f648ac6c325d/test/functional/test_framework/test_framework.py#L428-L434\n\n  creates a wallet without rescanning the blockchain; the test framework maps the importprivkey RPC calls to the importdescriptors RPC without rescanning by default (timestamp='now'). Fix this by always calling with `rescan=True`, which calls importdescriptors with timestamp=0. Also add `feature_rbf.py --descriptors` to the list of the test runner's calls.\n\n  Fixes #23563.\n\nACKs for top commit:\n  mjdietzx:\n    ACK b79dbe86a9886b3539512f6c35205f4c5454a952\n\nTree-SHA512: a3f3f7a4077066e3c910919d3b5e04bc6b580c1e0a06e9a2fc258950eaea5e59c0f805c8f00432aea722609f2f7e41eebfab653471b76729c5a316825a3d8c86",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shutogeorgio/bitcoin/commits/4f8b1f8759301d2553183e14f72444a0f1d80725'}]},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382019',
#   'type': 'WatchEvent',
#   'actor': {'id': 26456154,
#    'login': 'zhangying-code',
#    'display_login': 'zhangying-code',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhangying-code',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26456154?'},
#   'repo': {'id': 128141343,
#    'name': 'dsherret/conditional-type-checks',
#    'url': 'https://api.github.com/repos/dsherret/conditional-type-checks'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078382011',
#   'type': 'CreateEvent',
#   'actor': {'id': 91225758,
#    'login': '0-X0deX-o',
#    'display_login': '0-X0deX-o',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/0-X0deX-o',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91225758?'},
#   'repo': {'id': 432654426,
#    'name': '0-X0deX-o/programmingBooks',
#    'url': 'https://api.github.com/repos/0-X0deX-o/programmingBooks'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:45Z'},
#  {'id': '19078382016',
#   'type': 'DeleteEvent',
#   'actor': {'id': 22152877,
#    'login': 'takonomura',
#    'display_login': 'takonomura',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/takonomura',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22152877?'},
#   'repo': {'id': 432633229,
#    'name': 'takonomura/dex',
#    'url': 'https://api.github.com/repos/takonomura/dex'},
#   'payload': {'ref': 'v2.30.2', 'ref_type': 'tag', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:46Z'},
#  {'id': '19078381999',
#   'type': 'CreateEvent',
#   'actor': {'id': 66804870,
#    'login': 'kadirselcuk',
#    'display_login': 'kadirselcuk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kadirselcuk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66804870?'},
#   'repo': {'id': 284988500,
#    'name': 'kadirselcuk/desktop',
#    'url': 'https://api.github.com/repos/kadirselcuk/desktop'},
#   'payload': {'ref': 'snyk-fix-f8a87da880a2c6a2a43d592683da24ea',
#    'ref_type': 'branch',
#    'master_branch': 'development',
#    'description': 'Simple collaboration from your desktop',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:45Z'},
#  {'id': '19078382003',
#   'type': 'DeleteEvent',
#   'actor': {'id': 45145746,
#    'login': 'Naeviant',
#    'display_login': 'Naeviant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Naeviant',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45145746?'},
#   'repo': {'id': 432486593,
#    'name': 'Hive-Worker-Bees/PokemonSanctuary',
#    'url': 'https://api.github.com/repos/Hive-Worker-Bees/PokemonSanctuary'},
#   'payload': {'ref': 'more-pokemon',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-28T08:07:45Z',
#   'org': {'id': 95129434,
#    'login': 'Hive-Worker-Bees',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Hive-Worker-Bees',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95129434?'}}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
