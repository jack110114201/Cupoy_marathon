# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# * 請附上截圖：_______
#
# ![]()

# %% [markdown]
# ![title](image.PNG)

# %%
import requests
import json

r = requests.get('https://www.dcard.tw/service/api/v2/forums?nsfw=true&withPostListExcludeForums=false')
d = json.loads(r.text)

d
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# [{'id': '7f125e07-4460-4ea5-80b5-33f0e9aafa0c',
#   'alias': 'midnightlab',
#   'name': '午夜實驗室',
#   'description': '午夜實驗室10/6、10/7即將在華山登場！這裏提供大家交流活動資訊與討論，請大家要遵守 Dcard 板規喔！',
#   'subscriptionCount': 1694,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-14T19:15:15.698Z',
#   'updatedAt': '2021-04-20T08:36:58.712Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': True,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': [],
#   'topics': ['午夜實驗室'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic'],
#   'postCount': {'last30Days': 1},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'c0ed3f99-ed1c-49a8-b413-ed5e925aafe4',
#   'alias': 'timecapsule',
#   'name': '時光膠囊',
#   'description': 'Dcard 九週年最終章！告別動盪不安的 2020，說好了，2021 我們一起活得更努力！請寫一封信給 2021 的自己，你想要成為什麼樣的人、想達成的新年目標或行動計畫？這些願望，Dcard 陪你一起完成。許願的卡友們一年後都會收到「時光膠囊」，提醒你檢視「和 Dcard 的約定」完成了多少。在文章裡留下一句想隨身提醒自己的話，就有機會訂製你專屬的 D 卡。',
#   'subscriptionCount': 4276,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-14T20:15:15.698Z',
#   'updatedAt': '2021-01-07T07:24:57.455Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': True,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/9ab1db4e-8beb-4072-be8a-d067a0a02f92/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/18ce292e-934e-41d0-8936-11433faf56be/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 300},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'cc2164ae-88cd-466d-b11b-19e4b1f6f78c',
#   'alias': 'mother',
#   'name': '母親節',
#   'description': 'Dcard 母親節限定板，告訴媽媽我愛妳！',
#   'subscriptionCount': 364,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-14T22:15:15.698Z',
#   'updatedAt': '2021-04-20T08:36:35.702Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': True,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': ['我是媽寶我驕傲',
#    '曬媽媽',
#    '母親節蛋糕',
#    '康乃馨',
#    '母親節花束',
#    '我愛媽媽',
#    '母親節禮物',
#    '媽媽我愛你',
#    '媽媽',
#    '母親節大餐',
#    '母親節檔期'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic'],
#   'postCount': {'last30Days': 1},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '11e8d941-0aad-4960-8348-b27c36270fd1',
#   'alias': 'merryxmas',
#   'name': '聖誕CiaoCiao',
#   'description': '期間限定開啟！只要是和聖誕節有關的事情，或是和「禮物」有關的東西通通都來分享吧！',
#   'subscriptionCount': 16837,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-17T00:11:15.741Z',
#   'updatedAt': '2021-12-06T04:52:31.587Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': ['Dcard聖誕列車', '交換禮物', '聖誕禮物', '聖誕卡片', '聖誕舞會', '聖誕樹', '聖誕節'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/7b5b4c6c-ee5b-4903-a27f-e772de58f078/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/0d803925-c126-45db-8d21-2a18c65b85ee/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 37},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '8d5cabde-d0df-479f-8ab7-153209317537',
#   'alias': 'father',
#   'name': '父親節',
#   'description': 'Dcard 父親節特輯，上傳爸爸帥照，寫下真摯文字，一起謝謝我們心中的 「鋼鐵人老爸」。',
#   'subscriptionCount': 358,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-17T00:12:15.741Z',
#   'updatedAt': '2021-11-15T09:41:19.742Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': True,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'poll'],
#   'postCount': {'last30Days': 3},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '4dd9f69b-9b33-4ba0-9cec-887d8c5091e4',
#   'alias': 'bugreport',
#   'name': '臨時回報',
#   'description': '臨時回報版本問題',
#   'subscriptionCount': 17,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-18T07:20:35.139Z',
#   'updatedAt': '2017-06-18T03:31:45.331Z',
#   'canPost': False,
#   'ignorePost': True,
#   'invisible': True,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic'],
#   'postCount': {'last30Days': 1},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '460a5276-0480-4af1-86df-14b3040cab08',
#   'alias': '5anniversary',
#   'name': '五週年紀念',
#   'description': '五週年徵文活動限定板，僅供活動徵文、討論，發文前請先閱讀置頂喔！',
#   'subscriptionCount': 5286,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-18T07:20:35.139Z',
#   'updatedAt': '2018-04-18T07:16:27.550Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': True,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic'],
#   'postCount': {'last30Days': 7},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '3c91f2b0-6374-4467-b557-2e5383680afb',
#   'alias': 'ntu',
#   'name': '臺灣大學',
#   'description': '臺灣大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 29130,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T08:15:15.752Z',
#   'updatedAt': '2021-07-30T06:34:15.823Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/cf164bf7-5918-4b53-956e-93632d033b14/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/9808ed78-e150-47bb-847f-70eab4b55470/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 765},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'caf9487a-1994-494d-81f2-7950438e7bef',
#   'alias': 'nccu',
#   'name': '政治大學',
#   'description': '政治大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 18817,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T09:15:15.753Z',
#   'updatedAt': '2021-12-06T06:04:50.935Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/c80ae1a6-45d0-44e7-b8e5-539cd3a88043/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/0af62c52-7fdd-4055-9f4c-c91b00ea856a/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 1081},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '204997a1-c63d-4dc4-965e-9f018e452d1d',
#   'alias': 'nctu',
#   'name': '交通大學',
#   'description': '交通大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 11927,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T10:15:15.754Z',
#   'updatedAt': '2021-08-06T06:25:19.617Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/37208085-bffc-4a75-a17c-7a2b358515ef/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/b6ef12ed-e127-41db-a3cd-4f9a518eaefa/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 191},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '5120400e-e5e6-4676-a1b8-75a13625ecea',
#   'alias': 'tku',
#   'name': '淡江大學',
#   'description': '淡江大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 24010,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T11:15:15.756Z',
#   'updatedAt': '2021-12-06T06:05:07.797Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/bc6f4ea2-8698-4f85-8656-3ca6a93e0bea/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/176586b3-0d17-4e5f-89c9-e3c2e0d52ea2/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 1679},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'a8a2712f-80de-40c6-971f-c7bbb77716fe',
#   'alias': 'ndhu',
#   'name': '東華大學',
#   'description': '東華大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 9133,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T12:15:15.757Z',
#   'updatedAt': '2021-07-30T06:55:51.438Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/1517a9b4-f01c-4cc7-b2bb-3224f87cddf7/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/32a86221-9082-4dfe-9c3d-27125e361df3/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 828},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'abc4fa45-a456-49c6-8948-8981ad0b0f97',
#   'alias': 'ncku',
#   'name': '成功大學',
#   'description': '成功大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 24381,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T13:15:15.759Z',
#   'updatedAt': '2021-07-28T09:01:11.187Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/313d8179-6adb-4d87-a0fc-8c97fd9f14bf/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/7812ed61-f3ff-4e62-bbb4-85489610d513/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 1157},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'b6634fbb-b96a-41c6-82e1-80c18ed23dec',
#   'alias': 'ntut',
#   'name': '北科大',
#   'description': '北科大板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 9900,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T14:15:15.761Z',
#   'updatedAt': '2021-08-06T06:27:25.225Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/ad6ab485-9ad7-4872-84b0-00a967940d1b/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/dc2aafc4-9004-455d-ba1f-a6eb5a6375c6/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 138},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'a62a724b-4fdd-4044-b6d3-19483aa7f0df',
#   'alias': 'fju',
#   'name': '輔仁大學',
#   'description': '輔仁大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 22895,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T15:15:15.762Z',
#   'updatedAt': '2021-07-29T03:12:15.501Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/aeb20423-4edc-4832-b0f4-4d16236ee491/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/65316159-38dd-4fc4-bac8-03833d2530fb/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 1090},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '934ab7f8-a550-4b6a-b97c-44fc63a3345e',
#   'alias': 'ntnu',
#   'name': '師範大學',
#   'description': '師範大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 10128,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T16:15:15.764Z',
#   'updatedAt': '2021-08-06T06:28:02.251Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/7d5039ea-54c1-4515-96ce-6d4bfcb2aa96/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/6d409cfc-8310-4975-a38e-389940f1ab88/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 211},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'd2122f4e-d1b2-423a-8f68-1342906df9e9',
#   'alias': 'nknu',
#   'name': '高雄師範大學',
#   'description': '高雄師範大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 4235,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T17:15:15.765Z',
#   'updatedAt': '2021-08-06T06:40:49.361Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/c855878f-7855-451e-8db4-c69ce127d989/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/73e7a308-c8a5-439a-978d-a58b4b08dc8c/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 141},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '51a48caf-bfd4-4c12-979e-c55962856a81',
#   'alias': 'ncue',
#   'name': '彰化師範大學',
#   'description': '彰化師範大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 6401,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T18:15:15.767Z',
#   'updatedAt': '2021-08-06T06:29:02.444Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/326bf514-f456-4c58-96aa-a311761862c9/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/12e4f148-af86-440e-b2f0-4e7cb975fdd5/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 202},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '89e7bb6b-e15f-4168-add7-0b498e335ce7',
#   'alias': 'ncu',
#   'name': '中央大學',
#   'description': '中央大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 12059,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T19:15:15.768Z',
#   'updatedAt': '2021-08-06T06:25:55.703Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/c477af20-4885-4183-898f-fef172a902da/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/61e8d725-fd66-4dc0-98df-e4b3d02cfbaf/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 212},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '6f72a221-b46c-4f1e-9d82-26378d407608',
#   'alias': 'fcu',
#   'name': '逢甲大學',
#   'description': '逢甲大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 21800,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T20:15:15.770Z',
#   'updatedAt': '2021-07-30T06:34:07.756Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/843cb1d1-5a08-4cae-9361-283b8e95c8d5/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/c161ea54-618a-49eb-9710-fefffc7f6c33/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 628},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'e45851be-ad1b-4580-aa92-fe3e6e6fcd7e',
#   'alias': 'nthu',
#   'name': '清華大學',
#   'description': '清華大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 14348,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T21:15:15.771Z',
#   'updatedAt': '2021-07-30T06:34:26.725Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/124c6e6e-7513-4454-9f1d-eef5cff943b4/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/2ca1c8d0-d620-418b-8f03-6a21223d6963/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 539},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '921374a2-1d49-491f-968f-87f187d6928e',
#   'alias': 'ncnu',
#   'name': '暨南大學',
#   'description': '暨南大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 5260,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T22:15:15.773Z',
#   'updatedAt': '2021-08-06T06:27:13.452Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/27a6693a-41a3-426a-94ce-b8e835a2bd80/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/a915dad1-a1cd-4a35-8198-bab82ed124f4/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 399},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '91d20ae5-be49-419a-bd8b-457de2064aa3',
#   'alias': 'thu',
#   'name': '東海大學',
#   'description': '東海大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 16881,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-19T23:15:15.774Z',
#   'updatedAt': '2021-07-30T06:34:10.706Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/6749fe85-9287-4cd2-8652-a7e57028fa83/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/3d3e6f7a-fc87-4ba8-82b8-a909078b4f5f/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 1073},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'd477f90b-56e4-423d-8686-3524dc331bd5',
#   'alias': 'nkfust',
#   'name': '高雄第一科大',
#   'description': '高雄第一科大板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 8858,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T00:15:15.776Z',
#   'updatedAt': '2021-08-06T06:40:54.535Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/1a31e4b4-3daa-46e7-addd-562d1ee970e5/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/b67f780a-a98d-4f0d-ad79-71563a0d28fe/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 101},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '7e1a5d67-6085-491b-987a-e8ab6ddbd3ce',
#   'alias': 'ntust',
#   'name': '台科大',
#   'description': '台科大板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 9817,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T01:15:15.777Z',
#   'updatedAt': '2021-08-06T06:27:03.667Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/80ba5305-f90f-4efa-8f5c-ad9837eb5e8f/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/a3120743-b923-4ade-8417-5ed491d80471/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 197},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '9bfaab73-e0d2-4e73-ab82-101ab66dd2d4',
#   'alias': 'nchu',
#   'name': '中興大學',
#   'description': '中興大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 13551,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T02:15:15.779Z',
#   'updatedAt': '2021-07-29T03:12:19.843Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/bee7a5fb-f4c6-48ae-bfe1-6ace87dbc1dc/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/51f16f78-0cb8-4a15-84f4-67bfb4ec58f7/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 567},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '5e7919b5-805c-41c7-ad27-332105f9c614',
#   'alias': 'yzu',
#   'name': '元智大學',
#   'description': '元智大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 7556,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T03:15:15.780Z',
#   'updatedAt': '2021-08-06T06:25:47.095Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/0f91df24-f7c0-4c92-8b83-8d962e4090e3/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/8a7ee551-2866-4719-8444-ae7bd322c9fd/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 376},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '8b977798-d2b7-4c58-a21f-43c50e802bcf',
#   'alias': 'nuu',
#   'name': '聯合大學',
#   'description': '聯合大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 6427,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T04:15:15.782Z',
#   'updatedAt': '2021-08-06T06:25:39.104Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/b2e09129-2e82-4bbb-ae6f-df410f8702b1/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/72a16ede-18a5-4129-8c52-d12bde245a51/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 186},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '2cc8a947-691c-43c5-9f22-f323d1be75df',
#   'alias': 'ntou',
#   'name': '海洋大學',
#   'description': '海洋大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 7352,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T05:15:15.783Z',
#   'updatedAt': '2021-08-06T06:25:53.336Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/e1652401-25ed-496d-89ca-2e0e0611564e/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/d4e57420-b185-4d51-81e8-bcd987851012/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 274},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'eb59cc29-b856-4e45-8ff8-4936aeefc122',
#   'alias': 'nsysu',
#   'name': '中山大學',
#   'description': '中山大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 8315,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T06:15:15.784Z',
#   'updatedAt': '2021-08-06T06:26:50.404Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/fa56c166-40ad-4b7b-be89-c89f3bf70d9c/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/13a7a3c2-40a8-4b57-b230-3035ecff7a96/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 243},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '0b8a02a7-98c1-4da9-8c15-b3dea327ec65',
#   'alias': 'ntpu',
#   'name': '臺北大學',
#   'description': '臺北大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 9169,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T07:15:15.786Z',
#   'updatedAt': '2021-08-06T06:25:03.774Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/f8335431-74ef-49cb-94cd-b44df550774f/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/291d6a9e-69ce-4243-a31a-e60b45184e07/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 279},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'a69444ff-19f2-4ac4-b5d8-674a18a3b56b',
#   'alias': 'cpu',
#   'name': '中央警察大學',
#   'description': '中央警察大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 6859,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T08:15:15.787Z',
#   'updatedAt': '2021-08-06T06:35:30.968Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/1cbcfc71-e6e9-419f-a157-ee676e11499c/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/0872cd7b-d91c-44a0-a313-062ec88c29b7/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 83},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '2883c40b-552b-4b86-87ac-8c3209b88a17',
#   'alias': 'ccu',
#   'name': '中正大學',
#   'description': '中正大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 11122,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T09:15:15.788Z',
#   'updatedAt': '2021-07-30T06:34:13.000Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/4194bf5b-1fe2-46a2-85a4-8c3fe59212c6/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/ab892df7-78fc-475a-8959-68e8dcfa2f7c/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 470},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '2d5b4fc9-3eaa-4a8f-9dab-c9a835c2d5fa',
#   'alias': 'usc',
#   'name': '實踐大學',
#   'description': '實踐大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'subscriptionCount': 9176,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2016-05-20T10:15:15.790Z',
#   'updatedAt': '2021-07-30T06:35:31.098Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': True,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'subcategories': ['課程評價'],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'link'],
# ...
#   'alias': 'aquarium',
#   'name': '水族',
#   'description': '水族版，是一個能讓你開心分享水族相關大小事的地方。在這裡能讓卡友們盡情討論相關資訊，舉凡分享飼養的心得、對於品種的疑問及任何的疑難雜症都能在此看板得到解答！',
#   'subscriptionCount': 2018,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-10-14T05:53:21.235Z',
#   'updatedAt': '2021-12-16T07:00:51.468Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': True,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '新增標題分類的話，能加快回答的速度喔',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': ['請益', '分享', '水草', '海水魚', '水族設備', '小型魚', '其他'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/41abb8ee-d1e1-49f9-ab81-d939f08a369c/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/06a0302c-163b-4c9e-89be-1cbe5423e162/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 92},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '23112b48-0b74-4b37-a761-06351b33e241',
#   'alias': 'jp_performance',
#   'name': 'サークル',
#   'description': 'サークル掲示板へようこそ！',
#   'subscriptionCount': 154,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-10-18T04:02:43.036Z',
#   'updatedAt': '2021-11-29T10:14:43.051Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/f45eb104-ef87-4740-a96d-1efb1e12f43a/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/842431b2-87b7-440a-8b44-476f41679e8c/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 27},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '17185112-05c5-4659-82ac-f6e66db2d3fe',
#   'alias': 'jp_creative',
#   'name': 'サークル（クリエイティブ）',
#   'description': 'クリエイティブ掲示板へようこそ！この掲示板は10/21~11/28の期間で一番リアクションを獲得したサークルに賞金10万円＆サークルフェスティバル終了後１ヶ月間この掲示板で投稿を一番上の方にピン留めさせていただきます！素敵な投稿を見つけたらぜひリアクションしてしてください！',
#   'subscriptionCount': 59,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-10-18T04:04:51.182Z',
#   'updatedAt': '2021-11-29T10:11:50.619Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': True,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/96a8c180-f6c5-4657-8b66-6a82ee8724c9/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/01cdf5d9-72b9-4ab3-8928-c1a507c13849/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 3},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '80a12920-f4c1-4bc9-af40-c89526baabbb',
#   'alias': 'itzy',
#   'name': 'ITZY',
#   'description': 'ITZY, MIDZY, 날자!',
#   'subscriptionCount': 2408,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-10-21T03:05:53.289Z',
#   'updatedAt': '2021-12-10T00:47:51.692Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': True,
#   'hasPostCategories': True,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': 'ITZY, MIDZY, 날자!',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': ['分享', '消息', '公告', '舞台', '詢問', '綜藝'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/9534a852-f9df-4dfd-a1b6-356a92e92434/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1382,
#    'height': 460},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/94c3e1e5-8b05-4e11-abf6-9b83a61eb67b/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 22},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '16fda5a9-b48d-4b9b-88a1-cb21cfdb9639',
#   'alias': 'disney_plus',
#   'name': 'Disney+',
#   'description': 'Disney+ 確認 11/12 在台上線！！！',
#   'subscriptionCount': 14703,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-11-05T06:54:52.944Z',
#   'updatedAt': '2021-11-11T10:05:58.655Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/05ada016-4223-44ae-a3f8-ebb6d591eaa5/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 800,
#    'height': 266},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/69172514-0c00-4d2b-af40-9de23fed174f/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 138},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'cd9878ab-e0f1-4aea-851a-55799719f500',
#   'alias': 'steam',
#   'name': 'Steam',
#   'description': '入板發文、留言前，請詳閱置頂板規！\n\n本板為 Steam 板，討論主旨為一切與 Steam 有關之事物與話題。',
#   'subscriptionCount': 4029,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-11-05T07:30:37.820Z',
#   'updatedAt': '2021-12-15T08:37:57.612Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': True,
#   'hasPostCategories': True,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': ['分享', '討論', '情報', '請益', '揪團', '公告', '投票'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link', 'poll'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/0bef41b4-2bcb-42db-8140-c2c501971448/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/5dabc8cc-6738-4f32-9226-4a046af4fb78/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 68},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '21cd1563-fbe3-4e24-973e-fb4e4abb5f94',
#   'alias': 'blockchain_game',
#   'name': '區塊鏈遊戲',
#   'description': 'Gamefi市場多風險，謹慎參與，回本為上',
#   'subscriptionCount': 1098,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-11-05T07:31:30.942Z',
#   'updatedAt': '2021-12-09T04:29:40.810Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': ['虛擬貨幣', '區塊鏈', 'GameFi', '加密貨幣'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/6df69b27-349d-496d-8c38-63ef19f587bb/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/93e99e05-3e90-4322-be3d-d9286b858df3/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 46},
#   'favorite': False,
#   'enablePrivateMessage': True,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': 'd3d95a9c-4cbe-42ec-9aa8-edab9834c7d3',
#   'alias': 'bluearchive',
#   'name': '蔚藍檔案',
#   'description': '蔚藍檔案提供卡友分享討論攻略、共享檔案情報。一起來豐富你的學園生活吧！',
#   'subscriptionCount': 211,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-11-10T04:58:50.100Z',
#   'updatedAt': '2021-11-10T05:05:40.476Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': False,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/e76eed4c-84ce-4780-8aa0-c24e260bc8f6/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1800,
#    'height': 600},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/33c516bf-349c-48fc-8b82-777a999f2456/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 18},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '25bac930-7717-4d5f-87f7-2d4fd001c52a',
#   'alias': 'aespa',
#   'name': 'aespa',
#   'description': '歡迎喜歡aespa的MY們熱烈討論💙🌙⭐️🦋',
#   'subscriptionCount': 1873,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-11-12T05:43:35.455Z',
#   'updatedAt': '2021-12-16T09:47:40.260Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': True,
#   'hasPostCategories': True,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '發文前請閱讀版規喔！',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': ['閒聊', '資訊', '集中討論', '公告', '詢問', '數據', '後記'],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/399bc94b-4165-4f6e-b9b6-972bc6e457b8/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1170,
#    'height': 390},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/a68944a7-7763-4ab5-9070-f90c3f6566cb/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 14},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '861af50f-49b8-4c58-857b-092643416983',
#   'alias': 'house_purchase',
#   'name': '購屋',
#   'description': '青年購屋不是夢～但是從看房問題到驗屋過程總是有許多問題想發問，購屋不難，難在資金貸款/裝潢設計/驗屋選擇？來來來～不論你是來要答案還是來給答案，歡迎👏歡迎👏',
#   'subscriptionCount': 2654,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-11-25T05:25:15.931Z',
#   'updatedAt': '2021-11-25T17:23:48.622Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': True,
#   'hasPostCategories': True,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/3cf6c308-0e06-4554-9f52-af3e3446d8ff/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 1576,
#    'height': 525},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/2b05f056-7995-410c-962d-ef4a13bae474/full.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 16},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False},
#  {'id': '04eb1338-3026-4a1c-934c-e9d8fb273f5d',
#   'alias': 'xbox',
#   'name': 'Xbox',
#   'description': '分享討論微軟Xbox遊戲相關資訊 ，Xbox周邊軟體硬體 ，遊戲攻略、連線等問題。\n還有讓Xbox Game Pass Ultimate 這麼優質的會員 傳教給更多人知道。',
#   'subscriptionCount': 153,
#   'subscribed': False,
#   'read': False,
#   'createdAt': '2021-12-02T06:49:58.822Z',
#   'updatedAt': '2021-12-14T15:12:26.561Z',
#   'canPost': False,
#   'ignorePost': False,
#   'invisible': False,
#   'isSchool': False,
#   'fullyAnonymous': False,
#   'canUseNickname': True,
#   'postThumbnail': {'size': 'small'},
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'hasPostCategories': True,
#   'titlePlaceholder': '',
#   'postTitlePlaceholder': '發文請記得標記分類，轉載文章、圖片、影片請附上文章出處連結。',
#   'ipCountryCondition': {},
#   'subcategories': [],
#   'topics': [],
#   'nsfw': False,
#   'mediaThreshold': {},
#   'limitCountries': [],
#   'limitStage': 0,
#   'availableLayouts': ['classic', 'image', 'video', 'link'],
#   'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/95f5900c-eb9e-4248-ac69-75a10ce88de8/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 1280,
#    'height': 426},
#   'logo': {'url': 'https://megapx-assets.dcard.tw/images/1802bc24-36f8-4582-b1ce-5330eadbb2a1/orig.jpeg',
#    'type': 'image/jpeg',
#    'width': 200,
#    'height': 200},
#   'postCount': {'last30Days': 9},
#   'favorite': False,
#   'enablePrivateMessage': False,
#   'restrictIdentityOnComment': False,
#   'enableSelectedPosts': False,
#   'displaySelectedPostsTab': False,
#   'allowModManageSelectedPosts': False}]
