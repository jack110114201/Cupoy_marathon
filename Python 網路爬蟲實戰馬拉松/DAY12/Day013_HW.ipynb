# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html.parser')


for d in soup.find_all(class_="r-ent"):
    try:
        print('標題: ',d.find(class_="title").find('a').text)
        print('作者: ',d.find(class_="meta").find(class_='author').text)
        print('時間: ',d.find(class_="meta").find(class_='date').text)
        print('-----------------------------------')
    except AttributeError:
        print('本文已被刪除')
        print(d.find(class_="meta").find(class_='author').text)
        print('時間: ',d.find(class_="meta").find(class_='date').text)
        print('-----------------------------------')
# Out:
# 標題:  [花邊] CP3談關鍵抄截：就是球看多了，這麼簡單
# 作者:  arod1414
# 時間:  12/07
# -----------------------------------
# 標題:  [情報] ★今日排名(2021.12.07)★
# 作者:  Rambo
# 時間:  12/07
# -----------------------------------
# 本文已被刪除
# -
# 時間:  12/07
# -----------------------------------
# 標題:  [花邊] ESPN記者：拓荒者還要以小李建隊嗎？
# 作者:  mingonly
# 時間:  12/07
# -----------------------------------
# 標題:  [公告] NBA板主徵選開始
# 作者:  pneumo
# 時間:  11/16
# -----------------------------------
# 標題:  [公告] 板規v8.9
# 作者:  pneumo
# 時間:  11/22
# -----------------------------------
# 標題:  [情報] SEASON Schedule December 21–22
# 作者:  laptic
# 時間:  11/26
# -----------------------------------
# 標題:  [情報] NBA Standings (Dec. 07, 2021)
# 作者:  guardyo
# 時間:  12/07
# -----------------------------------
# 標題:  [情報] ★今日排名(2021.12.07)★
# 作者:  Rambo
# 時間:  12/07
# -----------------------------------

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
url = 'https://www.ptt.cc/bbs/NBA/index1.html'

r = requests.get(url)

soup = BeautifulSoup(r.text, 'html.parser')


for d in soup.find_all(class_="r-ent"):
    try:
        print('標題: ',d.find(class_="title").find('a').text)
        print('作者: ',d.find(class_="meta").find(class_='author').text)
        print('時間: ',d.find(class_="meta").find(class_='date').text)
        print('-----------------------------------')
    except AttributeError:
        print('本文已被刪除')
        print(d.find(class_="meta").find(class_='author').text)
        print('時間: ',d.find(class_="meta").find(class_='date').text)
        print('-----------------------------------')
# Out:
# 標題:  寫在 NBA 版的第九個球季之前
# 作者:  Price
# 時間:  10/31
# -----------------------------------
# 標題:  Re: [問題] 請問為何milicic都沒法上場？？？？
# 作者:  SHB
# 時間:  11/16
# -----------------------------------
# 標題:  Re: melo......
# 作者:  RickymarU
# 時間:  11/16
# -----------------------------------
# 標題:  [閒聊] penny
# 作者:  baoerking
# 時間:  11/18
# -----------------------------------
# 標題:  Re: 灌籃次數排行板
# 作者:  chinlingts
# 時間:  11/20
# -----------------------------------
# 標題:  Re: 哇勒大亂鬥~~~~今天這場真是[email protected]@
# 作者:  KOC
# 時間:  11/20
# -----------------------------------
# 標題:  [轉錄]（溜馬與活塞）後續發展  ~~by SHB
# 作者:  Lyotard
# 時間:  11/20
# -----------------------------------
# 標題:  Re:（溜馬與活塞）後續發展  ~~by SHB
# 作者:  BIASONICA
# 時間:  11/20
# -----------------------------------
# 標題:  Re: [請益] 請問nba各隊看板人物...
# 作者:  sunnyside
# 時間:  11/20
# -----------------------------------
# 標題:  Re: Good times for Jazz started with Stockton
# 作者:  temped
# 時間:  11/23
# -----------------------------------
# 標題:  十二月轉播表(未定)
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
payload = {
'from': '/bbs/sex/index.html',
'yes': 'yes'
}

rs = requests.session()
res = rs.post('https://www.ptt.cc/ask/over18',data=payload)
res = rs.get('https://www.ptt.cc/bbs/sex/index4000.html')

soup = BeautifulSoup(res.text, 'html.parser')

for d in soup.find_all(class_="r-ent"):
    try:
        print('標題: ',d.find(class_="title").find('a').text)
        print('作者: ',d.find(class_="meta").find(class_='author').text)
        print('時間: ',d.find(class_="meta").find(class_='date').text)
        print('-----------------------------------')
    except AttributeError:
        print('本文已被刪除')
        print(d.find(class_="meta").find(class_='author').text)
        print('時間: ',d.find(class_="meta").find(class_='date').text)
        print('-----------------------------------')
# Out:
# 本文已被刪除
# -
# 時間:  12/05
# -----------------------------------
# 標題:  [閒聊] 現在是不是罩杯通膨？
# 作者:  lpbrother
# 時間:  12/05
# -----------------------------------
# 標題:  [討論] 不是不想做
# 作者:  darksign
# 時間:  12/05
# -----------------------------------
# 標題:  [心得] 我們為何上床，又怕交往
# 作者:  boeing5566
# 時間:  12/05
# -----------------------------------
# 標題:  Re: [閒聊] 現在是不是罩杯通膨？
# 作者:  skinjazz
# 時間:  12/05
# -----------------------------------
# 標題:  Re: [閒聊] 現在是不是罩杯通膨？
# 作者:  Landtoss
# 時間:  12/05
# -----------------------------------
# 標題:  Re: [討論] 口爆、肛交 哪個是女生真愛的指標?(文長慎入)
# 作者:  heavenbeyond
# 時間:  12/05
# -----------------------------------
# 標題:  Re: [閒聊] 大家最刺激的性愛地點 ?
# 作者:  heavenbeyond
# 時間:  12/05
# -----------------------------------
# 標題:  [新聞] 摩鐵偷吃！人妻內褲掛門把 被尪抓包辯：上面有芒草刺
# 作者:  EVEA
# 時間:  12/05
# -----------------------------------
# 標題:  [新聞] 消防版林秉樞 性愛片外流她老公、同學
# 作者:  hvariables
# 時間:  12/05
# -----------------------------------
# 標題:  [心得] Omicron新變種籠罩下的FKK體驗-Shark
# 作者:  BlackBaoyu
# ...
