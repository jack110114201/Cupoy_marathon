# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
import requests
import json

# %%
API_text = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=true")
API_json = json.loads(API_text.text)
API_json
# Out:
# [{'id': 237558000,
#   'title': '討厭貓的媽媽 一年的變化',
#   'excerpt': '不知道還有沒有人記得，養貓前跟我鬧家庭革命的媽媽🤣，給大家複習一下 跟家人溝通兩年的我，養貓前，我媽有時候會以為我偷養貓 氣的想要罵我，⬇️ （當時還沒有貓），⬇️ （叫我出去住才可以養的媽媽），然後直到',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-29T04:16:52.111Z',
#   'updatedAt': '2021-11-29T04:16:52.111Z',
#   'commentCount': 58,
#   'likeCount': 1586,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['養貓', '小翠花小姐', '布偶貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '翠花爸',
#   'department': 'doge_g.m',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '40baa60b-191d-4ee2-9cb7-69fb3c7c4cbe',
#     'url': 'https://i.imgur.com/OcLm1opl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/OcLm1opl.jpg',
#     'thumbnail': 'https://i.imgur.com/OcLm1opl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1440,
#     'height': 1440},
#    {'id': '40baa60b-191d-4ee2-9cb7-69fb3c7c4cbe',
#     'url': 'https://i.imgur.com/OcLm1op.jpg',
#     'normalizedUrl': 'https://imgur.com/OcLm1op',
#     'thumbnail': 'https://i.imgur.com/OcLm1opl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1440,
#     'height': 1440},
#    {'id': '3b379683-bd6a-41ae-b86c-2c6afee74420',
#     'url': 'https://i.imgur.com/kRffPa5.jpg',
#     'normalizedUrl': 'https://imgur.com/kRffPa5',
#     'thumbnail': 'https://i.imgur.com/kRffPa5l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 475},
#    {'id': '4a9af51e-4d63-44f1-8579-d96327faea3b',
#     'url': 'https://i.imgur.com/5BtQfgo.jpg',
#     'normalizedUrl': 'https://imgur.com/5BtQfgo',
#     'thumbnail': 'https://i.imgur.com/5BtQfgol.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 736},
#    {'id': 'd1fa316e-f7f1-47d2-b18e-57986d7159fc',
#     'url': 'https://i.imgur.com/AcJCtCM.jpg',
#     'normalizedUrl': 'https://imgur.com/AcJCtCM',
#     'thumbnail': 'https://i.imgur.com/AcJCtCMl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 1289},
#    {'id': 'b862b1da-18a7-463a-8455-f44e3d9222d7',
#     'url': 'https://i.imgur.com/wQaS4UJ.jpg',
#     'normalizedUrl': 'https://imgur.com/wQaS4UJ',
#     'thumbnail': 'https://i.imgur.com/wQaS4UJl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 817},
#    {'id': '206a9b58-246d-44b4-8a48-2b84bb224eb0',
#     'url': 'https://i.imgur.com/QU3j5ed.jpg',
#     'normalizedUrl': 'https://imgur.com/QU3j5ed',
#     'thumbnail': 'https://i.imgur.com/QU3j5edl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 1333},
#    {'id': 'aedc8f58-9303-461f-bcad-e6d0a81ba050',
#     'url': 'https://i.imgur.com/xlQQTQ3.jpg',
#     'normalizedUrl': 'https://imgur.com/xlQQTQ3',
#     'thumbnail': 'https://i.imgur.com/xlQQTQ3l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1087,
#     'height': 2000},
#    {'id': '70aae5a2-44b1-46c6-99d5-6e049830007a',
#     'url': 'https://i.imgur.com/lncAiIo.jpg',
#     'normalizedUrl': 'https://imgur.com/lncAiIo',
#     'thumbnail': 'https://i.imgur.com/lncAiIol.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 772},
#    {'id': 'e07f5bdd-9f98-4049-b172-ffcbe7e9aea6',
#     'url': 'https://i.imgur.com/3Yts3vO.jpg',
#     'normalizedUrl': 'https://imgur.com/3Yts3vO',
#     'thumbnail': 'https://i.imgur.com/3Yts3vOl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 981},
#    {'id': 'b183ee9f-93a5-4fec-8062-c7ef57de20e2',
#     'url': 'https://i.imgur.com/tZOsv3x.jpg',
#     'normalizedUrl': 'https://imgur.com/tZOsv3x',
#     'thumbnail': 'https://i.imgur.com/tZOsv3xl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 1286},
#    {'id': 'fc69a068-d32a-4b0a-bd13-ca2a1b2c9274',
#     'url': 'https://i.imgur.com/losP7TJ.jpg',
#     'normalizedUrl': 'https://imgur.com/losP7TJ',
#     'thumbnail': 'https://i.imgur.com/losP7TJl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1284,
#     'height': 1577},
#    {'id': '5e80c1e5-cf59-4bf3-b442-7800a37a0bef',
#     'url': 'https://i.imgur.com/k5NVaUj.jpg',
#     'normalizedUrl': 'https://imgur.com/k5NVaUj',
#     'thumbnail': 'https://i.imgur.com/k5NVaUjl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T04:16:52.111Z',
#     'updatedAt': '2021-11-29T04:16:52.111Z',
#     'width': 1108,
#     'height': 1478}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1555},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 26},
#    {'id': '011ead16-9b83-4729-9fde-c588920c6c2d', 'count': 2},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 2},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 58,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/OcLm1op.jpg'},
#    {'url': 'https://i.imgur.com/kRffPa5.jpg'},
#    {'url': 'https://i.imgur.com/5BtQfgo.jpg'},
#    {'url': 'https://i.imgur.com/AcJCtCM.jpg'},
#    {'url': 'https://i.imgur.com/wQaS4UJ.jpg'},
#    {'url': 'https://i.imgur.com/QU3j5ed.jpg'},
#    {'url': 'https://i.imgur.com/xlQQTQ3.jpg'},
#    {'url': 'https://i.imgur.com/lncAiIo.jpg'},
#    {'url': 'https://i.imgur.com/3Yts3vO.jpg'},
#    {'url': 'https://i.imgur.com/tZOsv3x.jpg'},
#    {'url': 'https://i.imgur.com/losP7TJ.jpg'},
#    {'url': 'https://i.imgur.com/k5NVaUj.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': 'https://megapx-assets.dcard.tw/images/2923302b-1be6-49af-a8ce-fd8a54a78a7c/orig.png',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237553984,
#   'title': '台灣貓',
#   'excerpt': '人家説台灣人最愛的是排隊，原來台灣貓也愛排隊，可以告訴我你們在排什麼隊嗎',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T12:33:46.612Z',
#   'updatedAt': '2021-11-28T12:33:46.612Z',
#   'commentCount': 29,
#   'likeCount': 556,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '寵物', '貓咪', '貓咪真的很可愛', '米克斯'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '愛下廚不愛洗碗的大J🌈',
#   'department': 'j12349741',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6fa5d049-ffb7-4abe-89d6-430ba6c6a76c',
#     'url': 'https://i.imgur.com/RGWXmTRl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/RGWXmTRl.jpg',
#     'thumbnail': 'https://i.imgur.com/RGWXmTRl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T12:33:46.612Z',
#     'updatedAt': '2021-11-28T12:33:46.612Z',
#     'width': 720,
#     'height': 1280},
#    {'id': '6fa5d049-ffb7-4abe-89d6-430ba6c6a76c',
#     'url': 'https://i.imgur.com/RGWXmTR.jpg',
#     'normalizedUrl': 'https://imgur.com/RGWXmTR',
#     'thumbnail': 'https://i.imgur.com/RGWXmTRl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T12:33:46.612Z',
#     'updatedAt': '2021-11-28T12:33:46.612Z',
#     'width': 720,
#     'height': 1280}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 506},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 48},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 29,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/RGWXmTR.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237551033,
#   'title': '台中兩隻貓貓送養♥',
#   'excerpt': '哈囉各位～～這次我們要送養的是兩隻剛出生不久的貓貓們，小玳瑁和小虎斑，（前三張是小虎斑、後三張是小玳瑁），活潑好動的他們每次都和兄弟姊妹們玩到翻肚肚，平時喜歡在籠子裡來回衝刺，時不時還會表演個特技，懸',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T03:32:01.333Z',
#   'updatedAt': '2021-11-28T03:32:01.333Z',
#   'commentCount': 17,
#   'likeCount': 348,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['台中', '貓貓', '送養', '貓', '寵物'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '東海大學米克斯動物關懷社',
#   'department': 'lovemayday0603',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '4b1e4892-23b7-44e0-bc62-67fda417bfef',
#     'url': 'https://i.imgur.com/8kdCtJNl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/8kdCtJNl.jpg',
#     'thumbnail': 'https://i.imgur.com/8kdCtJNl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T03:32:01.333Z',
#     'updatedAt': '2021-11-28T03:32:01.333Z',
#     'width': 1080,
#     'height': 1080},
#    {'id': '4b1e4892-23b7-44e0-bc62-67fda417bfef',
#     'url': 'https://i.imgur.com/8kdCtJN.jpg',
#     'normalizedUrl': 'https://imgur.com/8kdCtJN',
#     'thumbnail': 'https://i.imgur.com/8kdCtJNl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T03:32:01.333Z',
#     'updatedAt': '2021-11-28T03:32:01.333Z',
#     'width': 1080,
#     'height': 1080},
#    {'id': 'e5aec0d6-3046-48cf-a913-744af26061ea',
#     'url': 'https://i.imgur.com/FwsSzrq.jpg',
#     'normalizedUrl': 'https://imgur.com/FwsSzrq',
#     'thumbnail': 'https://i.imgur.com/FwsSzrql.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T03:32:01.333Z',
#     'updatedAt': '2021-11-28T03:32:01.333Z',
#     'width': 1080,
#     'height': 1080},
#    {'id': 'e9bda529-2840-489b-bb36-3f3f288606bc',
#     'url': 'https://i.imgur.com/bb0aUxx.jpg',
#     'normalizedUrl': 'https://imgur.com/bb0aUxx',
#     'thumbnail': 'https://i.imgur.com/bb0aUxxl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T03:32:01.333Z',
#     'updatedAt': '2021-11-28T03:32:01.333Z',
#     'width': 1080,
#     'height': 1080},
#    {'id': 'd12c86df-080a-4f5d-94c6-3e51c66834d8',
#     'url': 'https://i.imgur.com/safXLHB.jpg',
#     'normalizedUrl': 'https://imgur.com/safXLHB',
#     'thumbnail': 'https://i.imgur.com/safXLHBl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T03:32:01.333Z',
#     'updatedAt': '2021-11-28T03:32:01.333Z',
#     'width': 723,
#     'height': 723},
#    {'id': '8582eaa1-ec67-4890-ae25-075db63a2267',
#     'url': 'https://i.imgur.com/cV8EILL.jpg',
#     'normalizedUrl': 'https://imgur.com/cV8EILL',
#     'thumbnail': 'https://i.imgur.com/cV8EILLl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T03:32:01.333Z',
#     'updatedAt': '2021-11-28T03:32:01.333Z',
#     'width': 1080,
#     'height': 1080},
#    {'id': 'df80499e-0153-4f28-a04b-850cbdd76d29',
#     'url': 'https://i.imgur.com/QVhY6QE.jpg',
#     'normalizedUrl': 'https://imgur.com/QVhY6QE',
#     'thumbnail': 'https://i.imgur.com/QVhY6QEl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T03:32:01.333Z',
#     'updatedAt': '2021-11-28T03:32:01.333Z',
#     'width': 1080,
#     'height': 1080}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 345},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 17,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/8kdCtJN.jpg'},
#    {'url': 'https://i.imgur.com/FwsSzrq.jpg'},
#    {'url': 'https://i.imgur.com/bb0aUxx.jpg'},
#    {'url': 'https://i.imgur.com/safXLHB.jpg'},
#    {'url': 'https://i.imgur.com/cV8EILL.jpg'},
#    {'url': 'https://i.imgur.com/QVhY6QE.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237554159,
#   'title': '長期鍊繩的貓',
#   'excerpt': '我上班都會經過一間店家，大約看了快一年了，門口有一隻長期被鍊繩的母貓，大約10個月前看過母貓在哺育幾隻小貓，最近母貓生了四隻小貓，越看越心疼貓媽媽，於是我下班時特地去錄影想檢舉飼主未將寵物絕育、以及長',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T13:01:08.830Z',
#   'updatedAt': '2021-11-28T13:01:08.830Z',
#   'commentCount': 82,
#   'likeCount': 279,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '請益'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '台南應用科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'e8a02862-f738-465a-98bf-3996eb283f89',
#     'url': 'https://vivid.dcard.tw/Public/0c4b18dd-e10b-4bdc-ae42-57664618ba0e/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/0c4b18dd-e10b-4bdc-ae42-57664618ba0e/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/0c4b18dd-e10b-4bdc-ae42-57664618ba0e/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T13:01:08.830Z',
#     'updatedAt': '2021-11-28T13:01:08.830Z'},
#    {'id': 'e8a02862-f738-465a-98bf-3996eb283f89',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/0c4b18dd-e10b-4bdc-ae42-57664618ba0e?r=0.5625',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/0c4b18dd-e10b-4bdc-ae42-57664618ba0e/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-28T13:01:08.830Z',
#     'updatedAt': '2021-11-28T13:01:08.830Z'},
#    {'id': '0f88f820-92af-4267-8dae-54de1c31bbda',
#     'url': 'https://i.imgur.com/AfhBczb.jpg',
#     'normalizedUrl': 'https://imgur.com/AfhBczb',
#     'thumbnail': 'https://i.imgur.com/AfhBczbl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T13:01:08.830Z',
#     'updatedAt': '2021-11-28T13:01:08.830Z',
#     'width': 870,
#     'height': 1883},
#    {'id': '8e265eb2-069c-4758-8e10-126311727f48',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/50d38bbe-3021-47c2-b77d-3320255e46d9?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/50d38bbe-3021-47c2-b77d-3320255e46d9/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-28T13:01:08.830Z',
#     'updatedAt': '2021-11-28T13:01:08.830Z'},
#    {'id': '02f6c83a-164d-4cc8-86a4-824ad6b79c3a',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/ca8fcd96-3c49-49b4-a704-bb5f7fbdd42c?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/ca8fcd96-3c49-49b4-a704-bb5f7fbdd42c/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-28T13:01:08.830Z',
#     'updatedAt': '2021-11-28T13:01:08.830Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 227},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 33},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 19}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 82,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/0c4b18dd-e10b-4bdc-ae42-57664618ba0e/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/AfhBczb.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/50d38bbe-3021-47c2-b77d-3320255e46d9/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/ca8fcd96-3c49-49b4-a704-bb5f7fbdd42c/thumbnail.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237552138,
#   'title': '好想知道她夢到什麼',
#   'excerpt': '坐著坐著睡著已經見怪不怪了但，如題，她是夢到在啃雞腿嗎⋯⋯，快被她笑死',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T07:18:18.069Z',
#   'updatedAt': '2021-11-28T07:24:39.708Z',
#   'commentCount': 5,
#   'likeCount': 273,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '美短', '奇葩', '日常'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '我愛咖喱',
#   'department': 'v8989',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '84386bee-039e-47c0-a771-65f013b5ede8',
#     'url': 'https://i.imgur.com/As62Xyul.jpg',
#     'normalizedUrl': 'https://i.imgur.com/As62Xyul.jpg',
#     'thumbnail': 'https://i.imgur.com/As62Xyul.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T07:18:18.069Z',
#     'updatedAt': '2021-11-28T07:24:39.708Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '84386bee-039e-47c0-a771-65f013b5ede8',
#     'url': 'https://i.imgur.com/As62Xyu.jpg',
#     'normalizedUrl': 'https://imgur.com/As62Xyu',
#     'thumbnail': 'https://i.imgur.com/As62Xyul.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T07:18:18.069Z',
#     'updatedAt': '2021-11-28T07:24:39.708Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 259},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 14}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'enablePrivateMessage': False,
#   'totalCommentCount': 5,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/As62Xyu.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237555943,
#   'title': '我說 不要 抱我',
#   'excerpt': '本喵說，不要，抱我，到底要多厭世啦🤣，發個可愛的小影片挽回一下',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T16:44:53.544Z',
#   'updatedAt': '2021-11-28T16:44:53.544Z',
#   'commentCount': 23,
#   'likeCount': 250,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '貓咪真的很可愛', '虎斑貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '鮮奶茶無糖熱的',
#   'department': 'ppyong5920',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6ad28ac6-2dfd-4183-993f-e6c774ef7c15',
#     'url': 'https://i.imgur.com/wiKKrbyl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/wiKKrbyl.jpg',
#     'thumbnail': 'https://i.imgur.com/wiKKrbyl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T16:44:53.544Z',
#     'updatedAt': '2021-11-28T16:44:53.544Z',
#     'width': 828,
#     'height': 1472},
#    {'id': '6ad28ac6-2dfd-4183-993f-e6c774ef7c15',
#     'url': 'https://i.imgur.com/wiKKrby.jpg',
#     'normalizedUrl': 'https://imgur.com/wiKKrby',
#     'thumbnail': 'https://i.imgur.com/wiKKrbyl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:44:53.544Z',
#     'updatedAt': '2021-11-28T16:44:53.544Z',
#     'width': 828,
#     'height': 1472},
#    {'id': '0a7060e9-b118-4bc8-8768-8544fb7597af',
#     'url': 'https://i.imgur.com/LJOoVId.jpg',
#     'normalizedUrl': 'https://imgur.com/LJOoVId',
#     'thumbnail': 'https://i.imgur.com/LJOoVIdl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:44:53.544Z',
#     'updatedAt': '2021-11-28T16:44:53.544Z',
#     'width': 828,
#     'height': 1472},
#    {'id': '8fa96002-4ed9-4aa0-9b9d-9e6bffe8144b',
#     'url': 'https://i.imgur.com/GuOHev9.jpg',
#     'normalizedUrl': 'https://imgur.com/GuOHev9',
#     'thumbnail': 'https://i.imgur.com/GuOHev9l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:44:53.544Z',
#     'updatedAt': '2021-11-28T16:44:53.544Z',
#     'width': 828,
#     'height': 1792},
#    {'id': '44d4d728-87e4-4611-9309-4c2bcf0a7a06',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/8b3b23ec-50de-438b-b9e3-0ff49f31ab38?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/8b3b23ec-50de-438b-b9e3-0ff49f31ab38/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-28T16:44:53.544Z',
#     'updatedAt': '2021-11-28T16:44:53.544Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 236},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 13},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 23,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/wiKKrby.jpg'},
#    {'url': 'https://i.imgur.com/LJOoVId.jpg'},
#    {'url': 'https://i.imgur.com/GuOHev9.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/8b3b23ec-50de-438b-b9e3-0ff49f31ab38/thumbnail.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237554717,
#   'title': '孩子是可以說丟就丟的嗎（文長',
#   'excerpt': '小弟今年養貓10年多了 高二開始養，首先我女兒是個敏感體質 容易生病的浪貓，也許就是因為這樣才被貓媽媽拋棄的吧，高二那年 我撿到了她 我很愛但母親說不行，極力懇求之後 以 誰人養的誰負責的條件答應了，',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T14:16:30.441Z',
#   'updatedAt': '2021-11-28T14:16:30.441Z',
#   'commentCount': 32,
#   'likeCount': 178,
#   'withNickname': True,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['貓', '父母', '孩子', '領養代替購買', '貓咪真的很可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '台南東尼大木',
#   'department': 'mispork',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 142},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 28},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 4},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 2},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 32,
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237555972,
#   'title': '#問問 不要把衣櫃當貓窩啦',
#   'excerpt': '今年北市有新規定！！ 寵物飼養環境不能低於10度~，下禮拜好像氣溫又會更低，我們家胖胖一到冬天就困難重重，放暖爐、貓咪衣服、貓窩都試過了，反正就是一定要進衣櫃裡面就對了，但是他又是掉毛怪，整間衣櫃的衣',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T16:49:59.721Z',
#   'updatedAt': '2021-11-28T16:49:59.721Z',
#   'commentCount': 15,
#   'likeCount': 131,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['問問', '貓', '貓咪真的很可愛', '橘貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立中興大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'a0115fda-a455-4e4d-9597-8613537289bb',
#     'url': 'https://i.imgur.com/OD1z9Qnl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/OD1z9Qnl.jpg',
#     'thumbnail': 'https://i.imgur.com/OD1z9Qnl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T16:49:59.721Z',
#     'updatedAt': '2021-11-28T16:49:59.721Z',
#     'width': 1478,
#     'height': 1108},
#    {'id': 'a0115fda-a455-4e4d-9597-8613537289bb',
#     'url': 'https://i.imgur.com/OD1z9Qn.jpg',
#     'normalizedUrl': 'https://imgur.com/OD1z9Qn',
#     'thumbnail': 'https://i.imgur.com/OD1z9Qnl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:49:59.721Z',
#     'updatedAt': '2021-11-28T16:49:59.721Z',
#     'width': 1478,
#     'height': 1108}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 128},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 15,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/OD1z9Qn.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237553820,
#   'title': '極品🍊找家',
#   'excerpt': '是不是！很可愛！，又非常黏人！溫馴！洗澡不出爪子！，我們放大一點看，炸可愛，▫️去年11月TNR了一隻小橘子，本來以為找到一個溫暖幸福的家，但今天收到主人訊息說因為太忙碌無法照顧 要幫他找新家，所以我幫',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T12:10:33.717Z',
#   'updatedAt': '2021-11-28T13:33:53.781Z',
#   'commentCount': 19,
#   'likeCount': 107,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['認養', '橘貓', '貓', '寵物', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '消壓的媽',
#   'department': 'aasta_lin',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '62a95f1e-9b00-4e23-908e-246711794028',
#     'url': 'https://i.imgur.com/RO6gtmXl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/RO6gtmXl.jpg',
#     'thumbnail': 'https://i.imgur.com/RO6gtmXl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T12:10:33.717Z',
#     'updatedAt': '2021-11-28T13:33:53.781Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '62a95f1e-9b00-4e23-908e-246711794028',
#     'url': 'https://i.imgur.com/RO6gtmX.jpg',
#     'normalizedUrl': 'https://imgur.com/RO6gtmX',
#     'thumbnail': 'https://i.imgur.com/RO6gtmXl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T12:10:33.717Z',
#     'updatedAt': '2021-11-28T13:33:53.781Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'a868a917-0d3b-4023-8afe-6f8e771b2b4f',
#     'url': 'https://i.imgur.com/djutqN5.jpg',
#     'normalizedUrl': 'https://imgur.com/djutqN5',
#     'thumbnail': 'https://i.imgur.com/djutqN5l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T12:10:33.717Z',
#     'updatedAt': '2021-11-28T13:33:53.781Z',
#     'width': 1108,
#     'height': 1477},
#    {'id': '82e1baf1-0e8d-4a71-9011-5f9693dce70c',
#     'url': 'https://i.imgur.com/go4WKFi.jpg',
#     'normalizedUrl': 'https://imgur.com/go4WKFi',
#     'thumbnail': 'https://i.imgur.com/go4WKFil.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T12:10:33.717Z',
#     'updatedAt': '2021-11-28T13:33:53.781Z',
#     'width': 828,
#     'height': 1104},
#    {'id': '47fc5945-c537-4f18-bfaf-7eadce078147',
#     'url': 'https://i.imgur.com/9aKwKW5.jpg',
#     'normalizedUrl': 'https://imgur.com/9aKwKW5',
#     'thumbnail': 'https://i.imgur.com/9aKwKW5l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T12:10:33.717Z',
#     'updatedAt': '2021-11-28T13:33:53.781Z',
#     'width': 828,
#     'height': 1104}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 106},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'enablePrivateMessage': False,
#   'totalCommentCount': 19,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/RO6gtmX.jpg'},
#    {'url': 'https://i.imgur.com/djutqN5.jpg'},
#    {'url': 'https://i.imgur.com/go4WKFi.jpg'},
#    {'url': 'https://i.imgur.com/9aKwKW5.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237553053,
#   'title': '黏人小幼貓找家',
#   'excerpt': '朋友有在幫貓咪TNR，想幫小隻的浪貓找家，橘貓 （男生）2個月 浪貓媽媽生的，賓士 （女生）3個月 中分超可愛，都很親人 也可以摸，如果妳/你們家想增加貓口的都可以詢問哦！，貓嗎在 #新北 #板橋，️認',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T10:02:32.747Z',
#   'updatedAt': '2021-11-28T10:02:32.747Z',
#   'commentCount': 9,
#   'likeCount': 106,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['黏人', '貓', '送養', '領養代替購買', '米克斯'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '實踐大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '5357f8c5-03ea-457f-a5c1-86477ae1fd32',
#     'url': 'https://i.imgur.com/LTHjLnkl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/LTHjLnkl.jpg',
#     'thumbnail': 'https://i.imgur.com/LTHjLnkl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T10:02:32.747Z',
#     'updatedAt': '2021-11-28T10:02:32.747Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '5357f8c5-03ea-457f-a5c1-86477ae1fd32',
#     'url': 'https://i.imgur.com/LTHjLnk.jpg',
#     'normalizedUrl': 'https://imgur.com/LTHjLnk',
#     'thumbnail': 'https://i.imgur.com/LTHjLnkl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T10:02:32.747Z',
#     'updatedAt': '2021-11-28T10:02:32.747Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '3103139d-8b1c-444d-a4de-d1d615379380',
#     'url': 'https://i.imgur.com/dWO1q18.jpg',
#     'normalizedUrl': 'https://imgur.com/dWO1q18',
#     'thumbnail': 'https://i.imgur.com/dWO1q18l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T10:02:32.747Z',
#     'updatedAt': '2021-11-28T10:02:32.747Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '9b490847-cf07-4514-a290-e4f0c2589780',
#     'url': 'https://i.imgur.com/ynlT7Qy.jpg',
#     'normalizedUrl': 'https://imgur.com/ynlT7Qy',
#     'thumbnail': 'https://i.imgur.com/ynlT7Qyl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T10:02:32.747Z',
#     'updatedAt': '2021-11-28T10:02:32.747Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '7c79230f-056e-4282-b196-a64536edc967',
#     'url': 'https://i.imgur.com/dv052c5.jpg',
#     'normalizedUrl': 'https://imgur.com/dv052c5',
#     'thumbnail': 'https://i.imgur.com/dv052c5l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T10:02:32.747Z',
#     'updatedAt': '2021-11-28T10:02:32.747Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '503b9dcd-0dcb-45ce-b4b5-4de176ffdc5c',
#     'url': 'https://i.imgur.com/ELqWLJE.jpg',
#     'normalizedUrl': 'https://imgur.com/ELqWLJE',
#     'thumbnail': 'https://i.imgur.com/ELqWLJEl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T10:02:32.747Z',
#     'updatedAt': '2021-11-28T10:02:32.747Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 105},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 9,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/LTHjLnk.jpg'},
#    {'url': 'https://i.imgur.com/dWO1q18.jpg'},
#    {'url': 'https://i.imgur.com/ynlT7Qy.jpg'},
#    {'url': 'https://i.imgur.com/dv052c5.jpg'},
#    {'url': 'https://i.imgur.com/ELqWLJE.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237555968,
#   'title': '被放電了(⁎⁍̴̛ᴗ⁍̴̛⁎)',
#   'excerpt': '剛剛躺在沙發上看影片，一個轉頭看到這隻可愛的喵喵在對我放電啊，差點被電暈，平常超ㄎㄧㄤ的，睡覺姿勢很奇怪的喵喵，這算是豪邁的大叔睡姿？他真的好萌️',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T16:49:29.008Z',
#   'updatedAt': '2021-11-28T16:49:29.008Z',
#   'commentCount': 3,
#   'likeCount': 103,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '薯條守衛隊(๑˃̵ᴗ˂̵)و',
#   'department': 'coco_ppu',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '609184c1-be0a-4481-a73b-62e0233f61f0',
#     'url': 'https://i.imgur.com/ezxm8I1l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/ezxm8I1l.jpg',
#     'thumbnail': 'https://i.imgur.com/ezxm8I1l.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T16:49:29.008Z',
#     'updatedAt': '2021-11-28T16:49:29.008Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '609184c1-be0a-4481-a73b-62e0233f61f0',
#     'url': 'https://i.imgur.com/ezxm8I1.jpg',
#     'normalizedUrl': 'https://imgur.com/ezxm8I1',
#     'thumbnail': 'https://i.imgur.com/ezxm8I1l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:49:29.008Z',
#     'updatedAt': '2021-11-28T16:49:29.008Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': 'fe9a30f0-7c69-4d73-835a-6a7781c1c931',
#     'url': 'https://i.imgur.com/YS3iioV.jpg',
#     'normalizedUrl': 'https://imgur.com/YS3iioV',
#     'thumbnail': 'https://i.imgur.com/YS3iioVl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:49:29.008Z',
#     'updatedAt': '2021-11-28T16:49:29.008Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': 'b6c25649-ada4-413b-b247-055a49f32b43',
#     'url': 'https://i.imgur.com/4MIQDWz.jpg',
#     'normalizedUrl': 'https://imgur.com/4MIQDWz',
#     'thumbnail': 'https://i.imgur.com/4MIQDWzl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:49:29.008Z',
#     'updatedAt': '2021-11-28T16:49:29.008Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '91fc79b6-3c3a-4465-bec6-9ae7699a8dad',
#     'url': 'https://i.imgur.com/ijmBWgk.jpg',
#     'normalizedUrl': 'https://imgur.com/ijmBWgk',
#     'thumbnail': 'https://i.imgur.com/ijmBWgkl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T16:49:29.008Z',
#     'updatedAt': '2021-11-28T16:49:29.008Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 101},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 3,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/ezxm8I1.jpg'},
#    {'url': 'https://i.imgur.com/YS3iioV.jpg'},
#    {'url': 'https://i.imgur.com/4MIQDWz.jpg'},
#    {'url': 'https://i.imgur.com/ijmBWgk.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237552394,
#   'title': '娃娃真的縮小了啦 趴兔',
#   'excerpt': '繼上次的娃娃縮小 這次我更確定一定是娃娃縮小了！，先給你們看現在帥氣的我跟小藍，準備好了嗎，給你們看看娃娃變小的證據，就說吧 一切都是娃娃的錯吧，喜歡我們的話歡迎來看看我們呦',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T08:02:20.371Z',
#   'updatedAt': '2021-11-28T08:02:20.371Z',
#   'commentCount': 1,
#   'likeCount': 62,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['娃娃', '黑貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '我們是酷弟',
#   'department': 'kulo.button',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '5525a692-9719-4eb0-8f38-7a09a0054f36',
#     'url': 'https://i.imgur.com/sM8G4Tbl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/sM8G4Tbl.jpg',
#     'thumbnail': 'https://i.imgur.com/sM8G4Tbl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T08:02:20.371Z',
#     'updatedAt': '2021-11-28T08:02:20.371Z',
#     'width': 2000,
#     'height': 1999},
#    {'id': '5525a692-9719-4eb0-8f38-7a09a0054f36',
#     'url': 'https://i.imgur.com/sM8G4Tb.jpg',
#     'normalizedUrl': 'https://imgur.com/sM8G4Tb',
#     'thumbnail': 'https://i.imgur.com/sM8G4Tbl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T08:02:20.371Z',
#     'updatedAt': '2021-11-28T08:02:20.371Z',
#     'width': 2000,
#     'height': 1999},
#    {'id': '01fa697a-32b1-4045-bd54-a9bc9b833620',
#     'url': 'https://i.imgur.com/2dC9WyS.jpg',
#     'normalizedUrl': 'https://imgur.com/2dC9WyS',
#     'thumbnail': 'https://i.imgur.com/2dC9WySl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T08:02:20.371Z',
#     'updatedAt': '2021-11-28T08:02:20.371Z',
#     'width': 986,
#     'height': 986}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 62}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 1,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/sM8G4Tb.jpg'},
#    {'url': 'https://i.imgur.com/2dC9WyS.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': 'https://megapx-assets.dcard.tw/images/dde3b52c-460c-49a8-a6da-28a6d9a73f03/full.jpeg',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237559491,
#   'title': '因為憂鬱症而得到的貓貓',
#   'excerpt': '第一次發文 如有發錯版 請見諒，文長注意️，———————————————————————，國二的時候，因為憂鬱症的關係，我的媽媽很擔心我的狀況，所以希望轉移我的注意力，於是他決定送一隻貓貓給我養，於是',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-29T08:07:54.065Z',
#   'updatedAt': '2021-11-29T08:07:54.065Z',
#   'commentCount': 2,
#   'likeCount': 44,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '寵物', '曼赤肯', '橘貓', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '耕莘健康管理專科學校',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'b3364c69-a119-4c03-94c2-85ab798fa351',
#     'url': 'https://vivid.dcard.tw/Public/38426f09-2f26-4c81-9489-bb480d11023a/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/38426f09-2f26-4c81-9489-bb480d11023a/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/38426f09-2f26-4c81-9489-bb480d11023a/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-29T08:07:54.065Z',
#     'updatedAt': '2021-11-29T08:07:54.065Z'},
#    {'id': 'b3364c69-a119-4c03-94c2-85ab798fa351',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/38426f09-2f26-4c81-9489-bb480d11023a?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/38426f09-2f26-4c81-9489-bb480d11023a/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-29T08:07:54.065Z',
#     'updatedAt': '2021-11-29T08:07:54.065Z'},
#    {'id': '40bfd20b-ba0d-4c98-aaae-464db2f9e7fd',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/da693971-3368-462b-bdfd-91ecebf4bf81?r=0.5625',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/da693971-3368-462b-bdfd-91ecebf4bf81/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-29T08:07:54.065Z',
#     'updatedAt': '2021-11-29T08:07:54.065Z'},
#    {'id': 'ea521187-ce8d-4728-babc-031841b46d2e',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/d5c7d905-6135-4e00-9b09-ba58e4f054d8?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/d5c7d905-6135-4e00-9b09-ba58e4f054d8/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-29T08:07:54.065Z',
#     'updatedAt': '2021-11-29T08:07:54.065Z'},
#    {'id': 'd2db5568-4ed0-4da9-bc7b-64dc89ceedd6',
#     'url': 'https://i.imgur.com/8y34GRo.jpg',
#     'normalizedUrl': 'https://imgur.com/8y34GRo',
#     'thumbnail': 'https://i.imgur.com/8y34GRol.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T08:07:54.065Z',
#     'updatedAt': '2021-11-29T08:07:54.065Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '3fd649d7-8950-4c24-883f-04c6e91798d3',
#     'url': 'https://i.imgur.com/cWuNNHx.jpg',
#     'normalizedUrl': 'https://imgur.com/cWuNNHx',
#     'thumbnail': 'https://i.imgur.com/cWuNNHxl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T08:07:54.065Z',
#     'updatedAt': '2021-11-29T08:07:54.065Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '69606359-45b1-4991-a2e4-e4c9ebb47d36',
#     'url': 'https://i.imgur.com/VVFy96k.jpg',
#     'normalizedUrl': 'https://imgur.com/VVFy96k',
#     'thumbnail': 'https://i.imgur.com/VVFy96kl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T08:07:54.065Z',
#     'updatedAt': '2021-11-29T08:07:54.065Z',
#     'width': 1108,
#     'height': 1478}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 44}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 2,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/38426f09-2f26-4c81-9489-bb480d11023a/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/da693971-3368-462b-bdfd-91ecebf4bf81/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/d5c7d905-6135-4e00-9b09-ba58e4f054d8/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/8y34GRo.jpg'},
#    {'url': 'https://i.imgur.com/cWuNNHx.jpg'},
#    {'url': 'https://i.imgur.com/VVFy96k.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237559220,
#   'title': '你知道有人在幫你剪指甲嗎？',
#   'excerpt': '佛系貓貓，請看完整影片，喔對我們都用人類的指甲剪沒錯～～看他也不抗拒應該是沒問題🤣',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-29T07:24:22.585Z',
#   'updatedAt': '2021-11-29T07:24:54.755Z',
#   'commentCount': 8,
#   'likeCount': 44,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['剪指甲', '貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '威士忌是一隻貓',
#   'department': 's777',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'd508583f-7f29-4707-b74f-c2883b21368e',
#     'url': 'https://i.imgur.com/UZmBaq4l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/UZmBaq4l.jpg',
#     'thumbnail': 'https://i.imgur.com/UZmBaq4l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-29T07:24:22.585Z',
#     'updatedAt': '2021-11-29T07:24:54.755Z',
#     'width': 1125,
#     'height': 1012},
#    {'id': 'd508583f-7f29-4707-b74f-c2883b21368e',
#     'url': 'https://i.imgur.com/UZmBaq4.jpg',
#     'normalizedUrl': 'https://imgur.com/UZmBaq4',
#     'thumbnail': 'https://i.imgur.com/UZmBaq4l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-29T07:24:22.585Z',
#     'updatedAt': '2021-11-29T07:24:54.755Z',
#     'width': 1125,
#     'height': 1012},
#    {'id': '6ce0b66b-e5e4-49c9-9219-0f5ce5de6f54',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/109419a5-2d72-4f54-a5be-8df3cf6d8321?r=0.9047619047619048',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/109419a5-2d72-4f54-a5be-8df3cf6d8321/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2021-11-29T07:24:22.585Z',
#     'updatedAt': '2021-11-29T07:24:54.755Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 44}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'enablePrivateMessage': False,
#   'totalCommentCount': 8,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/UZmBaq4.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/109419a5-2d72-4f54-a5be-8df3cf6d8321/thumbnail.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237558698,
#   'title': '如何幫助自閉貓交朋友',
#   'excerpt': '',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-29T05:59:50.613Z',
#   'updatedAt': '2021-11-29T05:59:50.613Z',
#   'commentCount': 2,
#   'likeCount': 41,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '寵物', '貓咪'],
#   'meta': {'layout': 'video'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '國立清華大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6ca7473e-b4f3-4a3b-be21-49c36851f94c',
#     'url': 'https://megapx-assets.dcard.tw/videos/fdb1720b-b4d7-4c27-8774-ec08401f60cb/thumb_180.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/videos/fdb1720b-b4d7-4c27-8774-ec08401f60cb/thumb_180.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/videos/fdb1720b-b4d7-4c27-8774-ec08401f60cb/thumb_180.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-29T05:59:50.613Z',
#     'updatedAt': '2021-11-29T05:59:50.613Z',
#     'width': 180,
#     'height': 244,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 216,
#      'width': 1080,
#      'height': 648}},
#    {'id': '6ca7473e-b4f3-4a3b-be21-49c36851f94c',
#     'url': 'https://megapx-assets.dcard.tw/videos/fdb1720b-b4d7-4c27-8774-ec08401f60cb/orig',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/videos/fdb1720b-b4d7-4c27-8774-ec08401f60cb',
# ...
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/fcSKXK4.jpg'},
#    {'url': 'https://i.imgur.com/iBReQih.jpg'},
#    {'url': 'https://i.imgur.com/Lxobj3v.jpg'},
#    {'url': 'https://i.imgur.com/R6rEIze.jpg'},
#    {'url': 'https://i.imgur.com/ycFJr3Y.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237553600,
#   'title': '老倉鼠身上長了腫瘤',
#   'excerpt': '這隻銀狐已經養了2年5個月，到現在還會跑滾輪，食物弄給他吃都還是嗑的很開心，但最近開始一整天幾乎都在睡覺，剛好他睡到四腳朝天才發現胸部那邊長了一顆腫瘤，（平常摸他或是抓在手裡不會讓他露肚子，因為他不喜',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T11:37:02.919Z',
#   'updatedAt': '2021-11-28T11:37:02.919Z',
#   'commentCount': 12,
#   'likeCount': 19,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['倉鼠', '腫瘤', '寵物'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立高雄應用科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'e401b780-31e4-472f-b749-ca63d2f82b19',
#     'url': 'https://i.imgur.com/Eejo2mLl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/Eejo2mLl.jpg',
#     'thumbnail': 'https://i.imgur.com/Eejo2mLl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-28T11:37:02.919Z',
#     'updatedAt': '2021-11-28T11:37:02.919Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'e401b780-31e4-472f-b749-ca63d2f82b19',
#     'url': 'https://i.imgur.com/Eejo2mL.jpg',
#     'normalizedUrl': 'https://imgur.com/Eejo2mL',
#     'thumbnail': 'https://i.imgur.com/Eejo2mLl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-28T11:37:02.919Z',
#     'updatedAt': '2021-11-28T11:37:02.919Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 16},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 12,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/Eejo2mL.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237557259,
#   'title': '黃金鼠有腮紅😍',
#   'excerpt': '前天幫我家小黃金整理家，拿去清洗乾淨後整理到一半，小黃金自己在旁邊玩，塞了好幾顆堅果再嘴巴裡，（平常都會固定幫他清理臉頰藏的食物），看著他那麼貪吃越塞越多，腮紅就出現了，我整個超興奮覺得超可愛吖！！，',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-29T01:41:28.033Z',
#   'updatedAt': '2021-11-29T01:41:28.033Z',
#   'commentCount': 3,
#   'likeCount': 17,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['倉鼠'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '中國科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'b65e0549-8d22-4bfd-8626-504e21c6ec88',
#     'url': 'https://vivid.dcard.tw/Public/ac5e992b-23ef-497b-8f7c-c4501dd0fdf2/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/ac5e992b-23ef-497b-8f7c-c4501dd0fdf2/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/ac5e992b-23ef-497b-8f7c-c4501dd0fdf2/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2021-11-29T01:41:28.033Z',
#     'updatedAt': '2021-11-29T01:41:28.033Z'},
#    {'id': 'b65e0549-8d22-4bfd-8626-504e21c6ec88',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/ac5e992b-23ef-497b-8f7c-c4501dd0fdf2?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/ac5e992b-23ef-497b-8f7c-c4501dd0fdf2/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-29T01:41:28.033Z',
#     'updatedAt': '2021-11-29T01:41:28.033Z'},
#    {'id': '1cc09e03-3d96-4248-a06f-c7a247a388a5',
#     'url': 'https://i.imgur.com/OjAEmxn.jpg',
#     'normalizedUrl': 'https://imgur.com/OjAEmxn',
#     'thumbnail': 'https://i.imgur.com/OjAEmxnl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T01:41:28.033Z',
#     'updatedAt': '2021-11-29T01:41:28.033Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '2031c2e9-b39f-4cef-b33a-2fafef4f97b3',
#     'url': 'https://i.imgur.com/XcrWmAs.jpg',
#     'normalizedUrl': 'https://imgur.com/XcrWmAs',
#     'thumbnail': 'https://i.imgur.com/XcrWmAsl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T01:41:28.033Z',
#     'updatedAt': '2021-11-29T01:41:28.033Z',
#     'width': 1118,
#     'height': 2000},
#    {'id': 'a85400bd-542a-41b0-aaea-d34f982b7374',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/eca41dcb-1c79-4d3e-a77e-e0a291fe6554?r=0.8777777777777778',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/eca41dcb-1c79-4d3e-a77e-e0a291fe6554/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2021-11-29T01:41:28.033Z',
#     'updatedAt': '2021-11-29T01:41:28.033Z'},
#    {'id': '6efc213c-4323-4a5f-9902-219c18be61c8',
#     'url': 'https://i.imgur.com/NETqx9N.jpg',
#     'normalizedUrl': 'https://imgur.com/NETqx9N',
#     'thumbnail': 'https://i.imgur.com/NETqx9Nl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T01:41:28.033Z',
#     'updatedAt': '2021-11-29T01:41:28.033Z',
#     'width': 1169,
#     'height': 1016},
#    {'id': 'e7238ab5-bed5-47bd-8cc7-d41eb92a9fe3',
#     'url': 'https://i.imgur.com/34sR4GS.jpg',
#     'normalizedUrl': 'https://imgur.com/34sR4GS',
#     'thumbnail': 'https://i.imgur.com/34sR4GSl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2021-11-29T01:41:28.033Z',
#     'updatedAt': '2021-11-29T01:41:28.033Z',
#     'width': 1835,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 17}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 3,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/ac5e992b-23ef-497b-8f7c-c4501dd0fdf2/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/OjAEmxn.jpg'},
#    {'url': 'https://i.imgur.com/XcrWmAs.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/eca41dcb-1c79-4d3e-a77e-e0a291fe6554/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/NETqx9N.jpg'},
#    {'url': 'https://i.imgur.com/34sR4GS.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237554514,
#   'title': '如何料理幼貓仔？清蒸or紅燒？',
#   'excerpt': '瞧那得意的表情，家裡年紀最小的小公主，最常咬自己的兩個哥哥，還咬壞網路數據機的線，咬壞自己小背心的蝴蝶結，剛剛咬壞哀鳳線，咬壞之後就跑去躲起來，被捉出來就給我無辜臉🥺想裝傻，妳兩個哥哥才不會亂咬線',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T13:48:24.748Z',
#   'updatedAt': '2021-11-28T14:10:11.590Z',
#   'commentCount': 3,
#   'likeCount': 17,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓咪真的很可愛', '氣死', '三寶', '寵物', '貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '娜拉',
#   'department': 'joanala',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'cc101914-4d19-4a4c-8733-c30768e4b969',
#     'url': 'https://i.imgur.com/kFdBq4Wl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/kFdBq4Wl.jpg',
#     'thumbnail': 'https://i.imgur.com/kFdBq4Wl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T13:48:24.748Z',
#     'updatedAt': '2021-11-28T14:10:11.590Z',
#     'width': 1125,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 225,
#      'width': 1125,
#      'height': 675}},
#    {'id': 'cc101914-4d19-4a4c-8733-c30768e4b969',
#     'url': 'https://i.imgur.com/kFdBq4W.jpg',
#     'normalizedUrl': 'https://imgur.com/kFdBq4W',
#     'thumbnail': 'https://i.imgur.com/kFdBq4Wl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T13:48:24.748Z',
#     'updatedAt': '2021-11-28T14:10:11.590Z',
#     'width': 1125,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 225,
#      'width': 1125,
#      'height': 675}},
#    {'id': '6c702556-659b-44b7-8228-e93450409bb4',
#     'url': 'https://i.imgur.com/U6Yr4Ub.jpg',
#     'normalizedUrl': 'https://imgur.com/U6Yr4Ub',
#     'thumbnail': 'https://i.imgur.com/U6Yr4Ubl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T13:48:24.748Z',
#     'updatedAt': '2021-11-28T14:10:11.590Z',
#     'width': 1125,
#     'height': 2000},
#    {'id': 'e920f114-c124-4619-8ea3-b203f9e67e0b',
#     'url': 'https://i.imgur.com/w0inahC.jpg',
#     'normalizedUrl': 'https://imgur.com/w0inahC',
#     'thumbnail': 'https://i.imgur.com/w0inahCl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-28T13:48:24.748Z',
#     'updatedAt': '2021-11-28T14:10:11.590Z',
#     'width': 2000,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 16},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 3,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/kFdBq4W.jpg'},
#    {'url': 'https://i.imgur.com/U6Yr4Ub.jpg'},
#    {'url': 'https://i.imgur.com/w0inahC.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237552289,
#   'title': '台中虐貓男的鄰居',
#   'excerpt': '引用原文：「我已經盡我所能，跟警察聯絡作證。也和動保團體接洽，還有通知議員，但是新聞熱度仍然消退中甚至，那個變態偵訊結束後還被放回來，口口聲聲他多愛那隻被他活活打死的乳牛貓，拜託大家幫幫我，不要讓他再',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-28T07:47:39.864Z',
#   'updatedAt': '2021-11-28T07:47:39.864Z',
#   'commentCount': 10,
#   'likeCount': 14,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['虐貓', '貓', '寵物', '狗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '元智大學',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 10},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 2},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 10,
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237556998,
#   'title': '‼️拜託幫忙 求寵物溝通 鸚鵡飛失',
#   'excerpt': '已經很難過了 拜託不相信寵物溝通的人不要留言，沒有心力再去看那些刺耳的話，目前尋求過三個 有兩個說法類似（地點 畫面等），但因為鸚鵡晚上才不會動..真的很暗很難找，有沒有誰有推薦的 或是曾經找回來的，',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-29T00:04:43.508Z',
#   'updatedAt': '2021-11-29T00:56:59.733Z',
#   'commentCount': 4,
#   'likeCount': 11,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['溝通', '鸚鵡', '請益', '協尋', '鳥'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '中國文化大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '7ffa3dec-f2bb-432c-b5e4-7f33d7e8551f',
#     'url': 'https://i.imgur.com/yMhq9w3l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/yMhq9w3l.jpg',
#     'thumbnail': 'https://i.imgur.com/yMhq9w3l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-29T00:04:43.508Z',
#     'updatedAt': '2021-11-29T00:56:59.733Z',
#     'width': 1169,
#     'height': 1518},
#    {'id': '7ffa3dec-f2bb-432c-b5e4-7f33d7e8551f',
#     'url': 'https://i.imgur.com/yMhq9w3.jpg',
#     'normalizedUrl': 'https://imgur.com/yMhq9w3',
#     'thumbnail': 'https://i.imgur.com/yMhq9w3l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-29T00:04:43.508Z',
#     'updatedAt': '2021-11-29T00:56:59.733Z',
#     'width': 1169,
#     'height': 1518}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 11}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'enablePrivateMessage': False,
#   'totalCommentCount': 4,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/yMhq9w3.jpg'}],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''},
#  {'id': 237558598,
#   'title': '這就是為什麼哈士奇叫二哈',
#   'excerpt': '',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-11-29T05:44:03.857Z',
#   'updatedAt': '2021-11-29T05:44:03.857Z',
#   'commentCount': 2,
#   'likeCount': 10,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '狗', '哈士奇', '二哈'],
#   'meta': {'layout': 'video'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '輔仁大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '58f6548c-87dc-44dd-8597-e4f43bd087d9',
#     'url': 'https://megapx-assets.dcard.tw/videos/4a60d845-1eca-448b-84a8-9ea31988c30e/thumb_180.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/videos/4a60d845-1eca-448b-84a8-9ea31988c30e/thumb_180.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/videos/4a60d845-1eca-448b-84a8-9ea31988c30e/thumb_180.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-29T05:44:03.857Z',
#     'updatedAt': '2021-11-29T05:44:03.857Z',
#     'width': 180,
#     'height': 314,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 150,
#      'width': 750,
#      'height': 450}},
#    {'id': '58f6548c-87dc-44dd-8597-e4f43bd087d9',
#     'url': 'https://megapx-assets.dcard.tw/videos/4a60d845-1eca-448b-84a8-9ea31988c30e/orig',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/videos/4a60d845-1eca-448b-84a8-9ea31988c30e',
#     'thumbnail': 'https://megapx-assets.dcard.tw/videos/4a60d845-1eca-448b-84a8-9ea31988c30e/thumb_180.jpeg',
#     'type': 'video/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2021-11-29T05:44:03.857Z',
#     'updatedAt': '2021-11-29T05:44:03.857Z',
#     'width': 750,
#     'height': 1308,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 150,
#      'width': 750,
#      'height': 450}}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 8},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'video',
#   'spoilerAlert': False,
#   'isSelectedPost': False,
#   'totalCommentCount': 2,
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'supportedReactions': None,
#   'excerptComments': [],
#   'edited': False,
#   'postAvatar': '',
#   'activityAvatar': '',
#   'verifiedBadge': False,
#   'memberType': ''}]

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？


print('API 一次會回傳的資料筆數: ', len(API_json),'筆')
print()

column_name_list = [column_name  for column_name in API_json[0].keys()]
print('每一筆資料包含的欄位名稱: ', str(column_name_list).replace('[',"").replace(']',""))
# Out:
# API 一次會回傳的資料筆數:  30 筆
#
# 每一筆資料包含的欄位名稱:  'id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'isModerator', 'layout', 'spoilerAlert', 'isSelectedPost', 'totalCommentCount', 'withImages', 'withVideos', 'media', 'reportReasonText', 'supportedReactions', 'excerptComments', 'edited', 'postAvatar', 'activityAvatar', 'verifiedBadge', 'memberType'

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

for row in range(0,30):
    if row < 29: 
        print("標題: ", API_json[row]['title'])
        print("貼文時間: ", API_json[row]['createdAt'])
        print("留言人數: ", API_json[row]['commentCount'])
        print("按讚人數: ", API_json[row]['likeCount'])
        print('-'*20)
    else:
        print("標題: ", API_json[row]['title'])
        print("貼文時間: ", API_json[row]['createdAt'])
        print("留言人數: ", API_json[row]['commentCount'])
        print("按讚人數: ", API_json[row]['likeCount'])
# Out:
# 標題:  討厭貓的媽媽 一年的變化
# 貼文時間:  2021-11-29T04:16:52.111Z
# 留言人數:  58
# 按讚人數:  1586
# --------------------
# 標題:  台灣貓
# 貼文時間:  2021-11-28T12:33:46.612Z
# 留言人數:  29
# 按讚人數:  556
# --------------------
# 標題:  台中兩隻貓貓送養♥
# 貼文時間:  2021-11-28T03:32:01.333Z
# 留言人數:  17
# 按讚人數:  348
# --------------------
# 標題:  長期鍊繩的貓
# 貼文時間:  2021-11-28T13:01:08.830Z
# 留言人數:  82
# 按讚人數:  279
# --------------------
# 標題:  好想知道她夢到什麼
# 貼文時間:  2021-11-28T07:18:18.069Z
# 留言人數:  5
# 按讚人數:  273
# --------------------
# 標題:  我說 不要 抱我
# 貼文時間:  2021-11-28T16:44:53.544Z
# 留言人數:  23
# 按讚人數:  250
# --------------------
# 標題:  孩子是可以說丟就丟的嗎（文長
# 貼文時間:  2021-11-28T14:16:30.441Z
# 留言人數:  32
# 按讚人數:  178
# --------------------
# 標題:  #問問 不要把衣櫃當貓窩啦
# 貼文時間:  2021-11-28T16:49:59.721Z
# 留言人數:  15
# 按讚人數:  131
# --------------------
# 標題:  極品🍊找家
# 貼文時間:  2021-11-28T12:10:33.717Z
# 留言人數:  19
# 按讚人數:  107
# --------------------
# 標題:  黏人小幼貓找家
# 貼文時間:  2021-11-28T10:02:32.747Z
# 留言人數:  9
# 按讚人數:  106
# --------------------
# 標題:  被放電了(⁎⁍̴̛ᴗ⁍̴̛⁎)
# 貼文時間:  2021-11-28T16:49:29.008Z
# 留言人數:  3
# 按讚人數:  103
# --------------------
# 標題:  娃娃真的縮小了啦 趴兔
# 貼文時間:  2021-11-28T08:02:20.371Z
# 留言人數:  1
# 按讚人數:  62
# --------------------
# 標題:  因為憂鬱症而得到的貓貓
# 貼文時間:  2021-11-29T08:07:54.065Z
# 留言人數:  2
# 按讚人數:  44
# --------------------
# 標題:  你知道有人在幫你剪指甲嗎？
# 貼文時間:  2021-11-29T07:24:22.585Z
# 留言人數:  8
# 按讚人數:  44
# --------------------
# 標題:  如何幫助自閉貓交朋友
# 貼文時間:  2021-11-29T05:59:50.613Z
# 留言人數:  2
# 按讚人數:  41
# --------------------
# 標題:  急！貓貓卡在上面怎麼辦！
# 貼文時間:  2021-11-28T11:36:49.330Z
# 留言人數:  17
# 按讚人數:  37
# --------------------
# 標題:  被發現在吃魚
# 貼文時間:  2021-11-28T10:34:05.893Z
# 留言人數:  2
# 按讚人數:  37
# --------------------
# 標題:  貓咪一直拉肚子💩
# 貼文時間:  2021-11-28T16:55:56.360Z
# 留言人數:  13
# 按讚人數:  32
# --------------------
# 標題:  #台中 貓咪送養 虎斑&黑貓
# 貼文時間:  2021-11-29T05:33:28.071Z
# 留言人數:  12
# 按讚人數:  29
# --------------------
# 標題:  剛領養回來的貓咪一直咬手手
# 貼文時間:  2021-11-29T05:18:53.849Z
# 留言人數:  19
# 按讚人數:  28
# --------------------
# 標題:  還有這招
# 貼文時間:  2021-11-29T05:58:25.677Z
# 留言人數:  0
# 按讚人數:  24
# --------------------
# 標題:  雙11幫貓貓敗的貓牆
# 貼文時間:  2021-11-29T03:56:05.962Z
# 留言人數:  0
# 按讚人數:  24
# --------------------
# 標題:  胡麻柴犬之完美接球
# 貼文時間:  2021-11-28T06:14:32.594Z
# 留言人數:  1
# 按讚人數:  21
# --------------------
# 標題:  狗狗指甲太長要剪嗎？關於指甲的二三事
# 貼文時間:  2021-11-28T08:54:33.989Z
# 留言人數:  0
# 按讚人數:  20
# --------------------
# 標題:  老倉鼠身上長了腫瘤
# 貼文時間:  2021-11-28T11:37:02.919Z
# 留言人數:  12
# 按讚人數:  19
# --------------------
# 標題:  黃金鼠有腮紅😍
# 貼文時間:  2021-11-29T01:41:28.033Z
# 留言人數:  3
# 按讚人數:  17
# --------------------
# 標題:  如何料理幼貓仔？清蒸or紅燒？
# 貼文時間:  2021-11-28T13:48:24.748Z
# 留言人數:  3
# 按讚人數:  17
# --------------------
# 標題:  台中虐貓男的鄰居
# 貼文時間:  2021-11-28T07:47:39.864Z
# 留言人數:  10
# 按讚人數:  14
# --------------------
# 標題:  ‼️拜託幫忙 求寵物溝通 鸚鵡飛失
# 貼文時間:  2021-11-29T00:04:43.508Z
# 留言人數:  4
# 按讚人數:  11
# --------------------
# 標題:  這就是為什麼哈士奇叫二哈
# 貼文時間:  2021-11-29T05:44:03.857Z
# 留言人數:  2
# 按讚人數:  10

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# 熱門API
API_text_popular = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=true")
API_json_popular = json.loads(API_text_popular.text)

total_article = len(API_json_popular)

commentCount_popular_sum = 0
for row in API_json_popular:
    commentCount_popular_sum += row['commentCount']

commentCount_avg = commentCount_popular_sum/total_article
print('熱門文章平均留言人數: ', commentCount_avg)


likeCount_popular_sum = 0
for row in API_json_popular:
    likeCount_popular_sum += row['likeCount']

likeCount_popular_avg = likeCount_popular_sum/total_article
print('熱門文章平均按讚人數: ', likeCount_popular_avg)
print('-'*30)


# 非熱門API
API_text_unpopular = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=false")
API_json_unpopular = json.loads(API_text_unpopular.text)


commentCount_unpopular_sum = 0
for row in API_json_unpopular:
    commentCount_unpopular_sum += row['commentCount']

commentCount_unpopular_avg = commentCount_unpopular_sum/total_article
print('熱門文章平均留言人數: ', commentCount_unpopular_avg)


likeCount_unpopular_sum = 0
for row in API_json_unpopular:
    likeCount_unpopular_sum += row['likeCount']

commentCount_unpopular_avg = likeCount_unpopular_sum/total_article
print('熱門文章平均按讚人數: ', commentCount_unpopular_avg)
# Out:
# 熱門文章平均留言人數:  14.2
# 熱門文章平均按讚人數:  155.06666666666666
# ------------------------------
# 熱門文章平均留言人數:  3.3333333333333335
# 熱門文章平均按讚人數:  11.866666666666667
