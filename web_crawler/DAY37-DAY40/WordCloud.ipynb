# %% [markdown]
# ## 安裝套件

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests) (2021.5.30)

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 1.3 MB/s eta 0:00:01
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=002eb840ac6b832f44d5474f16385eaa74a337aae6e2f693000db38a4658313a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/65/7a/a7/78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.8 sgmllib3k-1.0.0

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.6.3-cp39-cp39-manylinux2014_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 1.5 MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.6.3

# %%
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in /opt/conda/lib/python3.9/site-packages (0.42.1)

# %% [markdown]
# ### 下載繁體字的辭典檔

# %%
# !wget https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big -O jieba_data/dict.txt.big
# Out:
# --2021-08-06 18:02:13--  https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big [following]
# --2021-08-06 18:02:13--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [text/plain]
# Saving to: ‘jieba_data/dict.txt.big’
#
# jieba_data/dict.txt 100%[===================>]   8.18M  7.55MB/s    in 1.1s
#
# 2021-08-06 18:02:15 (7.55 MB/s) - ‘jieba_data/dict.txt.big’ saved [8583143/8583143]

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp39-cp39-manylinux1_x86_64.whl (363 kB)
#      |████████████████████████████████| 363 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from wordcloud) (3.4.2)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.9/site-packages (from wordcloud) (1.21.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.9/site-packages (from wordcloud) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1

# %% [markdown]
# ## 解析 RSS

# %%
import feedparser

# %%
rss_url = "https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money"

# %%
newsFeed = feedparser.parse(rss_url) #解析rss
#newsFeed
# Out:
# {'bozo': True,
#  'entries': [{'title': '美36個團體致信拜登 呼籲與大陸重啟談判',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美36個團體致信拜登 呼籲與大陸重啟談判'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5654887'}],
#    'link': 'https://money.udn.com/money/story/10511/5654887',
#    'published': 'Fri, 06 Aug 2021 12:10:46 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=6, tm_hour=4, tm_min=10, tm_sec=46, tm_wday=4, tm_yday=218, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/06/realtime/13220753.png&amp;s=Y&amp;x=0&amp;y=0&amp;sw=593&amp;sh=392&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國零售商、晶片製造商、農民和其它近36個具有影響力的商業團體，於當地時間8月5日致信貿易代表戴琪和財政部長葉倫，呼籲拜...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/06/realtime/13220753.png&amp;s=Y&amp;x=0&amp;y=0&amp;sw=593&amp;sh=392&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國零售商、晶片製造商、農民和其它近36個具有影響力的商業團體，於當地時間8月5日致信貿易代表戴琪和財政部長葉倫，呼籲拜...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5654887',
#    'guidislink': False},
#   {'title': '辣個男人回來了！再戰2024先發行「川普卡」給川粉',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '辣個男人回來了！再戰2024先發行「川普卡」給川粉'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5653906'}],
#    'link': 'https://money.udn.com/money/story/10511/5653906',
#    'published': 'Thu, 05 Aug 2021 23:18:19 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=5, tm_hour=15, tm_min=18, tm_sec=19, tm_wday=3, tm_yday=217, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/05/realtime/13207999.jpg&amp;s=Y&amp;x=0&amp;y=7&amp;sw=1000&amp;sh=666&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>去年敗選的川普不甘寂寞，對2024年大選躍躍欲試，也因此超前部署。川普團隊4日致函川粉，要求他們加入攜帶紅底金字「川普卡...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/05/realtime/13207999.jpg&amp;s=Y&amp;x=0&amp;y=7&amp;sw=1000&amp;sh=666&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>去年敗選的川普不甘寂寞，對2024年大選躍躍欲試，也因此超前部署。川普團隊4日致函川粉，要求他們加入攜帶紅底金字「川普卡...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5653906',
#    'guidislink': False},
#   {'title': '美中爭霸／專家之眼 台灣本土疫苗公司應該「三合一」',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中爭霸／專家之眼 台灣本土疫苗公司應該「三合一」'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5653493'}],
#    'link': 'https://money.udn.com/money/story/10511/5653493',
#    'published': 'Thu, 05 Aug 2021 19:58:18 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=5, tm_hour=11, tm_min=58, tm_sec=18, tm_wday=3, tm_yday=217, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/05/2/13204333.jpg&amp;s=Y&amp;x=50&amp;y=50&amp;sw=480&amp;sh=320&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>財團法人生物技術開發中心董事長凃醒哲日前接受經濟日報專訪有個超前提議，他認為台灣一定要支持國產疫苗，也因為台灣很小，現在有兩、三家疫苗公司生產一樣的東西，「太多了！」，最好三家整合起來。</p><p></p><p>不過，</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/05/2/13204333.jpg&amp;s=Y&amp;x=50&amp;y=50&amp;sw=480&amp;sh=320&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>財團法人生物技術開發中心董事長凃醒哲日前接受經濟日報專訪有個超前提議，他認為台灣一定要支持國產疫苗，也因為台灣很小，現在有兩、三家疫苗公司生產一樣的東西，「太多了！」，最好三家整合起來。</p><p></p><p>不過，</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5653493',
#    'guidislink': False},
#   {'title': '美中爭霸系列三／美中疫苗戰短兵相接  軍火庫對上兵工廠',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中爭霸系列三／美中疫苗戰短兵相接  軍火庫對上兵工廠'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5652828'}],
#    'link': 'https://money.udn.com/money/story/10511/5652828',
#    'published': 'Thu, 05 Aug 2021 19:20:36 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=5, tm_hour=11, tm_min=20, tm_sec=36, tm_wday=3, tm_yday=217, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/05/2/13199639.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1115&amp;sh=743&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>2021年新冠病毒全面散播，為美中爭霸開出新戰場。美國總統拜登6月10日在英國參加G7峰會時表示，今、明年將無條件捐贈5億支輝瑞BNT新冠疫苗。他形容，就像二戰時，美國是民主的軍火庫，現在的美國，則是</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/05/2/13199639.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1115&amp;sh=743&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>2021年新冠病毒全面散播，為美中爭霸開出新戰場。美國總統拜登6月10日在英國參加G7峰會時表示，今、明年將無條件捐贈5億支輝瑞BNT新冠疫苗。他形容，就像二戰時，美國是民主的軍火庫，現在的美國，則是</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5652828',
#    'guidislink': False},
#   {'title': '經濟尬你講／拜登的「印太戰術」圈得住中國戰狼？4QA解析美中爭霸戰',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '經濟尬你講／拜登的「印太戰術」圈得住中國戰狼？4QA解析美中爭霸戰'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5649813'}],
#    'link': 'https://money.udn.com/money/story/10511/5649813',
#    'published': 'Wed, 04 Aug 2021 14:47:29 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=4, tm_hour=6, tm_min=47, tm_sec=29, tm_wday=2, tm_yday=216, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/04/2/13191873.jpeg&amp;s=Y&amp;x=36&amp;y=24&amp;sw=1011&amp;sh=674&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>經濟日報全新podcast上線囉！想知道更多內幕？</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/04/2/13191873.jpeg&amp;s=Y&amp;x=36&amp;y=24&amp;sw=1011&amp;sh=674&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>經濟日報全新podcast上線囉！想知道更多內幕？</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5649813',
#    'guidislink': False},
#   {'title': '受美中貿易戰刺激 大陸出口產品精密度提升',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '受美中貿易戰刺激 大陸出口產品精密度提升'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5649669'}],
#    'link': 'https://money.udn.com/money/story/10511/5649669',
#    'published': 'Wed, 04 Aug 2021 13:57:34 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=4, tm_hour=5, tm_min=57, tm_sec=34, tm_wday=2, tm_yday=216, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/01/14/realtime/11187602.png&amp;s=Y&amp;x=67&amp;y=0&amp;sw=1137&amp;sh=758&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>依據哈佛大學成長實驗室最新公布的出口產品多元化與科技精密度指數顯示，中國大陸出口產品的科技層級已經在美中貿易戰的催化下，...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/01/14/realtime/11187602.png&amp;s=Y&amp;x=67&amp;y=0&amp;sw=1137&amp;sh=758&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>依據哈佛大學成長實驗室最新公布的出口產品多元化與科技精密度指數顯示，中國大陸出口產品的科技層級已經在美中貿易戰的催化下，...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5649669',
#    'guidislink': False},
#   {'title': '美中爭霸系列／美要求台灣供應鏈「去中」 質疑兩岸貿易額為何增加？',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中爭霸系列／美要求台灣供應鏈「去中」 質疑兩岸貿易額為何增加？'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5647667'}],
#    'link': 'https://money.udn.com/money/story/10511/5647667',
#    'published': 'Wed, 04 Aug 2021 09:53:25 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=4, tm_hour=1, tm_min=53, tm_sec=25, tm_wday=2, tm_yday=216, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/03/2/13189638.jpg&amp;s=Y&amp;x=50&amp;y=50&amp;sw=480&amp;sh=320&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美中科技戰進入新回合，台灣企業歷經貿易戰、科技戰與疫情衝擊，又逢美國要求高科技產品不得有「含中」（大陸生產）成份，夾在美中兩強之間左右為難。據了解，今年7月，台美恢復「台美貿易暨投資架構協定」（TIF</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/03/2/13189638.jpg&amp;s=Y&amp;x=50&amp;y=50&amp;sw=480&amp;sh=320&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美中科技戰進入新回合，台灣企業歷經貿易戰、科技戰與疫情衝擊，又逢美國要求高科技產品不得有「含中」（大陸生產）成份，夾在美中兩強之間左右為難。據了解，今年7月，台美恢復「台美貿易暨投資架構協定」（TIF</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5647667',
#    'guidislink': False},
#   {'title': '星總理促中美化解緊張 認大陸不會單方無端攻擊台灣',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '星總理促中美化解緊張 認大陸不會單方無端攻擊台灣'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5648767'}],
#    'link': 'https://money.udn.com/money/story/10511/5648767',
#    'published': 'Wed, 04 Aug 2021 08:57:24 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=4, tm_hour=0, tm_min=57, tm_sec=24, tm_wday=2, tm_yday=216, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/04/realtime/13189445.jpeg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>新加坡總理李顯龍再次呼籲中美兩國化解緊張關係，指雙方都錯誤假定自己可以在衝突中取勝。他雖然認為中國大陸不會無端單邊對台灣...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/04/realtime/13189445.jpeg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>新加坡總理李顯龍再次呼籲中美兩國化解緊張關係，指雙方都錯誤假定自己可以在衝突中取勝。他雖然認為中國大陸不會無端單邊對台灣...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5648767',
#    'guidislink': False},
#   {'title': '美中爭霸系列二／拜登築起小院高牆  大陸加速高科技自主',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中爭霸系列二／拜登築起小院高牆  大陸加速高科技自主'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5646937'}],
#    'link': 'https://money.udn.com/money/story/10511/5646937',
#    'published': 'Tue, 03 Aug 2021 14:35:00 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=3, tm_hour=6, tm_min=35, tm_sec=0, tm_wday=1, tm_yday=215, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/03/2/13184409.jpeg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1113&amp;sh=742&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>拜登政府上台後，持續推展川普遺留的「印太戰略」，從國際戰場一路延伸到科技場域，旨在建構一個綿密的「抗中包圍網」；而剛慶祝完百年黨慶的中國大陸，則繼續高舉「科技自主」大旗，近期更揮刀在美上市的滴滴打車，</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/08/03/2/13184409.jpeg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1113&amp;sh=742&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>拜登政府上台後，持續推展川普遺留的「印太戰略」，從國際戰場一路延伸到科技場域，旨在建構一個綿密的「抗中包圍網」；而剛慶祝完百年黨慶的中國大陸，則繼續高舉「科技自主」大旗，近期更揮刀在美上市的滴滴打車，</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5646937',
#    'guidislink': False},
#   {'title': '美證管會出手 凍結陸企IPO',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美證管會出手 凍結陸企IPO'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5639815'}],
#    'link': 'https://money.udn.com/money/story/10511/5639815',
#    'published': 'Sat, 31 Jul 2021 02:42:58 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=30, tm_hour=18, tm_min=42, tm_sec=58, tm_wday=4, tm_yday=211, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/29/realtime/13148882.png&amp;s=Y&amp;x=0&amp;y=0&amp;sw=713&amp;sh=483&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>路透30日引述消息人士報導，美國證管會（SEC）已停止處理中國大陸企業在美國首次公開發行股票（IPO）和其他證券的註冊登...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/29/realtime/13148882.png&amp;s=Y&amp;x=0&amp;y=0&amp;sw=713&amp;sh=483&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>路透30日引述消息人士報導，美國證管會（SEC）已停止處理中國大陸企業在美國首次公開發行股票（IPO）和其他證券的註冊登...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5639815',
#    'guidislink': False},
#   {'title': '美中爭霸系列／專家之眼 拜登轉彎就在明年期中選舉後',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中爭霸系列／專家之眼 拜登轉彎就在明年期中選舉後'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5632683'}],
#    'link': 'https://money.udn.com/money/story/10511/5632683',
#    'published': 'Thu, 29 Jul 2021 07:26:53 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=28, tm_hour=23, tm_min=26, tm_sec=53, tm_wday=2, tm_yday=209, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/28/2/13139674.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1279&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>中國戰略分析智庫研究員鄧聿文分析，中國大陸與美國的晶片等尖端領域科技，仍有很大差距，即使努力推動「科技自主」，也不易在所有方面都追趕上美國。他預判，明年美國國會期中選舉，民主黨獲勝，拜登對中國大陸的抗</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/28/2/13139674.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1279&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>中國戰略分析智庫研究員鄧聿文分析，中國大陸與美國的晶片等尖端領域科技，仍有很大差距，即使努力推動「科技自主」，也不易在所有方面都追趕上美國。他預判，明年美國國會期中選舉，民主黨獲勝，拜登對中國大陸的抗</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5632683',
#    'guidislink': False},
#   {'title': '美中爭霸系列／專家之眼 拜習準冷戰關係形成',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中爭霸系列／專家之眼 拜習準冷戰關係形成'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5631443'}],
#    'link': 'https://money.udn.com/money/story/10511/5631443',
#    'published': 'Thu, 29 Jul 2021 07:26:30 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=28, tm_hour=23, tm_min=26, tm_sec=30, tm_wday=2, tm_yday=209, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/2/13134831.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>想像兩隻大象在跳舞，地上的小草和昆蟲難免遭受無妄之災；如果兩隻大象打起架來，一場爭鬥的破壞程度將遠遠超過許多。近年中國大陸影響力直追美國，兩強相爭，煙硝四起，台灣蕞薾小島的安全更隨之迭宕起伏。（延伸閱</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/2/13134831.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>想像兩隻大象在跳舞，地上的小草和昆蟲難免遭受無妄之災；如果兩隻大象打起架來，一場爭鬥的破壞程度將遠遠超過許多。近年中國大陸影響力直追美國，兩強相爭，煙硝四起，台灣蕞薾小島的安全更隨之迭宕起伏。（延伸閱</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5631443',
#    'guidislink': False},
#   {'title': '美中爭霸系列一／準冷戰關係來了，拜登的「印太戰術」圈得住中國戰狼？',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中爭霸系列一／準冷戰關係來了，拜登的「印太戰術」圈得住中國戰狼？'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5630676'}],
#    'link': 'https://money.udn.com/money/story/10511/5630676',
#    'published': 'Thu, 29 Jul 2021 07:26:07 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=28, tm_hour=23, tm_min=26, tm_sec=7, tm_wday=2, tm_yday=209, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/2/13133093.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國副國務卿薛曼（Wendy Sherman）本周造訪中國大陸，她此行任務是與大陸磋商「設置護欄」，避免日後美中關係惡化到不堪境地。這次，薛曼到天津，也領教了中國外交部副部長謝鋒的「戰狼式洗臉」，他批</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/2/13133093.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國副國務卿薛曼（Wendy Sherman）本周造訪中國大陸，她此行任務是與大陸磋商「設置護欄」，避免日後美中關係惡化到不堪境地。這次，薛曼到天津，也領教了中國外交部副部長謝鋒的「戰狼式洗臉」，他批</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5630676',
#    'guidislink': False},
#   {'title': '美國參議員呼籲 禁用紓困金採購華為及中興設備',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國參議員呼籲 禁用紓困金採購華為及中興設備'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5634949'}],
#    'link': 'https://money.udn.com/money/story/10511/5634949',
#    'published': 'Thu, 29 Jul 2021 04:03:22 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=28, tm_hour=20, tm_min=3, tm_sec=22, tm_wday=2, tm_yday=209, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/29/98/13146128.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1254&amp;sh=836&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國兩名參議員表示，他們正推行一項措施，禁止1.9兆美元紓困案資金用於購買來自華為及中興等企業的中國電信設備，因為這...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/29/98/13146128.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1254&amp;sh=836&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國兩名參議員表示，他們正推行一項措施，禁止1.9兆美元紓困案資金用於購買來自華為及中興等企業的中國電信設備，因為這...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5634949',
#    'guidislink': False},
#   {'title': '拜登提名新駐歐盟大使 美歐如何應對中國威權受矚',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '拜登提名新駐歐盟大使 美歐如何應對中國威權受矚'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5634321'}],
#    'link': 'https://money.udn.com/money/story/10511/5634321',
#    'published': 'Wed, 28 Jul 2021 19:45:24 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=28, tm_hour=11, tm_min=45, tm_sec=24, tm_wday=2, tm_yday=209, tm_isdst=0),
#    'summary': '美國總統拜登提名前駐羅馬尼亞大使吉騰斯坦為歐盟大使，他若通過任命除致力修補前總統川普任內發展不順的美歐夥伴關係，更受矚的...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國總統拜登提名前駐羅馬尼亞大使吉騰斯坦為歐盟大使，他若通過任命除致力修補前總統川普任內發展不順的美歐夥伴關係，更受矚的...'},
#    'id': 'https://money.udn.com/money/story/10511/5634321',
#    'guidislink': False},
#   {'title': '陸學者：薛曼之後 美國可能會有更高層級官員訪華',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '陸學者：薛曼之後 美國可能會有更高層級官員訪華'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5633556'}],
#    'link': 'https://money.udn.com/money/story/10511/5633556',
#    'published': 'Wed, 28 Jul 2021 14:34:29 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=28, tm_hour=6, tm_min=34, tm_sec=29, tm_wday=2, tm_yday=209, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/28/realtime/13141529.png&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1279&amp;sh=848&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國副國務卿薛曼26日結束短暫但針鋒相對的天津之行，上海復旦大學國際問題研究院院長吳心伯預期，美國可能正在考慮擴大和提升...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/28/realtime/13141529.png&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1279&amp;sh=848&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國副國務卿薛曼26日結束短暫但針鋒相對的天津之行，上海復旦大學國際問題研究院院長吳心伯預期，美國可能正在考慮擴大和提升...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5633556',
#    'guidislink': False},
#   {'title': '美中關係前哨戰  從天津會談看「拜習會」怎麼演',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中關係前哨戰  從天津會談看「拜習會」怎麼演'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5632018'}],
#    'link': 'https://money.udn.com/money/story/10511/5632018',
#    'published': 'Tue, 27 Jul 2021 23:06:13 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=27, tm_hour=15, tm_min=6, tm_sec=13, tm_wday=1, tm_yday=208, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/realtime/13136770.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=650&amp;sh=433&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國常務副國務卿薛曼7月25、26日訪問中國，大陸外交部長王毅送了「兩份清單」、「三條底線」當見面禮，這讓原本要替「拜習...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/realtime/13136770.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=650&amp;sh=433&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國常務副國務卿薛曼7月25、26日訪問中國，大陸外交部長王毅送了「兩份清單」、「三條底線」當見面禮，這讓原本要替「拜習...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5632018',
#    'guidislink': False},
#   {'title': '尋求穩定美中關係！美防長：致力與陸建立建設性關係',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '尋求穩定美中關係！美防長：致力與陸建立建設性關係'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5631651'}],
#    'link': 'https://money.udn.com/money/story/10511/5631651',
#    'published': 'Tue, 27 Jul 2021 18:51:24 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=27, tm_hour=10, tm_min=51, tm_sec=24, tm_wday=1, tm_yday=208, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/realtime/13135662.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=851&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國國防部長奧斯丁27日說，他致力與中國大陸建立具有建設性的關係，並應對共同挑戰，但稱美方在利益受威脅時不會退縮，但不會...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/realtime/13135662.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=851&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國國防部長奧斯丁27日說，他致力與中國大陸建立具有建設性的關係，並應對共同挑戰，但稱美方在利益受威脅時不會退縮，但不會...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5631651',
#    'guidislink': False},
#   {'title': '美中天津會 北京：加起來6小時 談得深又透',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中天津會 北京：加起來6小時 談得深又透'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5631516'}],
#    'link': 'https://money.udn.com/money/story/10511/5631516',
#    'published': 'Tue, 27 Jul 2021 17:45:37 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=27, tm_hour=9, tm_min=45, tm_sec=37, tm_wday=1, tm_yday=208, tm_isdst=0),
#    'summary': '美中外交官員昨天在天津舉行會談和會見。中國外交部今天說，會見和會談時間共計6小時，談得很深、很透，增進了相互了解；雙方都...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中外交官員昨天在天津舉行會談和會見。中國外交部今天說，會見和會談時間共計6小時，談得很深、很透，增進了相互了解；雙方都...'},
#    'id': 'https://money.udn.com/money/story/10511/5631516',
#    'guidislink': False},
#   {'title': '專家：天津會談後\u3000美中敵對恐「像水泥變硬般」固化',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '專家：天津會談後\u3000美中敵對恐「像水泥變硬般」固化'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5631337'}],
#    'link': 'https://money.udn.com/money/story/10511/5631337',
#    'published': 'Tue, 27 Jul 2021 16:30:31 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=27, tm_hour=8, tm_min=30, tm_sec=31, tm_wday=1, tm_yday=208, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/realtime/13134481.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1279&amp;sh=847&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美中兩國官員26日結束了在天津舉行的高層會晤，專家認為，美中之間的敵對在此會談後可能會「像水泥變硬般」固化。</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/27/realtime/13134481.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1279&amp;sh=847&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美中兩國官員26日結束了在天津舉行的高層會晤，專家認為，美中之間的敵對在此會談後可能會「像水泥變硬般」固化。</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5631337',
#    'guidislink': False}],
#  'feed': {'title': '經濟日報',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '經濟日報'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://money.udn.com'}],
#   'link': 'https://money.udn.com',
#   'subtitle': '經濟日報(https://money.udn.com)每日透過專業記者群，將即時、熱點、國際、行情、證券、兩岸、產業、酷科技、生技、理財、房產、品味、觀點及商情等等最新資訊彙整成當天重要新聞，提供最新最精闢的內容，為工商業界每日必讀的新聞網站。',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '經濟日報(https://money.udn.com)每日透過專業記者群，將即時、熱點、國際、行情、證券、兩岸、產業、酷科技、生技、理財、房產、品味、觀點及商情等等最新資訊彙整成當天重要新聞，提供最新最精闢的內容，為工商業界每日必讀的新聞網站。'},
#   'published': 'Fri, 06 Aug 2021 18:01:39 +0800',
#   'published_parsed': time.struct_time(tm_year=2021, tm_mon=8, tm_mday=6, tm_hour=10, tm_min=1, tm_sec=39, tm_wday=4, tm_yday=218, tm_isdst=0),
#   'rights': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.'},
#   'language': 'zh-TW',
#   'ttl': '10'},
#  'headers': {'server': 'u-t-a',
#   'content-encoding': 'gzip',
#   'strict-transport-security': 'max-age=15768000',
#   'x-e': 'Money192',
#   'access-control-allow-origin': '*',
#   'access-control-allow-headers': 'Origin, No-Cache, X-Requested-With, If-Modified-Since, Pragma, Last-Modified, Cache-Control, Expires, Content-Type, X-E4M-With',
#   'content-length': '4898',
#   'content-type': 'text/xml',
#   'date': 'Fri, 06 Aug 2021 10:03:38 GMT',
#   'connection': 'close',
#   'vary': 'Accept-Encoding'},
#  'href': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#  'status': 200,
#  'encoding': 'utf-8',
#  'bozo_exception': feedparser.exceptions.CharacterEncodingOverride('document declared as us-ascii, but parsed as utf-8'),
#  'version': 'rss20',
#  'namespaces': {}}

# %% [markdown]
# ### 查看每個 entry 的 title, url

# %%
i = 1
for e in newsFeed['entries']:
    title = e['title']
    link_url = e['links'][0]['href']
    print("%s, %s, %s"%(i, title, link_url))
    i = i + 1
# Out:
# 1, 美36個團體致信拜登 呼籲與大陸重啟談判, https://money.udn.com/money/story/10511/5654887
# 2, 辣個男人回來了！再戰2024先發行「川普卡」給川粉, https://money.udn.com/money/story/10511/5653906
# 3, 美中爭霸／專家之眼 台灣本土疫苗公司應該「三合一」, https://money.udn.com/money/story/10511/5653493
# 4, 美中爭霸系列三／美中疫苗戰短兵相接  軍火庫對上兵工廠, https://money.udn.com/money/story/10511/5652828
# 5, 經濟尬你講／拜登的「印太戰術」圈得住中國戰狼？4QA解析美中爭霸戰, https://money.udn.com/money/story/10511/5649813
# 6, 受美中貿易戰刺激 大陸出口產品精密度提升, https://money.udn.com/money/story/10511/5649669
# 7, 美中爭霸系列／美要求台灣供應鏈「去中」 質疑兩岸貿易額為何增加？, https://money.udn.com/money/story/10511/5647667
# 8, 星總理促中美化解緊張 認大陸不會單方無端攻擊台灣, https://money.udn.com/money/story/10511/5648767
# 9, 美中爭霸系列二／拜登築起小院高牆  大陸加速高科技自主, https://money.udn.com/money/story/10511/5646937
# 10, 美證管會出手 凍結陸企IPO, https://money.udn.com/money/story/10511/5639815
# 11, 美中爭霸系列／專家之眼 拜登轉彎就在明年期中選舉後, https://money.udn.com/money/story/10511/5632683
# 12, 美中爭霸系列／專家之眼 拜習準冷戰關係形成, https://money.udn.com/money/story/10511/5631443
# 13, 美中爭霸系列一／準冷戰關係來了，拜登的「印太戰術」圈得住中國戰狼？, https://money.udn.com/money/story/10511/5630676
# 14, 美國參議員呼籲 禁用紓困金採購華為及中興設備, https://money.udn.com/money/story/10511/5634949
# 15, 拜登提名新駐歐盟大使 美歐如何應對中國威權受矚, https://money.udn.com/money/story/10511/5634321
# 16, 陸學者：薛曼之後 美國可能會有更高層級官員訪華, https://money.udn.com/money/story/10511/5633556
# 17, 美中關係前哨戰  從天津會談看「拜習會」怎麼演, https://money.udn.com/money/story/10511/5632018
# 18, 尋求穩定美中關係！美防長：致力與陸建立建設性關係, https://money.udn.com/money/story/10511/5631651
# 19, 美中天津會 北京：加起來6小時 談得深又透, https://money.udn.com/money/story/10511/5631516
# 20, 專家：天津會談後　美中敵對恐「像水泥變硬般」固化, https://money.udn.com/money/story/10511/5631337

# %% [markdown]
# ### 解析html可以參考 https://lxml.de/lxmlhtml.html

# %% [markdown]
# ## 開始取得文章

# %% [markdown]
# ### 載入 library

# %%
import requests
from lxml import etree
from io import StringIO
import jieba
import pandas as pd
import time
import random

# %% [markdown]
# ### 使用繁體辭典

# %%
#指定辭典檔
jieba.set_dictionary('jieba_data/dict.txt.big')

# %% [markdown]
# ### 使用自訂義辭典

# %%
jieba.load_userdict('jieba_data/mydict.txt')

# %% [markdown]
# ### 設定 request header

# %%
#設定 request header
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
my_headers = {
    'User-Agent': user_agent,
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "accept-encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "cache-control": "no-cache",
    "Accept-Charset": "UTF8,utf-8;q=0.7,*;q=0.7"
}

# %% [markdown]
# ### 先爬文

# %%
#分解動作

#爬文
each_article_text_list = []
for e in newsFeed['entries']:
    url = e['links'][0]['href']
    print(url)
    r = requests.get(url, headers = my_headers)
    if r.status_code == 200:
        parse_tree = etree.parse(StringIO(r.text), etree.HTMLParser())
        article_elements = parse_tree.xpath('//*[@id="article_body"]//p')
        for a_part in article_elements:
            if type(a_part.text) is str:
                each_article_text_list.append(a_part.text.strip())
        sleep_time = random.randint(3,10)
        print("sleep time: %s sec"%(sleep_time))
        time.sleep(sleep_time)
    all_article_text = ''.join(each_article_text_list)
all_article_text
# Out:
# https://money.udn.com/money/story/10511/5654887
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5653906
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5653493
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5652828
# sleep time: 5 sec
# https://money.udn.com/money/story/10511/5649813
# sleep time: 8 sec
# https://money.udn.com/money/story/10511/5649669
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5647667
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5648767
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/5646937
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5639815
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5632683
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/5631443
# sleep time: 5 sec
# https://money.udn.com/money/story/10511/5630676
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5634949
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5634321
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/5633556
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/5632018
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5631651
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/5631516
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/5631337
# sleep time: 7 sec
# '美國零售商、晶片製造商、農民和其它近36個具有影響力的商業團體，於當地時間8月5日致信貿易代表戴琪和財政部長葉倫，呼籲拜登政府重啟與大陸的談判，並削減進口關稅，以免拖累美國經濟。第一財經報導，信中表示，大陸方面達到2020年第一階段貿易協定中的「重要基準和承諾」，包括向美國金融機構開放市場，並減少美國對大陸出口農產品的一些監管障礙，美國政府制定政策時也應該優先考慮本國工人的利益，取消因提高了成本而損害美國利益的關稅。拜登上台後，保留對大陸產電子產品、服裝和其他商品的關稅，一個目的是為了確保大陸履行其在2020年與美國簽訂的第一階段貿易協議中規定的義務。這些關稅由美國進口商支付。美國貿易代表辦公室和財政部的發言人暫未對此做出回應。對於是否打算執行川普政府談判達成的第一階段貿易協議或尋求延長該協議，拜登政府基本沒有發出信號。美國官員曾表示，預計評估工作將持續到今年秋季。去年敗選的川普不甘寂寞，對2024年大選躍躍欲試，也因此超前部署。川普團隊4日致函川粉，要求他們加入攜帶紅底金字「川普卡」的行列，不料此舉引來網友嘲笑，批評者還將「川普卡」的設計和極右派或納粹的圖像相提並論。獨立報報導，川普去年敗選後，曾暗示可能還會投入2024年選戰，而川普團隊在4日寄募款信給川粉，讓他們在四張正面有川普簽名的卡片中選擇一張當作「川普卡」，因為川普認為這些設計都很好看，應該讓美國民眾決定，「他們總是知道什麼是最好的」。川普在信中說，「川普卡」不僅是全美愛國者攜帶的物品，也是各位大力支持「拯救美國」運動的標誌，「你們獲得我全部的信任」。推特上的批評人士認為，川普卡和邪教擁有的特點很像，而其中一張卡的設計有隻金色老鷹，也像是納粹德國的帝國之鷹圖徽。近期YouGov民調數據顯示，儘管川粉提出的所有大選陰謀論都被徹底推翻，但共和黨受訪者中仍有66%的人相信川普才是去年大選的真正贏家。然而，另據昆尼皮亞克大學（Quinnipiac）4日公布的民調顯示，每十名美國人就有六人認為，川普參選2024年大選對美國來說是件壞事。財團法人生物技術開發中心董事長凃醒哲日前接受經濟日報專訪有個超前提議，他認為台灣一定要支持國產疫苗，也因為台灣很小，現在有兩、三家疫苗公司生產一樣的東西，「太多了！」，最好三家整合起來。不過，話鋒一轉，他也說，可能要等到各家吃到苦頭後，才能體會到組「疫苗國家隊」的重要。凃醒哲曾擔任SARS期間的衛生署署長（衛福部的前身），也做過嘉義市長、立法委員。他從生技產業發展角度，鼓吹疫苗公司有「三合一」的必要。生技中心是台灣生技產業發展升級的重要中介機構，由政府與民間共同捐助成立，透過產官學研開發關鍵技術，培植延攬專業人才。對於新冠疫情的發展，學醫出身的凃醒哲有幾個推論。一是，由於基因飄移（genetic drift，又叫基因漂變，指任何族群任何基因的頻率都可能發生非方向性的隨機變化）影響，出現變種毒株，新冠疫情會走向類流感化，未來每年都要打不同疫苗。現在年長者打流感疫苗被稱作「老人年針」，年輕人因抵抗力強，並不鼓勵他們施打，這是為什麼新冠疫苗研究一開始沒做18歲以下研究之故。二是新冠病毒弱化，重症和死亡人數下降，傳播性仍強，預期未來流感化以後，即使感染了也會有藥可治。而年輕人感冒了，醫生一般會建議多喝水，給普拿疼就好，克流感都不一定使用。未來年輕人也不見得會鼓勵施打新冠疫苗。三是隨著病毒變化，人的身體內抗體量漸漸不夠，這樣就會出現打第三劑以強化抗體的情形。現在也有研究顯示，增加高鋅元素的攝取，可以抵禦病毒入侵，這些都還在研究中。凃醒哲提到一個很重要概念：打疫苗是打「信任」的，不夠信任就不會想打！」這個道理，適用在今天很多人看待大陸和台灣國產的新冠疫苗評價上。他指出，疫苗能否獲取信任的三個條件是：透明度、安全性和保護力，但有關保護力的臨床數據很難做，因此會改以「增加多少抗體量」來做判斷\u3000。今年5月台灣疫情大爆發，「疫苗荒」重擊台灣人心，國產疫苗進度嚴重落後，甚而演變成為政治事件。凃醒哲認為，現在國產疫苗最大困難是，第三期進度比別人慢，等到產品上市，到時候已經有那麼多的輝瑞BNT疫苗進來，國產疫苗哪有容身之處？所以到時行銷會是問題。他認為，除了國內市場，國產疫苗還可考慮以「半買半送」方式，開拓國外市場。他說，對於國產疫苗應該要有一些了解，首先是，一定要支持台灣國產疫苗，這樣在必要時，國人的安全才有依靠，不用看別人眼色；其次，通過緊急使用之後，要趕快推動使用高端疫苗，現在製造不是問題，雖然不見得一下子可以生產出100萬劑或500萬劑，但可以源源不絕供應；三是國產疫苗的未來生存，才是問題。凃醒哲說，比照國家口罩隊概念成立疫苗國家隊，很有必要，因為給健康人使用的疫苗，需要量大但不能太貴，生產起來沒有什麼利潤，台灣是一個小小的國家，實在不需要兩、三家疫苗公司，「太多了！」。「即使集全台灣之力成立一家疫苗公司，也比不上一家GSK（指荷商葛蘭素史克集團）的規模」他說。他指出，最好現有的三家（國光、高端、聯亞）整合起來一起做。一般生產藥品可以有幾十種品牌，但疫苗不然，國衛院和生技中心都可參與，整合三家公私合營，底下有研發單位，也有宣導工廠的生產線，由國家出面號召成立的疫苗公司，未來也可憑藉國家力道援助邦交國。由於上海復星去年初即取得輝瑞BNT疫苗的大中華區代理權，鴻海創辦人郭台銘、台積電董事長劉德音、慈濟向上海復集團採購了共1,500萬劑的BNT疫苗，轉贈給政府分配施打，過程中引發不少爭議。凃醒哲認為，「大中華區」是政治而非經濟用詞，這種情況很不好，也會引起很多疑慮，例如，使用方會擔心疫苗是從原廠來的嗎？政治層面也有顧慮，「我們應該建議外商，以後要從簽亞洲區的角度來處理代理權問題」。從美中兩大國的角力來看，凃醒哲指出，疫苗應該依據人道考量使用，但是大國普遍將疫苗作為外交工具，獲取政治和經濟紅利。去年爆發新冠疫情以來，中國大陸率先展開疫苗外交戰，美國被逼著跟上來，雖不談經濟利益，但賺回外交優勢。相比之下，美國的質和量應該都會勝出，許多施打大陸疫苗兩劑的東南亞國家，因再爆發嚴重疫情，已轉向美歐疫苗。2021年新冠病毒全面散播，為美中爭霸開出新戰場。美國總統拜登6月10日在英國參加G7峰會時表示，今、明年將無條件捐贈5億支輝瑞BNT新冠疫苗。他形容無獨有偶，6月底，在北京大興，也悄悄誕生了一座生物安全三級防護（P3）標準等級的新冠疫苗生產工廠，年產能設定為10億支。大陸國藥集團董事長劉敬楨稱它是「全球最大新冠疫苗的『兵工廠』」。今年5月，世衛組織才剛把國藥北京生物製品研究所的疫苗，列入「緊急使用清單」上。拜登政府以新印太戰略圍堵中國大陸，促使這場疫苗霸權之爭，變成了美國「軍火庫」對上中國的「兵工廠」。隨著變種病毒發威，美中邁入「第三劑」競賽，鹿死誰手，結局未定。今年由台灣主辦的亞洲生技大會在上周閉幕，主席李鍾熙分析：「美中兩國制度不同，疫苗競爭不只是科技競爭，也是制度的競爭。」雖然美國前總統川普任上荒腔走板的行徑，備受批評，但他去年4月，針對發展新冠疫苗採取快速大膽的計畫「神速行動」（Operation Wrap Speed），卻是讓美國今日穩居疫苗第一梯隊的關鍵。該計畫從開發、製造、分銷等層面訂出目標，選出莫德納、AZ、嬌生、輝瑞BNT等廠商，由政府投注120億美元，並保證疫苗研發成功政府就會收購，政府也協助在很短時間招募10萬到15萬名受試者參與實驗。輝瑞BNT十個月內，就獲得美國食品藥物管理局（FDA）的緊急授權許可（EUA），創下歷史研發疫苗速度最快的紀錄，隨後莫德納、嬌生等一一獲得EUA 許可，如果加上第3季將申請許可的諾瓦瓦克斯（Novavax），可以說，這四大疫苗讓美國奠定了全球疫苗霸權的地位。如果說，「神速行動」為美國在疫苗戰一役，取得全球發言權，那麼中國大陸在去年1月21日，武漢爆發新冠疫情決定封城的前兩天，由科技部召開的一項會議，對大陸疫苗發展的重要性也不能被忽略。該會議決定「全力發展新冠疫苗」，雖然當時沒人注意，但確立疫苗研發五路線並行的戰略，厚植了大陸得以突破美國疫苗強勢壓制的本錢。大陸採行的五種疫苗技術有：滅活、核酸、重組蛋白、腺病毒載體、減毒流感病體載體等疫苗。相較歐美國家多押寶核酸疫苗（mRNA），為什麼大陸要多路並進呢？大陸媒體解讀，疫苗研發失敗率高，為了確保成功，所以五路並進；其次種類越多，可依不同情況接種，且病毒可能出現變異，替代的選擇也多。研發疫苗很燒錢，但是，過去中國在高科技領域，曾被美國「卡脖子」（限制），吃過太多苦頭；大陸擔心如果不能自主研發疫苗，很可能面臨三大威脅，包括：一、買不到疫苗；二、只能買高價疫苗；三、買到了還有可能會委屈國格。為了避免因為疫苗，再被美國掐住脖子，大陸科技部成立了「科研攻關應急項目研究小組」，由政府主導，統籌科研單位與國有企業疫苗共同研發。大陸國產疫苗「五路並行」，也為大陸疫苗外交提供助力。今年7月16日，大陸國務院新聞辦宣布，大陸的新冠疫苗年產能達50億劑。大陸並與世衛組織（WHO）的新冠疫苗平台（COVAX）簽約，將在10月底前向COVAX提供1.1億劑疫苗。大陸積極拓展中國疫苗出海口，美國也沒閒著。6月中旬，美國總統拜登宣布，將分今年2億、明年上半年3億，共捐贈5億劑疫苗給需要的國家。白宮在8月3日盤點全球捐贈疫苗進度，至今已捐逾1.1億劑給台灣等65個國家，台灣在亞太地區排名第四，前三名是目前疫情嚴峻的東南亞國家：印尼、菲律賓、越南。8月底前，美國也將開始送出規劃好的5億劑輝瑞BNT疫苗，協助100個中低收入國家抗疫。這項大規模釋苗行動，搭配拜登政府重返亞洲的結盟單略，頗受盟邦歡迎。近來變種病毒肆虐，印尼、馬 ...

# %% [markdown]
# ### 做分詞

# %%
#分詞
seg_words_list = jieba.lcut(all_article_text)
seg_words_list
# Out:
# ['美國',
#  '零售商',
#  '、',
#  '晶片',
#  '製造商',
#  '、',
#  '農民',
#  '和',
#  '其它',
#  '近',
#  '36',
#  '個',
#  '具有',
#  '影響力',
#  '的',
#  '商業',
#  '團體',
#  '，',
#  '於',
#  '當地',
#  '時間',
#  '8',
#  '月',
#  '5',
#  '日',
#  '致信',
#  '貿易',
#  '代表',
#  '戴琪',
#  '和',
#  '財政部長',
#  '葉倫',
#  '，',
#  '呼籲',
#  '拜登',
#  '政府',
#  '重啟',
#  '與',
#  '大陸',
#  '的',
#  '談判',
#  '，',
#  '並',
#  '削減',
#  '進口關稅',
#  '，',
#  '以免',
#  '拖累',
#  '美國',
#  '經濟',
#  '。',
#  '第一',
#  '財經',
#  '報導',
#  '，',
#  '信中',
#  '表示',
#  '，',
#  '大陸',
#  '方面',
#  '達到',
#  '2020',
#  '年',
#  '第一階段',
#  '貿易協定',
#  '中',
#  '的',
#  '「',
#  '重要',
#  '基準',
#  '和',
#  '承諾',
#  '」',
#  '，',
#  '包括',
#  '向',
#  '美國',
#  '金融機構',
#  '開放市場',
#  '，',
#  '並',
#  '減少',
#  '美國',
#  '對',
#  '大陸',
#  '出口',
#  '農產品',
#  '的',
#  '一些',
#  '監管',
#  '障礙',
#  '，',
#  '美國政府',
#  '制定',
#  '政策',
#  '時',
#  '也',
#  '應該',
#  '優先',
#  '考慮',
#  '本國',
#  '工人',
#  '的',
#  '利益',
#  '，',
#  '取消',
#  '因',
#  '提高',
#  '了',
#  '成本',
#  '而',
#  '損害',
#  '美國',
#  '利益',
#  '的',
#  '關稅',
#  '。',
#  '拜',
#  '登上',
#  '台',
#  '後',
#  '，',
#  '保留',
#  '對',
#  '大陸',
#  '產',
#  '電子產品',
#  '、',
#  '服裝',
#  '和',
#  '其他',
#  '商品',
#  '的',
#  '關稅',
#  '，',
#  '一個',
#  '目的',
#  '是',
#  '為',
#  '了',
#  '確保',
#  '大陸',
#  '履行',
#  '其',
#  '在',
#  '2020',
#  '年',
#  '與',
#  '美國',
#  '簽訂',
#  '的',
#  '第一階段',
#  '貿易',
#  '協議',
#  '中',
#  '規定',
#  '的',
#  '義務',
#  '。',
#  '這些',
#  '關稅',
#  '由',
#  '美國',
#  '進口商',
#  '支付',
#  '。',
#  '美國',
#  '貿易',
#  '代表',
#  '辦公室',
#  '和',
#  '財政部',
#  '的',
#  '發言人',
#  '暫未',
#  '對此',
#  '做出',
#  '回應',
#  '。',
#  '對於',
#  '是否',
#  '打算',
#  '執行',
#  '川普',
#  '政府',
#  '談判',
#  '達成',
#  '的',
#  '第一階段',
#  '貿易',
#  '協議',
#  '或',
#  '尋求',
#  '延長',
#  '該',
#  '協議',
#  '，',
#  '拜登',
#  '政府',
#  '基本',
#  '沒有',
#  '發出信號',
#  '。',
#  '美國',
#  '官員',
#  '曾',
#  '表示',
#  '，',
#  '預計',
#  '評估',
#  '工作',
#  '將',
#  '持續',
#  '到',
#  '今年',
#  '秋季',
#  '。',
#  '去年',
#  '敗選',
#  '的',
#  '川普',
#  '不甘寂寞',
#  '，',
#  '對',
#  '2024',
#  '年',
#  '大選',
#  '躍躍欲試',
#  '，',
#  '也',
#  '因此',
#  '超前',
#  '部署',
#  '。',
#  '川普',
#  '團隊',
#  '4',
#  '日',
#  '致函',
#  '川粉',
#  '，',
#  '要求',
#  '他們',
#  '加入',
#  '攜帶',
#  '紅底',
#  '金字',
#  '「',
#  '川普卡',
#  '」',
#  '的',
#  '行列',
#  '，',
#  '不料',
#  '此舉',
#  '引來',
#  '網友',
#  '嘲笑',
#  '，',
#  '批評者',
#  '還將',
#  '「',
#  '川普卡',
#  '」',
#  '的',
#  '設計',
#  '和',
#  '極右派',
#  '或',
#  '納粹',
#  '的',
#  '圖像',
#  '相提並論',
#  '。',
#  '獨立報',
#  '報導',
#  '，',
#  '川普',
#  '去年',
#  '敗選',
#  '後',
#  '，',
#  '曾',
#  '暗示',
#  '可能',
#  '還會',
#  '投入',
#  '2024',
#  '年',
#  '選戰',
#  '，',
#  '而川普',
#  '團隊',
#  '在',
#  '4',
#  '日',
#  '寄',
#  '募款',
#  '信給川粉',
#  '，',
#  '讓',
#  '他們',
#  '在',
#  '四張',
#  '正面',
#  '有川普',
#  '簽名',
#  '的',
#  '卡片',
#  '中',
#  '選擇',
#  '一張',
#  '當作',
#  '「',
#  '川普卡',
#  '」',
#  '，',
#  '因為川',
#  '普認',
#  '為',
#  '這些',
#  '設計',
#  '都',
#  '很',
#  '好看',
#  '，',
#  '應該',
#  '讓',
#  '美國',
#  '民眾',
#  '決定',
#  '，',
#  '「',
#  '他們',
#  '總是',
#  '知道',
#  '什麼',
#  '是',
#  '最好',
#  '的',
#  '」',
#  '。',
#  '川普',
#  '在',
#  '信中',
#  '說',
#  '，',
#  '「',
#  '川普卡',
#  '」',
#  '不僅',
#  '是',
#  '全美',
#  '愛國者',
#  '攜帶',
#  '的',
#  '物品',
#  '，',
#  '也',
#  '是',
#  '各位',
#  '大力支持',
#  '「',
#  '拯救',
#  '美國',
#  '」',
#  '運動',
#  '的',
#  '標誌',
#  '，',
#  '「',
#  '你們',
#  '獲得',
#  '我',
#  '全部',
#  '的',
#  '信任',
#  '」',
#  '。',
#  '推特上',
#  '的',
#  '批評',
#  '人士',
#  '認為',
#  '，',
#  '川普卡',
#  '和',
#  '邪教',
#  '擁有',
#  '的',
#  '特點',
#  '很',
#  '像',
#  '，',
#  '而',
#  '其中',
#  '一張',
#  '卡',
#  '的',
#  '設計',
#  '有',
#  '隻',
#  '金色',
#  '老鷹',
#  '，',
#  '也',
#  '像是',
#  '納粹德國',
#  '的',
#  '帝國',
#  '之鷹',
#  '圖徽',
#  '。',
#  '近期',
#  'YouGov',
#  '民調',
#  '數據',
#  '顯示',
#  '，',
#  '儘管',
#  '川粉',
#  '提出',
#  '的',
#  '所有',
#  '大選',
#  '陰謀論',
#  '都',
#  '被',
#  '徹底',
#  '推翻',
#  '，',
#  '但',
#  '共和黨',
#  '受訪者',
#  '中',
#  '仍',
#  '有',
#  '66%',
#  '的',
#  '人',
#  '相信',
#  '川普才',
#  '是',
#  '去年',
#  '大選',
#  '的',
#  '真正',
#  '贏家',
#  '。',
#  '然而',
#  '，',
#  '另據',
#  '昆尼皮',
#  '亞克',
#  '大學',
#  '（',
#  'Quinnipiac',
#  '）',
#  '4',
#  '日',
#  '公布',
#  '的',
#  '民調',
#  '顯示',
#  '，',
#  '每',
#  '十名',
#  '美國',
#  '人',
#  '就',
#  '有',
#  '六人',
#  '認為',
#  '，',
#  '川普',
#  '參選',
#  '2024',
#  '年',
#  '大選',
#  '對',
#  '美國',
#  '來說',
#  '是',
#  '件',
#  '壞事',
#  '。',
#  '財團法人',
#  '生物',
#  '技術開發',
#  '中心',
#  '董事長',
#  '凃',
#  '醒',
#  '哲',
#  '日前',
#  '接受',
#  '經濟日報',
#  '專訪',
#  '有個',
#  '超前',
#  '提議',
#  '，',
#  '他',
#  '認為',
#  '台灣',
#  '一定',
#  '要',
#  '支持',
#  '國產',
#  '疫苗',
#  '，',
#  '也',
#  '因為',
#  '台灣',
#  '很小',
#  '，',
#  '現在',
#  '有',
#  '兩',
#  '、',
#  '三家',
#  '疫苗',
#  '公司',
#  '生產',
#  '一樣',
#  '的',
#  '東西',
#  '，',
#  '「',
#  '太多',
#  '了',
#  '！',
#  '」',
#  '，',
#  '最好',
#  '三家',
#  '整合',
#  '起來',
#  '。',
#  '不過',
#  '，',
#  '話鋒一轉',
#  '，',
#  '他',
#  '也',
#  '說',
#  '，',
#  '可能',
#  '要',
#  '等到',
#  '各家',
#  '吃',
#  '到',
#  '苦頭',
#  '後',
#  '，',
#  '才能',
#  '體會',
#  '到',
#  '組',
#  '「',
#  '疫苗',
#  '國家隊',
#  '」',
#  '的',
#  '重要',
#  '。',
#  '凃',
#  '醒',
#  '哲曾',
#  '擔任',
#  'SARS',
#  '期間',
#  '的',
#  '衛生署',
#  '署長',
#  '（',
#  '衛福部',
#  '的',
#  '前身',
#  '）',
#  '，',
#  '也',
#  '做過',
#  '嘉義',
#  '市長',
#  '、',
#  '立法委員',
#  '。',
#  '他',
#  '從',
#  '生技',
#  '產業',
#  '發展',
#  '角度',
#  '，',
#  '鼓吹',
#  '疫苗',
#  '公司',
#  '有',
#  '「',
#  '三合一',
#  '」',
#  '的',
#  '必要',
#  '。',
#  '生技',
#  '中心',
#  '是',
#  '台灣',
#  '生技',
#  '產業',
#  '發展',
#  '升級',
#  '的',
#  '重要',
#  '中介機構',
#  '，',
#  '由',
#  '政府',
#  '與',
#  '民間',
#  '共同',
#  '捐助',
#  '成立',
#  '，',
#  '透過',
#  '產官',
#  '學研',
#  '開發',
#  '關鍵技術',
#  '，',
#  '培植',
#  '延攬',
#  '專業人才',
#  '。',
#  '對於',
#  '新冠',
#  '疫情',
#  '的',
#  '發展',
#  '，',
#  '學醫',
#  '出身',
#  '的',
#  '凃',
#  '醒',
#  '哲有',
#  '幾個',
#  '推論',
#  '。',
#  '一是',
#  '，',
#  '由於',
#  '基因',
#  '飄移',
#  '（',
#  'genetic',
#  ' ',
#  'drift',
#  '，',
#  '又',
#  '叫',
#  '基因',
#  '漂變',
#  '，',
#  '指',
#  '任何',
#  '族群',
#  '任何',
#  '基因',
#  '的',
#  '頻率',
#  '都',
#  '可能',
#  '發生',
#  '非',
#  '方向性',
#  '的',
#  '隨機',
#  '變化',
#  '）',
#  '影響',
#  '，',
#  '出現',
#  '變種',
#  '毒株',
#  '，',
#  '新冠',
#  '疫情',
#  '會',
#  '走向',
#  '類',
#  '流感',
#  '化',
#  '，',
#  '未來',
#  '每年',
#  '都',
#  '要',
#  '打',
#  '不同',
#  '疫苗',
#  '。',
#  '現在',
#  '年長者',
#  '打',
#  '流感疫苗',
#  '被稱作',
#  '「',
#  '老人',
#  '年針',
#  '」',
#  '，',
#  '年輕人',
#  '因',
#  '抵抗力',
#  '強',
#  '，',
#  '並不',
#  '鼓勵',
#  '他們',
#  '施打',
#  '，',
#  '這是',
#  '為',
#  '什麼',
#  '新冠',
#  '疫苗',
#  '研究',
#  '一',
#  '開始',
#  '沒',
#  '做',
#  '18',
#  '歲',
#  '以下',
#  '研究',
#  '之故',
#  '。',
#  '二是',
#  '新冠',
#  '病毒',
#  '弱化',
#  '，',
#  '重症',
#  '和',
#  '死亡',
#  '人數',
#  '下降',
#  '，',
#  '傳播',
#  '性',
#  '仍強',
#  '，',
#  '預期',
#  '未來',
#  '流感',
#  '化',
#  '以後',
#  '，',
#  '即使',
#  '感染',
#  '了',
#  '也',
#  '會',
#  '有藥',
#  '可治',
#  '。',
#  '而',
#  '年輕人',
#  '感冒',
#  '了',
#  '，',
#  '醫生',
#  '一般',
#  '會',
#  '建議',
#  '多喝水',
#  '，',
#  '給普',
#  '拿',
#  '疼',
#  '就',
#  '好',
#  '，',
#  '克',
#  '流感',
#  '都',
#  '不',
#  '一定',
#  '使用',
#  '。',
#  '未來',
#  '年輕人',
#  '也',
#  '不見得',
#  '會',
#  '鼓勵',
#  '施打',
#  '新冠',
#  '疫苗',
#  '。',
#  '三是',
#  '隨著',
#  '病毒',
#  '變化',
#  '，',
#  '人',
#  '的',
#  '身體',
#  '內',
#  '抗體',
#  '量',
#  '漸漸',
#  '不夠',
#  '，',
#  '這樣',
#  '就',
#  '會',
#  '出現',
#  '打',
#  '第三',
#  '劑以',
#  '強化',
#  '抗體',
#  '的',
#  '情形',
#  '。',
#  '現在',
#  '也',
#  '有',
#  '研究',
#  '顯示',
#  '，',
#  '增加',
#  '高',
#  '鋅元素',
#  '的',
#  '攝取',
#  '，',
#  '可以',
#  '抵禦',
#  '病毒',
#  '入侵',
#  '，',
#  '這些',
#  '都',
#  '還在',
#  '研究',
#  '中',
#  '。',
#  '凃',
#  '醒',
#  '哲',
#  '提到',
#  '一個',
#  '很',
#  '重要',
#  '概念',
#  '：',
#  '打',
#  '疫苗',
#  '是',
#  '打',
#  '「',
#  '信任',
#  '」',
#  '的',
#  '，',
#  '不夠',
#  '信任',
#  '就',
#  '不會',
#  '想',
#  '打',
#  '！',
#  '」',
#  '這個',
#  '道理',
#  '，',
#  '適用',
#  '在',
#  '今天',
#  '很多',
#  '人',
#  '看待',
#  '大陸',
#  '和',
#  '台灣',
#  '國產',
#  '的',
#  '新冠',
#  '疫苗',
#  '評價',
#  '上',
#  '。',
#  '他',
#  '指出',
#  '，',
#  '疫苗',
#  '能否',
#  '獲取',
#  '信任',
#  '的',
#  '三個',
#  '條件',
#  '是',
#  '：',
#  '透明度',
#  '、',
#  '安全性',
#  '和',
#  '保護',
#  '力',
#  '，',
#  '但',
#  '有關',
#  '保護',
#  '力',
#  '的',
#  '臨床',
#  '數據',
#  '很難',
#  '做',
#  '，',
#  '因此',
#  '會',
#  '改以',
#  '「',
#  '增加',
#  '多少',
#  '抗體',
#  '量',
#  '」',
#  '來',
#  '做',
#  '判斷',
#  '\u3000',
#  '。',
#  '今年',
#  '5',
#  '月台',
#  '灣',
#  '疫情',
#  '大',
#  '爆發',
#  '，',
#  '「',
#  '疫苗',
#  '荒',
#  '」',
#  '重擊',
#  '台灣',
#  '人心',
#  '，',
#  '國產',
#  '疫苗',
#  '進度',
#  '嚴重',
#  '落後',
#  '，',
#  '甚而',
#  '演變成',
#  '為',
#  '政治事件',
#  '。',
#  '凃',
#  '醒',
#  '哲認',
#  '為',
#  '，',
#  '現在',
#  '國產',
#  '疫苗',
#  '最大',
#  '困難',
#  '是',
#  '，',
#  '第三期',
#  '進度',
#  '比',
#  '別人',
#  '慢',
#  '，',
#  '等到',
#  '產品',
#  '上市',
#  '，',
#  '到時候',
#  '已經',
#  '有',
#  '那麼',
#  '多',
#  '的',
#  '輝瑞',
#  'BNT',
#  '疫苗',
#  '進來',
#  '，',
#  ...]

# %%
# !ls jieba_data
# Out:
# dict.txt.big  mydict.txt  stop_words.txt

# %% [markdown]
# ### 準備 stop word

# %%
#stop word
with open(file='jieba_data/stop_words.txt', mode='r', encoding='utf-8') as file:
    stop_words = file.read().split('\n')
#stop_words

# %% [markdown]
# ### 準備一個利用stop word過濾後的分詞結果

# %%
#分詞
seg_stop_words_list = []
seg_words_list = jieba.lcut(all_article_text)
for term in seg_words_list:
    if term not in stop_words:
        seg_stop_words_list.append(term)
#seg_stop_words_list

# %%
#合併動作 XD
each_article_text_list = []
seg_words_list = []
for e in newsFeed['entries']:
    url = e['links'][0]['href']
    print(url)
    r = requests.get(url, headers = my_headers)
    if r.status_code == 200:
        parse_tree = etree.parse(StringIO(r.text), etree.HTMLParser())
        article_elements = parse_tree.xpath('//article//p')
        for a_part in article_elements:
            if type(a_part.text) is str:
                term = a_part.text.strip()
                if term not in stop_words:
                    each_article_text_list.append(term)
        all_article_text += ''.join(each_article_text_list)
        sleep_time = random.randint(0,2)
        print("sleep time: %s sec"%(sleep_time))
        time.sleep(sleep_time)
seg_words_list = jieba.lcut(all_article_text)
seg_df = pd.DataFrame(seg_words_list, columns=['seg_word'])
print(seg_df)
# Out:
# https://money.udn.com/money/story/10511/5654887
# sleep time: 0 sec
# https://money.udn.com/money/story/10511/5653906
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5653493
# sleep time: 2 sec
# https://money.udn.com/money/story/10511/5652828
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5649813
# sleep time: 2 sec
# https://money.udn.com/money/story/10511/5649669
# sleep time: 2 sec
# https://money.udn.com/money/story/10511/5647667
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5648767
# sleep time: 0 sec
# https://money.udn.com/money/story/10511/5646937
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5639815
# sleep time: 0 sec
# https://money.udn.com/money/story/10511/5632683
# sleep time: 0 sec
# https://money.udn.com/money/story/10511/5631443
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5630676
# sleep time: 0 sec
# https://money.udn.com/money/story/10511/5634949
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5634321
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5633556
# sleep time: 0 sec
# https://money.udn.com/money/story/10511/5632018
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5631651
# sleep time: 1 sec
# https://money.udn.com/money/story/10511/5631516
# sleep time: 2 sec
# https://money.udn.com/money/story/10511/5631337
# sleep time: 0 sec
#       seg_word
# 0           美國
# 1          零售商
# 2            、
# 3           晶片
# 4          製造商
# ...        ...
# 11508        並
# 11509       持續
# 11510     一段時間
# 11511        。
# 11512        」
#
# [11513 rows x 1 columns]

# %% [markdown]
# ### 載入繪圖相關的 library

# %%
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
print(matplotlib.matplotlib_fname())
# Out:
# /opt/conda/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc

# %% [markdown]
# ### 安裝中文字型

# %%
#!ls fonts/*.ttf
# Out:
# fonts/SimHei.ttf  fonts/TaipeiSansTCBeta-Regular.ttf

# %%
#!cat /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc
# Out:
# #### MATPLOTLIBRC FORMAT
#
# ## This is a sample matplotlib configuration file - you can find a copy
# ## of it on your system in site-packages/matplotlib/mpl-data/matplotlibrc
# ## (which related to your Python installation location).
# ##
# ## If you edit it there, please note that it will be overwritten in your
# ## next install.  If you want to keep a permanent local copy that will not
# ## be overwritten, place it in one of the following locations:
# ## unix/linux:
# ##     $HOME/.config/matplotlib/matplotlibrc OR
# ##     $XDG_CONFIG_HOME/matplotlib/matplotlibrc (if $XDG_CONFIG_HOME is set)
# ## other platforms:
# ##     $HOME/.matplotlib/matplotlibrc
# ##
# ## See https://matplotlib.org/users/customizing.html#the-matplotlibrc-file
# ## for more details on the paths which are checked for the configuration file.
# ##
# ## This file is best viewed in a editor which supports python mode syntax
# ## highlighting.  Blank lines, or lines starting with a comment symbol, are
# ## ignored, as are trailing comments.  Other lines must have the format:
# ##     key : val  ## optional comment
# ##
# ## Formatting and style conventions for this file:
# ##     - at least one whitesapce AROUND `:` to seperate key and val
# ##         * prefer one whitesapce except for block colon alignment
# ##     - at least two whitesapces BEFORE `##` to seperate the key-val pair and
# ##       the trailing comments
# ##         * prefer two whitesapces except for block `##` alignment
# ##     - at least one whitesapce AFTER `##` to seperate the `##` marker and
# ##       the comment text
# ##         * prefer one whitesapce except for indentation (listing, etc.), in
# ##           which case, four more whitespaces are preferred
# ##
# ## Colors: for the color values below, you can either use
# ##     - a matplotlib color string, such as r, k, or b
# ##     - an rgb tuple, such as (1.0, 0.5, 0.0)
# ##     - a hex string, such as ff00ff
# ##     - a scalar grayscale intensity such as 0.75
# ##     - a legal html color name, e.g., red, blue, darkslategray
# ##
# ## Matplotlib configuration are currently divided into following parts:
# ##     - BACKENDS
# ##     - LINES
# ##     - PATCHES
# ##     - HATCHES
# ##     - BOXPLOT
# ##     - FONT
# ##     - TEXT
# ##     - LaTeX
# ##     - AXES
# ##     - DATES
# ##     - TICKS
# ##     - GRIDS
# ##     - LEGEND
# ##     - FIGURE
# ##     - IMAGES
# ##     - CONTOUR PLOTS
# ##     - ERRORBAR PLOTS
# ##     - HISTOGRAM PLOTS
# ##     - SCATTER PLOTS
# ##     - AGG RENDERING
# ##     - PATHS
# ##     - SAVING FIGURES
# ##     - INTERACTIVE KEYMAPS
# ##     - ANIMATION
#
# ##### CONFIGURATION BEGINS HERE
#
#
# ## ***************************************************************************
# ## * BACKENDS                                                                *
# ## ***************************************************************************
# ## The default backend.  If you omit this parameter, the first working
# ## backend from the following list is used:
# ##     MacOSX Qt5Agg Qt4Agg Gtk3Agg TkAgg WxAgg Agg
# ## Other choices include:
# ##     Qt5Cairo Qt4Cairo GTK3Cairo TkCairo WxCairo Cairo Wx
# ##     PS PDF SVG Template
# ## You can also deploy your own backend outside of matplotlib by referring to
# ## the module name (which must be in the PYTHONPATH) as 'module://my_backend'.
# #backend : Agg
#
# ## The port to use for the web server in the WebAgg backend.
# #webagg.port : 8988
#
# ## The address on which the WebAgg web server should be reachable
# #webagg.address : 127.0.0.1
#
# ## If webagg.port is unavailable, a number of other random ports will
# ## be tried until one that is available is found.
# #webagg.port_retries : 50
#
# ## When True, open the webbrowser to the plot that is shown
# #webagg.open_in_browser : True
#
# ## If you are running pyplot inside a GUI and your backend choice
# ## conflicts, we will automatically try to find a compatible one for
# ## you if backend_fallback is True
# #backend_fallback : True
#
# #interactive : False
# #toolbar     : toolbar2  ## {None, toolbar2}
# #timezone    : UTC       ## a pytz timezone string, e.g., US/Central or Europe/Paris
#
#
# ## ***************************************************************************
# ## * LINES                                                                   *
# ## ***************************************************************************
# ## See https://matplotlib.org/api/artist_api.html#module-matplotlib.lines
# ## for more information on line properties.
# #lines.linewidth : 1.5  ## line width in points
# #lines.linestyle : -    ## solid line
# #lines.color     : C0   ## has no affect on plot(); see axes.prop_cycle
# #lines.marker          : None  ## the default marker
# #lines.markerfacecolor : auto  ## the default marker face color
# #lines.markeredgecolor : auto  ## the default marker edge color
# #lines.markeredgewidth : 1.0   ## the line width around the marker symbol
# #lines.markersize      : 6     ## marker size, in points
# #lines.dash_joinstyle  : round       ## {miter, round, bevel}
# #lines.dash_capstyle   : butt        ## {butt, round, projecting}
# #lines.solid_joinstyle : round       ## {miter, round, bevel}
# #lines.solid_capstyle  : projecting  ## {butt, round, projecting}
# #lines.antialiased : True  ## render lines in antialiased (no jaggies)
#
# ## The three standard dash patterns.  These are scaled by the linewidth.
# #lines.dashed_pattern : 3.7, 1.6
# #lines.dashdot_pattern : 6.4, 1.6, 1, 1.6
# #lines.dotted_pattern : 1, 1.65
# #lines.scale_dashes : True
#
# #markers.fillstyle : full  ## {full, left, right, bottom, top, none}
#
#
# ## ***************************************************************************
# ## * PATCHES                                                                 *
# ## ***************************************************************************
# ## Patches are graphical objects that fill 2D space, like polygons or circles.
# ## See https://matplotlib.org/api/artist_api.html#module-matplotlib.patches
# ## for more information on patch properties.
# #patch.linewidth       : 1      ## edge width in points.
# #patch.facecolor       : C0
# #patch.edgecolor       : black  ## if forced, or patch is not filled
# #patch.force_edgecolor : False  ## True to always use edgecolor
# #patch.antialiased     : True   ## render patches in antialiased (no jaggies)
#
#
# ## ***************************************************************************
# ## * HATCHES                                                                 *
# ## ***************************************************************************
# #hatch.color     : black
# #hatch.linewidth : 1.0
#
#
# ## ***************************************************************************
# ## * BOXPLOT                                                                 *
# ## ***************************************************************************
# #boxplot.notch       : False
# #boxplot.vertical    : True
# #boxplot.whiskers    : 1.5
# #boxplot.bootstrap   : None
# #boxplot.patchartist : False
# #boxplot.showmeans   : False
# #boxplot.showcaps    : True
# #boxplot.showbox     : True
# #boxplot.showfliers  : True
# #boxplot.meanline    : False
#
# #boxplot.flierprops.color           : black
# #boxplot.flierprops.marker          : o
# #boxplot.flierprops.markerfacecolor : none
# #boxplot.flierprops.markeredgecolor : black
# #boxplot.flierprops.markeredgewidth : 1.0
# #boxplot.flierprops.markersize      : 6
# #boxplot.flierprops.linestyle       : none
# #boxplot.flierprops.linewidth       : 1.0
#
# #boxplot.boxprops.color     : black
# #boxplot.boxprops.linewidth : 1.0
# #boxplot.boxprops.linestyle : -
#
# #boxplot.whiskerprops.color     : black
# #boxplot.whiskerprops.linewidth : 1.0
# #boxplot.whiskerprops.linestyle : -
#
# #boxplot.capprops.color     : black
# #boxplot.capprops.linewidth : 1.0
# #boxplot.capprops.linestyle : -
#
# #boxplot.medianprops.color     : C1
# #boxplot.medianprops.linewidth : 1.0
# #boxplot.medianprops.linestyle : -
#
# #boxplot.meanprops.color           : C2
# #boxplot.meanprops.marker          : ^
# #boxplot.meanprops.markerfacecolor : C2
# #boxplot.meanprops.markeredgecolor : C2
# #boxplot.meanprops.markersize      :  6
# #boxplot.meanprops.linestyle       : --
# #boxplot.meanprops.linewidth       : 1.0
#
#
# ## ***************************************************************************
# ## * FONT                                                                    *
# ## ***************************************************************************
# ## The font properties used by `text.Text`.
# ## See https://matplotlib.org/api/font_manager_api.html for more information
# ## on font properties.  The 6 font properties used for font matching are
# ## given below with their default values.
# ##
# ## The font.family property has five values:
# ##     - 'serif' (e.g., Times),
# ##     - 'sans-serif' (e.g., Helvetica),
# ##     - 'cursive' (e.g., Zapf-Chancery),
# ##     - 'fantasy' (e.g., Western), and
# ##     - 'monospace' (e.g., Courier).
# ## Each of these font families has a default list of font names in decreasing
# ## order of priority associated with them.  When text.usetex is False,
# ## font.family may also be one or more concrete font names.
# ##
# ## The font.style property has three values: normal (or roman), italic
# ## or oblique.  The oblique style will be used for italic, if it is not
# ## present.
# ##
# ## The font.variant property has two values: normal or small-caps.  For
# ## TrueType fonts, which are scalable fonts, small-caps is equivalent
# ## to using a font size of 'smaller', or about 83%% of the current font
# ## size.
# ##
# ## The font.weight property has effectively 13 values: normal, bold,
# ## bolder, lighter, 100, 200, 300, ..., 900.  Normal is the same as
# ## 400, and bold is 700.  bolder and lighter are relative values with
# ## respect to the current weight.
# ##
# ## The font.stretch property has 11 values: ultra-condensed,
# ## extra-condensed, condensed, semi-condensed, normal, semi-expanded,
# ## expanded, extra-expanded, ultra-expanded, wider, and narrower.  This
# ## property is not currently implemented.
# ##
# ## The font.size property is the default font size for text, given in pts.
# ## 10 pt is the standard value.
# ##
# ## Note that font.size controls default text sizes.  To configure
# ## special text sizes tick labels, axes, labels, title, etc, see the rc
# ## settings for axes and ticks.  Special text sizes can be defined
# ## relative to font.size, using the following values: xx-small, x-small,
# ## small, medium, large, x-large, xx-large, larger, or smaller
#
# #font.family  : sans-serif
# #font.style   : normal
# #font.variant : normal
# #font.weight  : normal
# #font.stretch : normal
# #font.size    : 10.0
#
# #font.serif      : DejaVu Serif, Bitstream Vera Serif, Computer Modern Roman, New Century Schoolbook, Century Schoolbook L, Utopia, ITC Bookman, Bookman, Nimbus Roman No9 L, Times New Roman, Times, Palatino, Charter, serif
# #font.sans-serif : DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# #font.cursive    : Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, cursive
# #font.fantasy    : Comic Neue, Comic Sans MS, Chicago, Charcoal, ImpactWestern, Humor Sans, xkcd, fantasy
# #font.monospace  : DejaVu Sans Mono, Bitstream Vera Sans Mono, Computer Modern Typewriter, Andale Mono, Nimbus Mono L, Courier New, Courier, Fixed, Terminal, monospace
#
#
# ## ***************************************************************************
# ## * TEXT                                                                    *
# ## ***************************************************************************
# ## The text properties used by `text.Text`.
# ## See https://matplotlib.org/api/artist_api.html#module-matplotlib.text
# ## for more information on text properties
# #text.color : black
#
#
# ## ***************************************************************************
# ## * LaTeX                                                                   *
# ## ***************************************************************************
# ## See following links for more information on LaTex properties:
# ## https://matplotlib.org/tutorials/text/usetex.html
# ## https://scipy-cookbook.readthedocs.io/items/idx_matplotlib_typesetting.html
# #text.usetex : False  ## use latex for all text handling. The following fonts
#                       ## are supported through the usual rc parameter settings:
#                       ## new century schoolbook, bookman, times, palatino,
#                       ## zapf chancery, charter, serif, sans-serif, helvetica,
#                       ## avant garde, courier, monospace, computer modern roman,
#                       ## computer modern sans serif, computer modern typewriter
#                       ## If another font is desired which can loaded using the
#                       ## LaTeX \usepackage command, please inquire at the
#                       ## matplotlib mailing list
# #text.latex.preamble :      ## IMPROPER USE OF THIS FEATURE WILL LEAD TO LATEX FAILURES
#                             ## AND IS THEREFORE UNSUPPORTED. PLEASE DO NOT ASK FOR HELP
#                             ## IF THIS FEATURE DOES NOT DO WHAT YOU EXPECT IT TO.
#                             ## text.latex.preamble is a single line of LaTeX code that
#                             ## will be passed on to the LaTeX system. It may contain
#                             ## any code that is valid for the LaTeX "preamble", i.e.
#                             ## between the "\documentclass" and "\begin{document}"
#                             ## statements.
#                             ## Note that it has to be put on a single line, which may
#                             ## become quite long.
#                             ## The following packages are always loaded with usetex, so
#                             ## beware of package collisions: color, geometry, graphicx,
#                             ## type1cm, textcomp.
#                             ## Adobe Postscript (PSSNFS) font packages may also be
#                             ## loaded, depending on your font settings.
# #text.latex.preview : False
#
# #text.hinting : auto  ## May be one of the following:
#                       ##     - none: Perform no hinting
#                       ##     - auto: Use FreeType's autohinter
#                       ##     - native: Use the hinting information in the
#                       ##               font file, if available, and if your
#                       ##               FreeType library supports it
#                       ##     - either: Use the native hinting information,
#                       ##               or the autohinter if none is available.
# #text.hinting_factor : 8  ## Specifies the amount of softness for hinting in the
#                           ## horizontal direction.  A value of 1 will hint to full
#                           ## pixels.  A value of 2 will hint to half pixels etc.
# #text.kerning_factor : 0  ## Specifies the scaling factor for kerning values. This
#                           ## is provided solely to allow old test images to remain
#                           ## unchanged. Set to 6 to obtain previous behavior. Values
#                           ## other than 0 or 6 have no defined meaning.
# #text.antialiased : True  ## If True (default), the text will be antialiased.
#                           ## This only affects the Agg backend.
#
# ## The following settings allow you to select the fonts in math mode.
# ## They map from a TeX font name to a fontconfig font pattern.
# ## These settings are only used if mathtext.fontset is 'custom'.
# ## Note that this "custom" mode is unsupported and may go away in the future.
# #mathtext.cal : cursive
# #mathtext.rm  : sans
# #mathtext.tt  : monospace
# #mathtext.it  : sans:italic
# #mathtext.bf  : sans:bold
# #mathtext.sf  : sans
# #mathtext.fontset : dejavusans  ## Should be 'dejavusans' (default),
#                                 ## 'dejavuserif', 'cm' (Computer Modern), 'stix',
#                                 ## 'stixsans' or 'custom'
# #mathtext.fallback_to_cm : True  ## When True, use symbols from the Computer Modern
#                                  ## fonts when a symbol can not be found in one of
#                                  ## the custom math fonts.
# #mathtext.default : it  ## The default font to use for math.
#                         ## Can be any of the LaTeX font names, including
#                         ## the special name "regular" for the same font
#                         ## used in regular text.
#
#
# ## ***************************************************************************
# ## * AXES                                                                    *
# ## ***************************************************************************
# ## Following are default face and edge colors, default tick sizes,
# ## default fontsizes for ticklabels, and so on.  See
# ## https://matplotlib.org/api/axes_api.html#module-matplotlib.axes
# #axes.facecolor     : white   ## axes background color
# #axes.edgecolor     : black   ## axes edge color
# #axes.linewidth     : 0.8     ## edge linewidth
# #axes.grid          : False   ## display grid or not
# #axes.grid.axis     : both    ## which axis the grid should apply to
# #axes.grid.which    : major   ## gridlines at {major, minor, both} ticks
# #axes.titlelocation : center  ## alignment of the title: {left, right, center}
# #axes.titlesize     : large   ## fontsize of the axes title
# #axes.titleweight   : normal  ## font weight of title
# #axes.titlecolor    : auto    ## color of the axes title, auto falls back to text.color
#                               ## as default value
# #axes.titlepad      : 6.0     ## pad between axes and title in points
# #axes.labelsize     : medium  ## fontsize of the x any y labels
# #axes.labelpad      : 4.0     ## space between label and axis
# #axes.labelweight   : normal  ## weight of the x and y labels
# #axes.labelcolor    : black
# #axes.axisbelow     : line    ## draw axis gridlines and ticks:
#                               ##     - below patches (True)
#                               ##     - above patches but below lines ('line')
#                               ##     - above all (False)
#
# #axes.formatter.limits : -5, 6  ## use scientific notation if log10
#                                 ## of the axis range is smaller than the
#                                 ## first or larger than the second
# #axes.formatter.use_locale : False  ## When True, format tick labels
#                                     ## according to the user's locale.
#                                     ## For example, use ',' as a decimal
#                                     ## separator in the fr_FR locale.
# #axes.formatter.use_mathtext : False  ## When True, use mathtext for scientific
#                                       ## notation.
# #axes.formatter.min_exponent : 0  ## minimum exponent to format in scientific notation
# #axes.formatter.useoffset : True  ## If True, the tick label formatter
#                                   ## will default to labeling ticks relative
#                                   ## to an offset when the data range is
#                                   ## small compared to the minimum absolute
#                                   ## value of the data.
# #axes.formatter.offset_threshold : 4  ## When useoffset is True, the offset
#                                       ## will be used when it can remove
#                                       ## at least this number of significant
#                                       ## digits from tick labels.
#
# #axes.spines.left   : True  ## display axis spines
# #axes.spines.bottom : True
# #axes.spines.top    : True
# #axes.spines.right  : True
#
# #axes.unicode_minus : True  ## use Unicode for the minus symbol
#                             ## rather than hyphen.  See
#                             ## https://en.wikipedia.org/wiki/Plus_and_minus_signs#Character_codes
# #axes.prop_cycle : cycler('color', ['1f77b4', 'ff7f0e', '2ca02c', 'd62728', '9467bd', '8c564b', 'e377c2', '7f7f7f', 'bcbd22', '17becf'])
#                    ## color cycle for plot lines as list of string colorspecs:
#                    ##     single letter, long name, or web-style hex
# 				   ## As opposed to all other paramters in this file, the color
# 				   ## values must be enclosed in quotes for this parameter,
# 				   #  e.g. '1f77b4', instead of 1f77b4.
#                    ## See also https://matplotlib.org/tutorials/intermediate/color_cycle.html
#                    ## for more details on prop_cycle usage.
# #axes.autolimit_mode : data  ## How to scale axes limits to the data.  By using:
#                              ##     - "data" to use data limits, plus some margin
#                              ##     - "round_numbers" move to the nearest "round" number
# #axes.xmargin   : .05   ## x margin.  See `axes.Axes.margins`
# #axes.ymargin   : .05   ## y margin.  See `axes.Axes.margins`
# #polaraxes.grid : True  ## display grid on polar axes
# #axes3d.grid    : True  ## display grid on 3d axes
#
#
# ## ***************************************************************************
# ## * DATES                                                                   *
# ## ***************************************************************************
# ## These control the default format strings used in AutoDateFormatter.
# ## Any valid format datetime format string can be used (see the python
# ## `datetime` for details).  For example, by using:
# ##     - '%%x' will use the locale date representation
# ##     - '%%X' will use the locale time representation
# ##     - '%%c' will use the full locale datetime representation
# ## These values map to the scales:
# ##     {'year': 365, 'month': 30, 'day': 1, 'hour': 1/24, 'minute': 1 / (24 * 60)}
#
# #date.autoformatter.year        : %Y
# #date.autoformatter.month       : %Y-%m
# #date.autoformatter.day         : %Y-%m-%d
# #date.autoformatter.hour        : %m-%d %H
# #date.autoformatter.minute      : %d %H:%M
# #date.autoformatter.second      : %H:%M:%S
# #date.autoformatter.microsecond : %M:%S.%f
#
#
# ## ***************************************************************************
# ## * TICKS                                                                   *
# ## ***************************************************************************
# ## See https://matplotlib.org/api/axis_api.html#matplotlib.axis.Tick
# #xtick.top           : False   ## draw ticks on the top side
# #xtick.bottom        : True    ## draw ticks on the bottom side
# #xtick.labeltop      : False   ## draw label on the top
# #xtick.labelbottom   : True    ## draw label on the bottom
# #xtick.major.size    : 3.5     ## major tick size in points
# #xtick.minor.size    : 2       ## minor tick size in points
# #xtick.major.width   : 0.8     ## major tick width in points
# #xtick.minor.width   : 0.6     ## minor tick width in points
# #xtick.major.pad     : 3.5     ## distance to major tick label in points
# #xtick.minor.pad     : 3.4     ## distance to the minor tick label in points
# #xtick.color         : black   ## color of the tick labels
# #xtick.labelsize     : medium  ## fontsize of the tick labels
# #xtick.direction     : out     ## direction: {in, out, inout}
# #xtick.minor.visible : False   ## visibility of minor ticks on x-axis
# #xtick.major.top     : True    ## draw x axis top major ticks
# #xtick.major.bottom  : True    ## draw x axis bottom major ticks
# #xtick.minor.top     : True    ## draw x axis top minor ticks
# #xtick.minor.bottom  : True    ## draw x axis bottom minor ticks
# #xtick.alignment     : center  ## alignment of xticks
#
# #ytick.left          : True    ## draw ticks on the left side
# #ytick.right         : False   ## draw ticks on the right side
# #ytick.labelleft     : True    ## draw tick labels on the left side
# #ytick.labelright    : False   ## draw tick labels on the right side
# #ytick.major.size    : 3.5     ## major tick size in points
# #ytick.minor.size    : 2       ## minor tick size in points
# #ytick.major.width   : 0.8     ## major tick width in points
# #ytick.minor.width   : 0.6     ## minor tick width in points
# #ytick.major.pad     : 3.5     ## distance to major tick label in points
# #ytick.minor.pad     : 3.4     ## distance to the minor tick label in points
# #ytick.color         : black   ## color of the tick labels
# #ytick.labelsize     : medium  ## fontsize of the tick labels
# #ytick.direction     : out     ## direction: {in, out, inout}
# #ytick.minor.visible : False   ## visibility of minor ticks on y-axis
# #ytick.major.left    : True    ## draw y axis left major ticks
# #ytick.major.right   : True    ## draw y axis right major ticks
# #ytick.minor.left    : True    ## draw y axis left minor ticks
# #ytick.minor.right   : True    ## draw y axis right minor ticks
# #ytick.alignment     : center_baseline  ## alignment of yticks
#
#
# ## ***************************************************************************
# ## * GRIDS                                                                   *
# ## ***************************************************************************
# #grid.color     : b0b0b0  ## grid color
# #grid.linestyle : -       ## solid
# #grid.linewidth : 0.8     ## in points
# #grid.alpha     : 1.0     ## transparency, between 0.0 and 1.0
#
#
# ## ***************************************************************************
# ## * LEGEND                                                                  *
# ## ***************************************************************************
# #legend.loc           : best
# #legend.frameon       : True     ## if True, draw the legend on a background patch
# #legend.framealpha    : 0.8      ## legend patch transparency
# #legend.facecolor     : inherit  ## inherit from axes.facecolor; or color spec
# #legend.edgecolor     : 0.8      ## background patch boundary color
# #legend.fancybox      : True     ## if True, use a rounded box for the
#                                  ## legend background, else a rectangle
# #legend.shadow        : False    ## if True, give background a shadow effect
# #legend.numpoints     : 1        ## the number of marker points in the legend line
# #legend.scatterpoints : 1        ## number of scatter points
# #legend.markerscale   : 1.0      ## the relative size of legend markers vs. original
# #legend.fontsize      : medium
# #legend.title_fontsize : None    ## None sets to the same as the default axes.
#
# ## Dimensions as fraction of fontsize:
# #legend.borderpad     : 0.4  ## border whitespace
# #legend.labelspacing  : 0.5  ## the vertical space between the legend entries
# #legend.handlelength  : 2.0  ## the length of the legend lines
# #legend.handleheight  : 0.7  ## the height of the legend handle
# #legend.handletextpad : 0.8  ## the space between the legend line and legend text
# #legend.borderaxespad : 0.5  ## the border between the axes and legend edge
# #legend.columnspacing : 2.0  ## column separation
#
#
# ## ***************************************************************************
# ## * FIGURE                                                                  *
# ## ***************************************************************************
# ## See https://matplotlib.org/api/figure_api.html#matplotlib.figure.Figure
# #figure.titlesize   : large     ## size of the figure title (``Figure.suptitle()``)
# #figure.titleweight : normal    ## weight of the figure title
# #figure.figsize     : 6.4, 4.8  ## figure size in inches
# #figure.dpi         : 100       ## figure dots per inch
# #figure.facecolor   : white     ## figure facecolor
# #figure.edgecolor   : white     ## figure edgecolor
# #figure.frameon     : True      ## enable figure frame
# #figure.max_open_warning : 20   ## The maximum number of figures to open through
#                                 ## the pyplot interface before emitting a warning.
#                                 ## If less than one this feature is disabled.
#
# ## The figure subplot parameters.  All dimensions are a fraction of the figure width and height.
# #figure.subplot.left   : 0.125  ## the left side of the subplots of the figure
# #figure.subplot.right  : 0.9    ## the right side of the subplots of the figure
# #figure.subplot.bottom : 0.11   ## the bottom of the subplots of the figure
# #figure.subplot.top    : 0.88   ## the top of the subplots of the figure
# #figure.subplot.wspace : 0.2    ## the amount of width reserved for space between subplots,
#                                 ## expressed as a fraction of the average axis width
# #figure.subplot.hspace : 0.2    ## the amount of height reserved for space between subplots,
#                                 ## expressed as a fraction of the average axis height
#
# ## Figure layout
# #figure.autolayout : False  ## When True, automatically adjust subplot
#                             ## parameters to make the plot fit the figure
#                             ## using `tight_layout`
# #figure.constrained_layout.use : False  ## When True, automatically make plot
#                                         ## elements fit on the figure. (Not
#                                         ## compatible with `autolayout`, above).
# #figure.constrained_layout.h_pad  : 0.04167  ## Padding around axes objects. Float representing
# #figure.constrained_layout.w_pad  : 0.04167  ## inches. Default is 3./72. inches (3 pts)
# #figure.constrained_layout.hspace : 0.02     ## Space between subplot groups. Float representing
# #figure.constrained_layout.wspace : 0.02     ## a fraction of the subplot widths being separated.
#
#
# ## ***************************************************************************
# ## * IMAGES                                                                  *
# ## ***************************************************************************
# #image.aspect : equal            ## {equal, auto} or a number
# #image.interpolation  : antialiased  ## see help(imshow) for options
# #image.cmap   : viridis          ## A colormap name, gray etc...
# #image.lut    : 256              ## the size of the colormap lookup table
# #image.origin : upper            ## {lower, upper}
# #image.resample  : True
# #image.composite_image : True  ## When True, all the images on a set of axes are
#                                ## combined into a single composite image before
#                                ## saving a figure as a vector graphics file,
#                                ## such as a PDF.
#
#
# ## ***************************************************************************
# ## * CONTOUR PLOTS                                                           *
# ## ***************************************************************************
# #contour.negative_linestyle : dashed  ## string or on-off ink sequence
# #contour.corner_mask        : True    ## {True, False, legacy}
#
#
# ## ***************************************************************************
# ## * ERRORBAR PLOTS                                                          *
# ## ***************************************************************************
# #errorbar.capsize : 0  ## length of end cap on error bars in pixels
#
#
# ## ***************************************************************************
# ## * HISTOGRAM PLOTS                                                         *
# ## ***************************************************************************
# #hist.bins : 10  ## The default number of histogram bins or 'auto'.
#
#
# ## ***************************************************************************
# ## * SCATTER PLOTS                                                           *
# ## ***************************************************************************
# #scatter.marker : o         ## The default marker type for scatter plots.
# #scatter.edgecolors : face  ## The default edge colors for scatter plots.
#
#
# ## ***************************************************************************
# ## * AGG RENDERING                                                           *
# ## ***************************************************************************
# ## Warning: experimental, 2008/10/10
# #agg.path.chunksize : 0  ## 0 to disable; values in the range
#                          ## 10000 to 100000 can improve speed slightly
#                          ## and prevent an Agg rendering failure
#                          ## when plotting very large data sets,
#                          ## especially if they are very gappy.
#                          ## It may cause minor artifacts, though.
#                          ## A value of 20000 is probably a good
#                          ## starting point.
#
#
# ## ***************************************************************************
# ## * PATHS                                                                   *
# ## ***************************************************************************
# #path.simplify : True  ## When True, simplify paths by removing "invisible"
#                        ## points to reduce file size and increase rendering
#                        ## speed
# #path.simplify_threshold : 0.111111111111  ## The threshold of similarity below
#                                            ## which vertices will be removed in
#                                            ## the simplification process.
# #path.snap : True  ## When True, rectilinear axis-aligned paths will be snapped
#                    ## to the nearest pixel when certain criteria are met.
#                    ## When False, paths will never be snapped.
# #path.sketch : None  ## May be None, or a 3-tuple of the form:
#                      ## (scale, length, randomness).
#                      ##     - *scale* is the amplitude of the wiggle
#                      ##         perpendicular to the line (in pixels).
#                      ##     - *length* is the length of the wiggle along the
#                      ##         line (in pixels).
#                      ##     - *randomness* is the factor by which the length is
#                      ##         randomly scaled.
# #path.effects : []   ##
#
#
# ## ***************************************************************************
# ## * SAVING FIGURES                                                          *
# ## ***************************************************************************
# ## The default savefig params can be different from the display params
# ## e.g., you may want a higher resolution, or to make the figure
# ## background white
# #savefig.dpi       : figure      ## figure dots per inch or 'figure'
# #savefig.facecolor : white       ## figure facecolor when saving
# #savefig.edgecolor : white       ## figure edgecolor when saving
# #savefig.format    : png         ## {png, ps, pdf, svg}
# #savefig.bbox      : standard    ## {tight, standard}
#                                  ## 'tight' is incompatible with pipe-based animation
#                                  ## backends but will workd with temporary file based ones:
#                                  ## e.g. setting animation.writer to ffmpeg will not work,
#                                  ## use ffmpeg_file instead
# #savefig.pad_inches   : 0.1      ## Padding to be used when bbox is set to 'tight'
# #savefig.jpeg_quality : 95       ## when a jpeg is saved, the default quality parameter.
# #savefig.directory    : ~        ## default directory in savefig dialog box,
#                                  ## leave empty to always use current working directory
# #savefig.transparent : False     ## setting that controls whether figures are saved with a
#                                  ## transparent background by default
# #savefig.orientation : portrait  ## Orientation of saved figure
#
# ### tk backend params
# #tk.window_focus   : False  ## Maintain shell focus for TkAgg
#
# ### ps backend params
# #ps.papersize      : letter  ## {auto, letter, legal, ledger, A0-A10, B0-B10}
# #ps.useafm         : False   ## use of afm fonts, results in small files
# #ps.usedistiller   : False   ## {ghostscript, xpdf, None}
#                              ## Experimental: may produce smaller files.
#                              ## xpdf intended for production of publication quality files,
#                              ## but requires ghostscript, xpdf and ps2eps
# #ps.distiller.res  : 6000    ## dpi
# #ps.fonttype       : 3       ## Output Type 3 (Type3) or Type 42 (TrueType)
#
# ### PDF backend params
# #pdf.compression    : 6  ## integer from 0 to 9
#                          ## 0 disables compression (good for debugging)
# #pdf.fonttype       : 3  ## Output Type 3 (Type3) or Type 42 (TrueType)
# #pdf.use14corefonts : False
# #pdf.inheritcolor   : False
#
# ### SVG backend params
# #svg.image_inline : True  ## Write raster image data directly into the SVG file
# #svg.fonttype : path      ## How to handle SVG fonts:
#                           ##     path: Embed characters as paths -- supported
#                           ##           by most SVG renderers
#                           ##     None: Assume fonts are installed on the
#                           ##           machine where the SVG will be viewed.
# #svg.hashsalt : None      ## If not None, use this string as hash salt instead of uuid4
#
# ### pgf parameter
# ## See https://matplotlib.org/tutorials/text/pgf.html for more information.
# #pgf.rcfonts : True
# #pgf.preamble :          ## See text.latex.preamble for documentation
# #pgf.texsystem : xelatex
#
# ### docstring params
# ##docstring.hardcopy = False  ## set this when you want to generate hardcopy docstring
#
#
# ## ***************************************************************************
# ## * INTERACTIVE KEYMAPS                                                     *
# ## ***************************************************************************
# ## Event keys to interact with figures/plots via keyboard.
# ## See https://matplotlib.org/users/navigation_toolbar.html for more details on
# ## interactive navigation.  Customize these settings according to your needs.
# ## Leave the field(s) empty if you don't need a key-map. (i.e., fullscreen : '')
# #keymap.fullscreen : f, ctrl+f   ## toggling
# #keymap.home : h, r, home        ## home or reset mnemonic
# #keymap.back : left, c, backspace, MouseButton.BACK  ## forward / backward keys
# #keymap.forward : right, v, MouseButton.FORWARD      ## for quick navigation
# #keymap.pan : p                  ## pan mnemonic
# #keymap.zoom : o                 ## zoom mnemonic
# #keymap.save : s, ctrl+s         ## saving current figure
# #keymap.help : f1                ## display help about active tools
# #keymap.quit : ctrl+w, cmd+w, q  ## close the current figure
# #keymap.quit_all : W, cmd+W, Q   ## close all figures
# #keymap.grid : g                 ## switching on/off major grids in current axes
# #keymap.grid_minor : G           ## switching on/off minor grids in current axes
# #keymap.yscale : l               ## toggle scaling of y-axes ('log'/'linear')
# #keymap.xscale : k, L            ## toggle scaling of x-axes ('log'/'linear')
# #keymap.all_axes : a             ## enable all axes
# #keymap.copy : ctrl+c, cmd+c     ## Copy figure to clipboard
#
#
# ## ***************************************************************************
# ## * ANIMATION                                                               *
# ## ***************************************************************************
# #animation.html : none  ## How to display the animation as HTML in
#                         ## the IPython notebook:
#                         ##     - 'html5' uses HTML5 video tag
#                         ##     - 'jshtml' creates a Javascript animation
# #animation.writer  : ffmpeg  ## MovieWriter 'backend' to use
# #animation.codec   : h264    ## Codec to use for writing movie
# #animation.bitrate : -1      ## Controls size/quality tradeoff for movie.
#                              ## -1 implies let utility auto-determine
# #animation.frame_format : png      ## Controls frame format used by temp files
# #animation.html_args    :          ## Additional arguments to pass to html writer
# #animation.ffmpeg_path  : ffmpeg   ## Path to ffmpeg binary. Without full path
#                                    ## $PATH is searched
# #animation.ffmpeg_args  :          ## Additional arguments to pass to ffmpeg
# #animation.avconv_path  : avconv   ## Path to avconv binary. Without full path
#                                    ## $PATH is searched
# #animation.avconv_args  :          ## Additional arguments to pass to avconv
# #animation.convert_path : convert  ## Path to ImageMagick's convert binary.
#                                    ## On Windows use the full path since convert
#                                    ## is also the name of a system tool.
# #animation.convert_args :          ## Additional arguments to pass to convert
# #animation.embed_limit  : 20.0     ## Limit, in MB, of size of base64 encoded
#                                    ## animation in HTML (i.e. IPython notebook)
#
# #mpl_toolkits.legacy_colorbar: True

# %% [markdown]
# #### 字型檔案是放在 /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf 我們先列出來看一下

# %%
# !ls /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf
# Out:
# cmb10.ttf			DejaVuSerif.ttf
# cmex10.ttf			LICENSE_DEJAVU
# cmmi10.ttf			LICENSE_STIX
# cmr10.ttf			STIXGeneralBolIta.ttf
# cmss10.ttf			STIXGeneralBol.ttf
# cmsy10.ttf			STIXGeneralItalic.ttf
# cmtt10.ttf			STIXGeneral.ttf
# DejaVuSans-BoldOblique.ttf	STIXNonUniBolIta.ttf
# DejaVuSans-Bold.ttf		STIXNonUniBol.ttf
# DejaVuSansDisplay.ttf		STIXNonUniIta.ttf
# DejaVuSansMono-BoldOblique.ttf	STIXNonUni.ttf
# DejaVuSansMono-Bold.ttf		STIXSizFiveSymReg.ttf
# DejaVuSansMono-Oblique.ttf	STIXSizFourSymBol.ttf
# DejaVuSansMono.ttf		STIXSizFourSymReg.ttf
# DejaVuSans-Oblique.ttf		STIXSizOneSymBol.ttf
# DejaVuSans.ttf			STIXSizOneSymReg.ttf
# DejaVuSerif-BoldItalic.ttf	STIXSizThreeSymBol.ttf
# DejaVuSerif-Bold.ttf		STIXSizThreeSymReg.ttf
# DejaVuSerifDisplay.ttf		STIXSizTwoSymBol.ttf
# DejaVuSerif-Italic.ttf		STIXSizTwoSymReg.ttf

# %% [markdown]
# #### 將中文字型檔案放到字型收容的路徑

# %%
# !cp fonts/*.ttf /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf

# %% [markdown]
# #### 檢查一下結果

# %%
# !ls /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf
# Out:
# cmb10.ttf			LICENSE_DEJAVU
# cmex10.ttf			LICENSE_STIX
# cmmi10.ttf			SimHei.ttf
# cmr10.ttf			STIXGeneralBolIta.ttf
# cmss10.ttf			STIXGeneralBol.ttf
# cmsy10.ttf			STIXGeneralItalic.ttf
# cmtt10.ttf			STIXGeneral.ttf
# DejaVuSans-BoldOblique.ttf	STIXNonUniBolIta.ttf
# DejaVuSans-Bold.ttf		STIXNonUniBol.ttf
# DejaVuSansDisplay.ttf		STIXNonUniIta.ttf
# DejaVuSansMono-BoldOblique.ttf	STIXNonUni.ttf
# DejaVuSansMono-Bold.ttf		STIXSizFiveSymReg.ttf
# DejaVuSansMono-Oblique.ttf	STIXSizFourSymBol.ttf
# DejaVuSansMono.ttf		STIXSizFourSymReg.ttf
# DejaVuSans-Oblique.ttf		STIXSizOneSymBol.ttf
# DejaVuSans.ttf			STIXSizOneSymReg.ttf
# DejaVuSerif-BoldItalic.ttf	STIXSizThreeSymBol.ttf
# DejaVuSerif-Bold.ttf		STIXSizThreeSymReg.ttf
# DejaVuSerifDisplay.ttf		STIXSizTwoSymBol.ttf
# DejaVuSerif-Italic.ttf		STIXSizTwoSymReg.ttf
# DejaVuSerif.ttf			TaipeiSansTCBeta-Regular.ttf

# %% [markdown]
# #### 清除 matplotlib 快取

# %%
print(matplotlib.get_configdir())
# Out:
# /home/jovyan/.config/matplotlib

# %%
# !ls -la /home/jovyan/.config/matplotlib
# Out:
# total 12
# drwsrwsr-x 2 jovyan users 4096 Jun 18 11:43 .
# drwsrws--- 1 jovyan users 4096 Jun 18 11:43 ..

# %%
print(matplotlib.get_cachedir())
# Out:
# /home/jovyan/.cache/matplotlib

# %%
# !rm -rf /home/jovyan/.cache/matplotlib

# %%
#用來顯示中文
plt.rcParams['font.sans-serif']=['SimHei']
#用來顯示負號
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# #### 其他 FAQ 可以參考 https://matplotlib.org/3.1.1/faq/troubleshooting_faq.html

# %% [markdown]
# ### 繪製文字雲 ( wordcloud.generate )

# %%
# wordcloud.generate 參數是吃文字內容，以空白為文字區隔
seg_words = ' '.join(seg_words_list)
#seg_words

# %%
#不同字型
wordcloud = WordCloud(font_path='fonts/SimHei.ttf').generate(seg_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#不同字型
wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate(seg_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 繪製文字雲 ( wordcloud.generate_from_frequencies )

# %%
# https://docs.python.org/zh-tw/3/library/collections.html
# 準備一個沒有經過stop word 處理的 counter
from collections import Counter
seg_counter = Counter(seg_words_list)
seg_counter
# Out:
# Counter({'美國': 165,
#          '零售商': 1,
#          '、': 133,
#          '晶片': 6,
#          '製造商': 1,
#          '農民': 1,
#          '和': 79,
#          '其它': 1,
#          '近': 1,
#          '36': 1,
#          '個': 9,
#          '具有': 3,
#          '影響力': 9,
#          '的': 446,
#          '商業': 1,
#          '團體': 1,
#          '，': 1005,
#          '於': 3,
#          '當地': 2,
#          '時間': 5,
#          '8': 7,
#          '月': 36,
#          '5': 9,
#          '日': 25,
#          '致信': 1,
#          '貿易': 10,
#          '代表': 7,
#          '戴琪': 1,
#          '財政部長': 1,
#          '葉倫': 1,
#          '呼籲': 3,
#          '拜登': 53,
#          '政府': 32,
#          '重啟': 2,
#          '與': 57,
#          '大陸': 135,
#          '談判': 2,
#          '並': 14,
#          '削減': 1,
#          '進口關稅': 1,
#          '以免': 1,
#          '拖累': 1,
#          '經濟': 19,
#          '。': 337,
#          '第一': 2,
#          '財經': 1,
#          '報導': 7,
#          '信中': 2,
#          '表示': 16,
#          '方面': 6,
#          '達到': 2,
#          '2020': 3,
#          '年': 20,
#          '第一階段': 3,
#          '貿易協定': 1,
#          '中': 52,
#          '「': 157,
#          '重要': 11,
#          '基準': 1,
#          '承諾': 1,
#          '」': 158,
#          '包括': 11,
#          '向': 10,
#          '金融機構': 1,
#          '開放市場': 1,
#          '減少': 1,
#          '對': 45,
#          '出口': 8,
#          '農產品': 1,
#          '一些': 6,
#          '監管': 7,
#          '障礙': 3,
#          '美國政府': 5,
#          '制定': 3,
#          '政策': 10,
#          '時': 11,
#          '也': 86,
#          '應該': 14,
#          '優先': 1,
#          '考慮': 7,
#          '本國': 2,
#          '工人': 1,
#          '利益': 10,
#          '取消': 3,
#          '因': 5,
#          '提高': 2,
#          '了': 83,
#          '成本': 2,
#          '而': 10,
#          '損害': 2,
#          '關稅': 5,
#          '拜': 9,
#          '登上': 8,
#          '台': 7,
#          '後': 23,
#          '保留': 1,
#          '產': 1,
#          '電子產品': 2,
#          '服裝': 1,
#          '其他': 8,
#          '商品': 1,
#          '一個': 11,
#          '目的': 3,
#          '是': 89,
#          '為': 52,
#          '確保': 5,
#          '履行': 2,
#          '其': 8,
#          '在': 138,
#          '簽訂': 1,
#          '協議': 4,
#          '規定': 1,
#          '義務': 2,
#          '這些': 12,
#          '由': 11,
#          '進口商': 1,
#          '支付': 1,
#          '辦公室': 1,
#          '財政部': 1,
#          '發言人': 2,
#          '暫未': 1,
#          '對此': 2,
#          '做出': 2,
#          '回應': 1,
#          '對於': 9,
#          '是否': 5,
#          '打算': 1,
#          '執行': 1,
#          '川普': 17,
#          '達成': 2,
#          '或': 12,
#          '尋求': 4,
#          '延長': 2,
#          '該': 4,
#          '基本': 2,
#          '沒有': 14,
#          '發出信號': 1,
#          '官員': 7,
#          '曾': 4,
#          '預計': 1,
#          '評估': 2,
#          '工作': 5,
#          '將': 19,
#          '持續': 10,
#          '到': 23,
#          '今年': 18,
#          '秋季': 1,
#          '去年': 12,
#          '敗選': 2,
#          '不甘寂寞': 1,
#          '2024': 4,
#          '大選': 4,
#          '躍躍欲試': 1,
#          '因此': 8,
#          '超前': 2,
#          '部署': 1,
#          '團隊': 5,
#          '4': 6,
#          '致函': 2,
#          '川粉': 2,
#          '要求': 21,
#          '他們': 10,
#          '加入': 2,
#          '攜帶': 2,
#          '紅底': 1,
#          '金字': 1,
#          '川普卡': 5,
#          '行列': 1,
#          '不料': 1,
#          '此舉': 3,
#          '引來': 1,
#          '網友': 1,
#          '嘲笑': 1,
#          '批評者': 1,
#          '還將': 1,
#          '設計': 4,
#          '極右派': 1,
#          '納粹': 1,
#          '圖像': 1,
#          '相提並論': 1,
#          '獨立報': 1,
#          '暗示': 2,
#          '可能': 23,
#          '還會': 1,
#          '投入': 1,
#          '選戰': 1,
#          '而川普': 1,
#          '寄': 1,
#          '募款': 1,
#          '信給川粉': 1,
#          '讓': 17,
#          '四張': 1,
#          '正面': 1,
#          '有川普': 1,
#          '簽名': 1,
#          '卡片': 1,
#          '選擇': 5,
#          '一張': 3,
#          '當作': 1,
#          '因為川': 1,
#          '普認': 1,
#          '都': 40,
#          '很': 16,
#          '好看': 1,
#          '民眾': 1,
#          '決定': 4,
#          '總是': 1,
#          '知道': 4,
#          '什麼': 13,
#          '最好': 4,
#          '說': 27,
#          '不僅': 2,
#          '全美': 1,
#          '愛國者': 1,
#          '物品': 1,
#          '各位': 1,
#          '大力支持': 1,
#          '拯救': 1,
#          '運動': 1,
#          '標誌': 1,
#          '你們': 1,
#          '獲得': 4,
#          '我': 7,
#          '全部': 1,
#          '信任': 4,
#          '推特上': 1,
#          '批評': 4,
#          '人士': 2,
#          '認為': 30,
#          '邪教': 1,
#          '擁有': 3,
#          '特點': 1,
#          '像': 3,
#          '其中': 4,
#          '卡': 1,
#          '有': 53,
#          '隻': 1,
#          '金色': 1,
#          '老鷹': 1,
#          '像是': 2,
#          '納粹德國': 1,
#          '帝國': 1,
#          '之鷹': 1,
#          '圖徽': 1,
#          '近期': 5,
#          'YouGov': 1,
#          '民調': 2,
#          '數據': 6,
#          '顯示': 9,
#          '儘管': 7,
#          '提出': 7,
#          '所有': 3,
#          '陰謀論': 1,
#          '被': 14,
#          '徹底': 2,
#          '推翻': 1,
#          '但': 44,
#          '共和黨': 2,
#          '受訪者': 1,
#          '仍': 8,
#          '66%': 1,
#          '人': 13,
#          '相信': 1,
#          '川普才': 1,
#          '真正': 3,
#          '贏家': 2,
#          '然而': 2,
#          '另據': 1,
#          '昆尼皮': 1,
#          '亞克': 1,
#          '大學': 3,
#          '（': 52,
#          'Quinnipiac': 1,
#          '）': 47,
#          '公布': 5,
#          '每': 1,
#          '十名': 1,
#          '就': 16,
#          '六人': 1,
#          '參選': 1,
#          '來說': 3,
#          '件': 1,
#          '壞事': 2,
#          '財團法人': 1,
#          '生物': 2,
#          '技術開發': 1,
#          '中心': 4,
#          '董事長': 3,
#          '凃': 8,
#          '醒': 8,
#          '哲': 3,
#          '日前': 7,
#          '接受': 3,
#          '經濟日報': 2,
#          '專訪': 3,
#          '有個': 1,
#          '提議': 1,
#          '他': 52,
#          '台灣': 58,
#          '一定': 4,
#          '要': 29,
#          '支持': 8,
#          '國產': 12,
#          '疫苗': 89,
#          '因為': 12,
#          '很小': 1,
#          '現在': 20,
#          '兩': 4,
#          '三家': 5,
#          '公司': 8,
#          '生產': 15,
#          '一樣': 1,
#          '東西': 1,
#          '太多': 2,
#          '！': 7,
#          '整合': 3,
#          '起來': 4,
#          '不過': 7,
#          '話鋒一轉': 1,
#          '等到': 3,
#          '各家': 1,
#          '吃': 2,
#          '苦頭': 2,
#          '才能': 1,
#          '體會': 1,
#          '組': 1,
#          '國家隊': 2,
#          '哲曾': 1,
#          '擔任': 4,
#          'SARS': 1,
#          '期間': 1,
#          '衛生署': 1,
#          '署長': 1,
#          '衛福部': 1,
#          '前身': 1,
#          '做過': 1,
#          '嘉義': 1,
#          '市長': 1,
#          '立法委員': 1,
#          '從': 16,
#          '生技': 5,
#          '產業': 11,
#          '發展': 21,
#          '角度': 3,
#          '鼓吹': 1,
#          '三合一': 1,
#          '必要': 4,
#          '升級': 2,
#          '中介機構': 1,
#          '民間': 1,
#          '共同': 4,
#          '捐助': 1,
#          '成立': 5,
#          '透過': 4,
#          '產官': 1,
#          '學研': 1,
#          '開發': 6,
#          '關鍵技術': 1,
#          '培植': 1,
#          '延攬': 1,
#          '專業人才': 1,
#          '新冠': 23,
#          '疫情': 12,
#          '學醫': 1,
#          '出身': 1,
#          '哲有': 1,
#          '幾個': 2,
#          '推論': 1,
#          '一是': 3,
#          '由於': 11,
#          '基因': 3,
#          '飄移': 1,
#          'genetic': 1,
#          ' ': 22,
#          'drift': 1,
#          '又': 11,
#          '叫': 1,
#          '漂變': 1,
#          '指': 4,
#          '任何': 3,
#          '族群': 1,
#          '頻率': 1,
#          '發生': 8,
#          '非': 1,
#          '方向性': 1,
#          '隨機': 1,
#          '變化': 3,
#          '影響': 5,
#          '出現': 5,
#          '變種': 4,
#          '毒株': 1,
#          '會': 40,
#          '走向': 2,
#          '類': 1,
#          '流感': 4,
#          '化': 2,
#          '未來': 16,
#          '每年': 1,
#          '打': 8,
#          '不同': 6,
#          '年長者': 1,
#          '流感疫苗': 1,
#          '被稱作': 1,
#          '老人': 1,
#          '年針': 1,
#          '年輕人': 3,
#          '抵抗力': 1,
#          '強': 1,
#          '並不': 2,
#          '鼓勵': 3,
#          '施打': 6,
#          '這是': 8,
#          '研究': 11,
#          '一': 5,
#          '開始': 3,
#          '沒': 3,
#          '做': 10,
#          '18': 1,
#          '歲': 1,
#          '以下': 1,
#          '之故': 1,
#          '二是': 1,
#          '病毒': 10,
#          '弱化': 1,
#          '重症': 1,
#          '死亡': 1,
#          '人數': 2,
#          '下降': 3,
#          '傳播': 1,
#          '性': 2,
#          '仍強': 1,
#          '預期': 3,
#          '以後': 2,
#          '即使': 8,
#          '感染': 2,
#          '有藥': 1,
#          '可治': 1,
#          '感冒': 1,
#          '醫生': 1,
#          '一般': 3,
#          '建議': 2,
#          '多喝水': 1,
#          '給普': 1,
#          '拿': 4,
#          '疼': 1,
#          '好': 4,
#          '克': 1,
#          '不': 22,
#          '使用': 8,
#          '不見得': 3,
#          '三是': 2,
#          '隨著': 2,
#          '身體': 1,
#          '內': 4,
#          '抗體': 3,
#          '量': 2,
#          '漸漸': 1,
#          '不夠': 3,
#          '這樣': 4,
#          '第三': 4,
#          '劑以': 1,
#          '強化': 5,
#          '情形': 2,
#          '增加': 2,
#          '高': 4,
#          '鋅元素': 1,
#          '攝取': 1,
#          '可以': 16,
#          '抵禦': 1,
#          '入侵': 1,
#          '還在': 1,
#          '提到': 4,
#          '概念': 3,
#          '：': 31,
#          '不會': 10,
#          '想': 4,
#          '這個': 3,
#          '道理': 1,
#          '適用': 2,
#          '今天': 3,
#          '很多': 6,
#          '看待': 1,
#          '評價': 1,
#          '上': 34,
#          '指出': 13,
#          '能否': 1,
#          '獲取': 2,
#          '三個': 3,
#          '條件': 1,
#          '透明度': 2,
#          '安全性': 1,
#          '保護': 2,
#          '力': 3,
#          '有關': 3,
#          '臨床': 1,
#          '很難': 4,
#          '改以': 1,
#          '多少': 2,
#          '來': 11,
#          '判斷': 1,
#          '\u3000': 1,
#          '月台': 2,
#          '灣': 2,
#          '大': 8,
#          '爆發': 6,
#          '荒': 1,
#          '重擊': 1,
#          '人心': 1,
#          '進度': 4,
#          '嚴重': 3,
#          '落後': 2,
#          '甚而': 2,
#          '演變成': 1,
#          '政治事件': 1,
#          '哲認': 2,
#          '最大': 4,
#          '困難': 5,
#          '第三期': 1,
#          '比': 2,
#          '別人': 2,
#          '慢': 1,
#          '產品': 4,
#          '上市': 9,
#          '到時候': 1,
#          '已經': 6,
#          '那麼': 4,
#          '多': 15,
#          '輝瑞': 7,
#          'BNT': 8,
#          '進來': 1,
#          '哪有': 1,
#          '容身之處': 1,
#          '？': 28,
#          '所以': 2,
#          '時行': 1,
#          '銷會': 1,
#          '問題': 34,
#          '除了': 3,
#          '國內': 5,
#          '市場': 6,
#          '還可': 1,
#          '以': 17,
#          '半買半送': 1,
#          '方式': 5,
#          '開拓': 1,
#          '國外市場': 1,
#          '了解': 6,
#          '首先': 3,
#          '國人': 1,
#          '安全': 24,
#          '才': 6,
#          '依靠': 1,
#          '不用': 1,
#          '看': 7,
#          '眼色': 1,
#          '；': 33,
#          '其次': 3,
#          '通過': 10,
#          '緊急': 3,
#          '之後': 6,
#          '趕快': 2,
#          '推動': 8,
#          '高端': 4,
#          '製造': 6,
#          '不是': 4,
#          '雖然': 8,
#          '一下子': 1,
#          '出': 6,
#          '100': 4,
#          '萬劑': 4,
#          '500': 4,
#          '源源不絕': 1,
#          '供應': 3,
#          '生存': 1,
#          '哲說': 1,
#          '比照': 1,
#          '國家': 35,
#          '口罩': 1,
#          '隊': 1,
#          '因為給': 1,
#          '健康人': 1,
#          '需要量': 1,
#          '不能': 11,
#          '太貴': 1,
#          '利潤': 1,
#          '小小的': 1,
#          '實在': 1,
#          '需要': 12,
#          '集全': 1,
#          '之力': 1,
#          '一家': 3,
#          '比不上': 1,
#          'GSK': 1,
#          '指荷商': 1,
#          '葛蘭素': 1,
#          '史克': 1,
#          '集團': 6,
#          '規模': 2,
#          '現有': 1,
#          '國光': 1,
#          '聯亞': 1,
#          '一起': 2,
#          '藥品': 1,
#          '幾十種': 1,
#          '品牌': 1,
#          '不然': 1,
#          '國衛院': 1,
#          '可': 6,
#          '參與': 4,
#          '公私合營': 1,
#          '底下': 1,
#          '研發': 10,
#          '單位': 2,
#          '宣導': 1,
#          '工廠': 3,
#          '生產線': 3,
#          '出面': 1,
#          '號召': 1,
#          '憑藉': 2,
#          '力道': 1,
#          '援助': 1,
#          '邦交國': 1,
#          '上海': 3,
#          '復星': 2,
#          '去年初': 1,
#          '即': 2,
#          '取得': 6,
#          '大中華區': 2,
#          '代理權': 2,
#          '鴻海': 2,
#          '創辦人': 3,
#          '郭台銘': 2,
#          '台積電': 2,
#          '劉德音': 1,
#          '慈濟': 1,
#          '復': 1,
#          '採購': 4,
#          '共': 4,
#          '1': 4,
#          ',': 4,
#          '轉贈給': 1,
#          '分配': 1,
#          '過程': 1,
#          '引發': 3,
#          '不少': 3,
#          '爭議': 1,
#          '政治': 14,
#          '非經濟': 1,
#          '用詞': 2,
#          '這種': 4,
#          '情況': 8,
#          '不好': 2,
#          '引起': 1,
#          '疑慮': 2,
#          '例如': 4,
#          '方會': 1,
#          '擔心': 3,
#          '是從': 4,
#          '原廠': 1,
#          '嗎': 4,
#          '層面': 5,
#          '顧慮': 2,
#          '我們': 10,
#          '外商': 1,
#          '從簽': 1,
#          '亞洲區': 1,
#          '處理': 5,
#          '從美中': 1,
#          '大國': 10,
#          '角力': 3,
#          '來看': 5,
#          '依據': 4,
#          '道': 1,
#          '考量': 2,
#          '但是': 10,
#          '普遍': 2,
#          '作為': 4,
#          '外交': 14,
#          '工具': 2,
#          '紅利': 1,
#          '以來': 6,
#          '中國': 133,
#          '率先': 1,
#          '展開': 4,
#          '戰': 5,
#          '逼': 1,
#          '著': 2,
#          '跟上來': 1,
#          '雖不談': 1,
#          '賺回': 1,
#          '優勢': 1,
#          '相比之下': 1,
#          '質和量': 1,
#          '勝出': 1,
#          '許多': 5,
#          '兩劑': 2,
#          '東南亞': 4,
#          '因再': 1,
#          '已': 15,
#          '轉向': 2,
#          '美歐': 7,
#          '2021': 1,
#          '全面': 8,
#          '散播': 1,
#          '美中': 14,
#          '爭霸': 1,
#          '開出': 1,
#          '新戰場': 3,
#          '總統': 12,
#          '6': 14,
#          '10': 10,
#          '英國': 4,
#          '參加': 1,
#          'G7': 7,
#          '峰會時': 1,
#          '今': 1,
#          '明年': 4,
#          '無條件': 2,
#          '捐贈': 7,
#          '億支': 2,
#          '形容': 4,
#          '無獨有偶': 1,
#          '月底': 5,
#          '北京': 9,
#          '大興': 1,
#          '悄悄': 1,
#          '誕生': 1,
#          '一座': 1,
#          '三級': 1,
#          '防護': 1,
#          'P3': 1,
#          '標準': 4,
#          '等級': 1,
#          '產能': 3,
#          '設定': 1,
#          '國藥': 3,
#          '劉敬楨': 1,
#          '稱': 1,
#          '它': 2,
#          '全球': 17,
#          '『': 2,
#          '兵工廠': 2,
#          '』': 2,
#          '世衛': 2,
#          '組織': 3,
#          '才剛': 1,
#          '把': 9,
#          '生物製品': 1,
#          '研究所': 1,
#          '列入': 3,
#          '清單': 7,
#          '以新': 1,
#          '印太': 21,
#          '戰略': 21,
#          '圍堵': 6,
#          '促使': 1,
#          '這場': 1,
#          '霸權': 2,
#          '之爭': 1,
#          '變成': 3,
#          '軍火庫': 1,
#          '發威': 1,
#          '美': 27,
#          '邁入': 1,
#          '劑': 2,
#          '競賽': 2,
#          '鹿死誰手': 1,
#          '結局': 1,
#          '未定': 1,
#          '主辦': 1,
#          '亞洲': 5,
#          '大會': 1,
#          '上周': 1,
#          '閉幕': 1,
#          '主席': 6,
#          '李鍾熙': 2,
#          '分析': 10,
#          '兩國': 10,
#          '制度': 3,
#          '競爭': 9,
#          '只是': 4,
#          '科技': 45,
#          '前': 9,
#          '川普任': 1,
#          '荒腔': 1,
#          '走板': 1,
#          '行徑': 1,
#          '備受': 1,
#          '針對': 7,
#          '採取': 4,
#          '快速': 2,
#          '大膽': 1,
#          '計畫': 12,
#          '神速': 2,
#          '行動': 8,
#          'Operation': 1,
#          'Wrap': 1,
#          'Speed': 1,
#          '卻是': 2,
#          '今日': 1,
#          '穩居': 1,
#          '梯隊': 1,
#          '關鍵': 4,
#          '該計畫': 1,
#          '分銷': 1,
#          '等': 31,
#          '訂出': 1,
#          '目標': 6,
#          '選出': 1,
#          '莫': 2,
#          '德納': 2,
#          'AZ': 1,
#          '嬌生': 2,
#          '廠商': 1,
#          '投注': 1,
#          '120': 1,
#          '億美元': 6,
#          '保證': 2,
#          '成功': 4,
#          '收購': 2,
#          '協助': 3,
#          '短時間': 1,
#          '招募': 1,
#          '萬到': 1,
#          '15': 2,
#          '萬名': 1,
#          '受試者': 1,
#          '實驗': 1,
#          '十個月': 1,
#          '食品': 1,
#          '藥物': 2,
#          '管理局': 1,
#          'FDA': 1,
#          '授權': 1,
#          '許可': 3,
#          'EUA': 2,
#          '創下': 1,
#          '歷史': 3,
#          '速度': 3,
#          '最快': 1,
#          '紀錄': 1,
#          '隨後': 4,
#          '一一': 1,
#          '如果': 15,
#          '加上': 2,
#          '第': 6,
#          '3': 13,
#          '季將': 1,
#          '申請': 2,
#          '諾瓦': 1,
#          '瓦克斯': 1,
#          'Novavax': 1,
#          '這': 14,
#          '四大': 1,
#          '奠定': 1,
#          '地位': 3,
#          '如果說': 1,
#          '戰一役': 1,
#          '發言權': 1,
#          '21': 2,
#          '武漢': 2,
#          '封城': 1,
#          '前兩天': 1,
#          '科技部': 2,
#          '召開': 2,
#          '一項': 2,
#          '會議': 9,
#          '重要性': 5,
#          '忽略': 1,
#          '全力': 1,
#          '當時': 2,
#          '注意': 1,
#          '確立': 2,
#          '五': 1,
#          '路線': 3,
#          '並行': 2,
#          '厚植': 1,
#          '得以': 1,
#          '突破': 5,
#          '強勢': 2,
#          '壓制': 1,
#          '本錢': 1,
#          '採行': 3,
#          '五種': 1,
#          '技術': 5,
#          '滅活': 1,
#          '核酸': 2,
#          '重組': 4,
#          '蛋白': 1,
#          '腺病毒': 1,
#          '載體': 2,
#          '減毒': 1,
#          '病體': 1,
#          '相': 1,
#          '較': 2,
#          '歐美國家': 1,
#          '押寶': 2,
#          'mRNA': 1,
#          '多路': 1,
#          '並進': 2,
#          '呢': 6,
#          '媒體': 6,
#          '解讀': 2,
#          '失敗率': 1,
#          '五路': 2,
#          '種類': 1,
#          '越': 1,
#          '可依': 1,
#          '接種': 2,
#          '且': 5,
#          '變異': 2,
#          '替代': 1,
#          '燒錢': 1,
#          '過去': 10,
#          '高科技': 2,
#          '領域': 7,
#          '卡脖子': 2,
#          '限制': 5,
#          '過太多': 1,
#          '自主': 4,
#          '面臨': 6,
#          '三大': 2,
#          '威脅': 3,
#          '買不到': 1,
#          '二': 3,
#          '只能': 1,
#          '買': 2,
#          '高價': 1,
#          '三': 1,
#          '買到': 1,
#          '還有': 4,
#          '委屈': 1,
#          '國格': 1,
#          '避免': 6,
#          '再': 5,
#          '掐住': 1,
#          '脖子': 1,
#          '科研': 1,
#          '攻關': 1,
#          '應急': 1,
#          '項目': 4,
#          '小組': 1,
#          '主導': 2,
#          '統籌': 1,
#          '科研單位': 1,
#          '國有企業': 1,
#          '提供': 6,
#          '助力': 1,
#          '7': 10,
#          '16': 4,
#          '國務院新聞辦': 1,
#          '宣布': 5,
#          '達': 1,
#          '50': 1,
#          '億劑': 6,
#          '並與': 1,
#          'WHO': 1,
#          '平台': 2,
#          'COVAX': 2,
#          '簽約': 1,
#          '將在': 1,
#          '前向': 1,
#          '1.1': 2,
#          '積極': 5,
#          '拓展': 1,
#          '出海口': 1,
#          '沒閒著': 1,
#          '中旬': 2,
#          '將分': 1,
#          '2': 4,
#          '億': 2,
#          '上半年': 3,
#          '給': 6,
#          '白宮': 3,
#          '盤點': 1,
#          '至今': 2,
#          '捐': 1,
#          '逾': 1,
#          '給台灣': 1,
#          '65': 1,
#          '亞太地區': 1,
#          '排名': 8,
#          '第四': 1,
#          '前三名': 1,
#          '目前': 8,
#          '嚴峻': 2,
#          '印尼': 2,
#          '菲律賓': 2,
#          '越南': 1,
#          '也將': 2,
#          '送': 2,
#          '規劃': 2,
#          '中低收入': 1,
#          '抗疫': 1,
#          '這項': 10,
#          '大規模': 1,
#          '釋苗': 1,
#          '搭配': 1,
#          '重返': 2,
#          '結盟': 2,
#          ...})

# %%
# 準備一個有經過stop word 處理的 counter
from collections import Counter
seg_stop_counter = Counter(seg_stop_words_list)
seg_stop_counter
# Out:
# Counter({'美國': 165,
#          '零售商': 1,
#          '晶片': 6,
#          '製造商': 1,
#          '農民': 1,
#          '其它': 1,
#          '36': 1,
#          '個': 9,
#          '具有': 3,
#          '影響力': 9,
#          '商業': 1,
#          '團體': 1,
#          '於': 3,
#          '當地': 2,
#          '時間': 5,
#          '致信': 1,
#          '貿易': 10,
#          '代表': 7,
#          '戴琪': 1,
#          '財政部長': 1,
#          '葉倫': 1,
#          '呼籲': 3,
#          '拜登': 53,
#          '政府': 32,
#          '重啟': 2,
#          '大陸': 135,
#          '談判': 2,
#          '削減': 1,
#          '進口關稅': 1,
#          '以免': 1,
#          '拖累': 1,
#          '經濟': 19,
#          '第一': 2,
#          '財經': 1,
#          '報導': 7,
#          '信中': 2,
#          '表示': 16,
#          '方面': 6,
#          '達到': 2,
#          '2020': 3,
#          '第一階段': 3,
#          '貿易協定': 1,
#          '重要': 11,
#          '基準': 1,
#          '承諾': 1,
#          '包括': 11,
#          '金融機構': 1,
#          '開放市場': 1,
#          '減少': 1,
#          '出口': 8,
#          '農產品': 1,
#          '一些': 6,
#          '監管': 7,
#          '障礙': 3,
#          '美國政府': 5,
#          '制定': 3,
#          '政策': 10,
#          '應該': 14,
#          '優先': 1,
#          '考慮': 7,
#          '本國': 2,
#          '工人': 1,
#          '利益': 10,
#          '取消': 3,
#          '提高': 2,
#          '成本': 2,
#          '損害': 2,
#          '關稅': 5,
#          '登上': 8,
#          '保留': 1,
#          '電子產品': 2,
#          '服裝': 1,
#          '其他': 8,
#          '商品': 1,
#          '目的': 3,
#          '確保': 5,
#          '履行': 2,
#          '簽訂': 1,
#          '協議': 4,
#          '規定': 1,
#          '義務': 2,
#          '這些': 12,
#          '進口商': 1,
#          '支付': 1,
#          '辦公室': 1,
#          '財政部': 1,
#          '發言人': 2,
#          '暫未': 1,
#          '對此': 2,
#          '做出': 2,
#          '回應': 1,
#          '對於': 9,
#          '打算': 1,
#          '執行': 1,
#          '川普': 17,
#          '達成': 2,
#          '尋求': 4,
#          '延長': 2,
#          '基本': 2,
#          '發出信號': 1,
#          '官員': 7,
#          '預計': 1,
#          '評估': 2,
#          '工作': 5,
#          '持續': 10,
#          '今年': 18,
#          '秋季': 1,
#          '去年': 12,
#          '敗選': 2,
#          '不甘寂寞': 1,
#          '2024': 4,
#          '大選': 4,
#          '躍躍欲試': 1,
#          '因此': 8,
#          '超前': 2,
#          '部署': 1,
#          '團隊': 5,
#          '致函': 2,
#          '川粉': 2,
#          '要求': 21,
#          '加入': 2,
#          '攜帶': 2,
#          '紅底': 1,
#          '金字': 1,
#          '川普卡': 5,
#          '行列': 1,
#          '不料': 1,
#          '此舉': 3,
#          '引來': 1,
#          '網友': 1,
#          '嘲笑': 1,
#          '批評者': 1,
#          '還將': 1,
#          '設計': 4,
#          '極右派': 1,
#          '納粹': 1,
#          '圖像': 1,
#          '相提並論': 1,
#          '獨立報': 1,
#          '暗示': 2,
#          '可能': 23,
#          '還會': 1,
#          '投入': 1,
#          '選戰': 1,
#          '而川普': 1,
#          '募款': 1,
#          '信給川粉': 1,
#          '四張': 1,
#          '正面': 1,
#          '有川普': 1,
#          '簽名': 1,
#          '卡片': 1,
#          '選擇': 5,
#          '一張': 3,
#          '當作': 1,
#          '好看': 1,
#          '民眾': 1,
#          '決定': 4,
#          '總是': 1,
#          '知道': 4,
#          '什麼': 13,
#          '最好': 4,
#          '不僅': 2,
#          '全美': 1,
#          '愛國者': 1,
#          '物品': 1,
#          '各位': 1,
#          '大力支持': 1,
#          '拯救': 1,
#          '運動': 1,
#          '標誌': 1,
#          '獲得': 4,
#          '全部': 1,
#          '信任': 4,
#          '推特上': 1,
#          '批評': 4,
#          '人士': 2,
#          '認為': 30,
#          '邪教': 1,
#          '擁有': 3,
#          '特點': 1,
#          '其中': 4,
#          '隻': 1,
#          '金色': 1,
#          '老鷹': 1,
#          '像是': 2,
#          '納粹德國': 1,
#          '帝國': 1,
#          '之鷹': 1,
#          '圖徽': 1,
#          '近期': 5,
#          'YouGov': 1,
#          '民調': 2,
#          '數據': 6,
#          '顯示': 9,
#          '儘管': 7,
#          '提出': 7,
#          '所有': 3,
#          '陰謀論': 1,
#          '徹底': 2,
#          '推翻': 1,
#          '共和黨': 2,
#          '受訪者': 1,
#          '66%': 1,
#          '相信': 1,
#          '川普才': 1,
#          '真正': 3,
#          '贏家': 2,
#          '然而': 2,
#          '另據': 1,
#          '昆尼皮': 1,
#          '亞克': 1,
#          '大學': 3,
#          'Quinnipiac': 1,
#          '公布': 5,
#          '每': 1,
#          '十名': 1,
#          '六人': 1,
#          '參選': 1,
#          '來說': 3,
#          '件': 1,
#          '壞事': 2,
#          '財團法人': 1,
#          '生物': 2,
#          '技術開發': 1,
#          '中心': 4,
#          '董事長': 3,
#          '哲': 3,
#          '日前': 7,
#          '接受': 3,
#          '經濟日報': 2,
#          '專訪': 3,
#          '有個': 1,
#          '提議': 1,
#          '台灣': 58,
#          '一定': 4,
#          '支持': 8,
#          '國產': 12,
#          '疫苗': 89,
#          '因為': 12,
#          '很小': 1,
#          '現在': 20,
#          '兩': 4,
#          '三家': 5,
#          '公司': 8,
#          '生產': 15,
#          '一樣': 1,
#          '東西': 1,
#          '太多': 2,
#          '整合': 3,
#          '起來': 4,
#          '不過': 7,
#          '話鋒一轉': 1,
#          '等到': 3,
#          '各家': 1,
#          '吃': 2,
#          '苦頭': 2,
#          '才能': 1,
#          '體會': 1,
#          '國家隊': 2,
#          '哲曾': 1,
#          '擔任': 4,
#          'SARS': 1,
#          '期間': 1,
#          '衛生署': 1,
#          '署長': 1,
#          '衛福部': 1,
#          '前身': 1,
#          '做過': 1,
#          '嘉義': 1,
#          '市長': 1,
#          '立法委員': 1,
#          '生技': 5,
#          '產業': 11,
#          '發展': 21,
#          '角度': 3,
#          '鼓吹': 1,
#          '三合一': 1,
#          '必要': 4,
#          '升級': 2,
#          '中介機構': 1,
#          '民間': 1,
#          '共同': 4,
#          '捐助': 1,
#          '成立': 5,
#          '透過': 4,
#          '產官': 1,
#          '學研': 1,
#          '開發': 6,
#          '關鍵技術': 1,
#          '培植': 1,
#          '延攬': 1,
#          '專業人才': 1,
#          '新冠': 23,
#          '疫情': 12,
#          '學醫': 1,
#          '出身': 1,
#          '哲有': 1,
#          '幾個': 2,
#          '推論': 1,
#          '一是': 3,
#          '由於': 11,
#          '基因': 3,
#          '飄移': 1,
#          'genetic': 1,
#          'drift': 1,
#          '叫': 1,
#          '漂變': 1,
#          '指': 4,
#          '任何': 3,
#          '族群': 1,
#          '頻率': 1,
#          '發生': 8,
#          '非': 1,
#          '方向性': 1,
#          '隨機': 1,
#          '變化': 3,
#          '影響': 5,
#          '出現': 5,
#          '變種': 4,
#          '毒株': 1,
#          '會': 40,
#          '走向': 2,
#          '類': 1,
#          '流感': 4,
#          '化': 2,
#          '未來': 16,
#          '每年': 1,
#          '打': 8,
#          '不同': 6,
#          '年長者': 1,
#          '流感疫苗': 1,
#          '被稱作': 1,
#          '老人': 1,
#          '年針': 1,
#          '年輕人': 3,
#          '抵抗力': 1,
#          '強': 1,
#          '並不': 2,
#          '鼓勵': 3,
#          '施打': 6,
#          '這是': 8,
#          '研究': 11,
#          '開始': 3,
#          '沒': 3,
#          '做': 10,
#          '18': 1,
#          '歲': 1,
#          '以下': 1,
#          '之故': 1,
#          '二是': 1,
#          '病毒': 10,
#          '弱化': 1,
#          '重症': 1,
#          '死亡': 1,
#          '人數': 2,
#          '下降': 3,
#          '傳播': 1,
#          '性': 2,
#          '仍強': 1,
#          '預期': 3,
#          '以後': 2,
#          '即使': 8,
#          '感染': 2,
#          '有藥': 1,
#          '可治': 1,
#          '感冒': 1,
#          '醫生': 1,
#          '一般': 3,
#          '建議': 2,
#          '多喝水': 1,
#          '給普': 1,
#          '拿': 4,
#          '疼': 1,
#          '好': 4,
#          '克': 1,
#          '使用': 8,
#          '不見得': 3,
#          '三是': 2,
#          '隨著': 2,
#          '身體': 1,
#          '內': 4,
#          '抗體': 3,
#          '量': 2,
#          '漸漸': 1,
#          '不夠': 3,
#          '這樣': 4,
#          '第三': 4,
#          '劑以': 1,
#          '強化': 5,
#          '情形': 2,
#          '增加': 2,
#          '高': 4,
#          '鋅元素': 1,
#          '攝取': 1,
#          '抵禦': 1,
#          '入侵': 1,
#          '還在': 1,
#          '提到': 4,
#          '概念': 3,
#          '不會': 10,
#          '想': 4,
#          '這個': 3,
#          '道理': 1,
#          '適用': 2,
#          '今天': 3,
#          '很多': 6,
#          '看待': 1,
#          '評價': 1,
#          '指出': 13,
#          '能否': 1,
#          '獲取': 2,
#          '三個': 3,
#          '條件': 1,
#          '透明度': 2,
#          '安全性': 1,
#          '保護': 2,
#          '力': 3,
#          '有關': 3,
#          '臨床': 1,
#          '很難': 4,
#          '改以': 1,
#          '多少': 2,
#          '判斷': 1,
#          '\u3000': 1,
#          '月台': 2,
#          '灣': 2,
#          '爆發': 6,
#          '荒': 1,
#          '重擊': 1,
#          '人心': 1,
#          '進度': 4,
#          '嚴重': 3,
#          '落後': 2,
#          '甚而': 2,
#          '演變成': 1,
#          '政治事件': 1,
#          '哲認': 2,
#          '最大': 4,
#          '困難': 5,
#          '第三期': 1,
#          '比': 2,
#          '別人': 2,
#          '慢': 1,
#          '產品': 4,
#          '上市': 9,
#          '到時候': 1,
#          '已經': 6,
#          '那麼': 4,
#          '多': 15,
#          '輝瑞': 7,
#          'BNT': 8,
#          '進來': 1,
#          '哪有': 1,
#          '容身之處': 1,
#          '所以': 2,
#          '時行': 1,
#          '銷會': 1,
#          '問題': 34,
#          '除了': 3,
#          '國內': 5,
#          '市場': 6,
#          '還可': 1,
#          '以': 17,
#          '半買半送': 1,
#          '方式': 5,
#          '開拓': 1,
#          '國外市場': 1,
#          '了解': 6,
#          '首先': 3,
#          '國人': 1,
#          '安全': 24,
#          '依靠': 1,
#          '不用': 1,
#          '看': 7,
#          '眼色': 1,
#          '其次': 3,
#          '通過': 10,
#          '緊急': 3,
#          '之後': 6,
#          '趕快': 2,
#          '推動': 8,
#          '高端': 4,
#          '製造': 6,
#          '不是': 4,
#          '雖然': 8,
#          '一下子': 1,
#          '100': 4,
#          '萬劑': 4,
#          '500': 4,
#          '源源不絕': 1,
#          '供應': 3,
#          '生存': 1,
#          '哲說': 1,
#          '比照': 1,
#          '國家': 35,
#          '口罩': 1,
#          '隊': 1,
#          '因為給': 1,
#          '健康人': 1,
#          '需要量': 1,
#          '不能': 11,
#          '太貴': 1,
#          '利潤': 1,
#          '小小的': 1,
#          '實在': 1,
#          '需要': 12,
#          '集全': 1,
#          '之力': 1,
#          '一家': 3,
#          '比不上': 1,
#          'GSK': 1,
#          '指荷商': 1,
#          '葛蘭素': 1,
#          '史克': 1,
#          '集團': 6,
#          '規模': 2,
#          '現有': 1,
#          '國光': 1,
#          '聯亞': 1,
#          '一起': 2,
#          '藥品': 1,
#          '幾十種': 1,
#          '品牌': 1,
#          '不然': 1,
#          '國衛院': 1,
#          '參與': 4,
#          '公私合營': 1,
#          '底下': 1,
#          '研發': 10,
#          '單位': 2,
#          '宣導': 1,
#          '工廠': 3,
#          '生產線': 3,
#          '出面': 1,
#          '號召': 1,
#          '憑藉': 2,
#          '力道': 1,
#          '援助': 1,
#          '邦交國': 1,
#          '上海': 3,
#          '復星': 2,
#          '去年初': 1,
#          '即': 2,
#          '取得': 6,
#          '大中華區': 2,
#          '代理權': 2,
#          '鴻海': 2,
#          '創辦人': 3,
#          '郭台銘': 2,
#          '台積電': 2,
#          '劉德音': 1,
#          '慈濟': 1,
#          '復': 1,
#          '採購': 4,
#          '1': 4,
#          '轉贈給': 1,
#          '分配': 1,
#          '過程': 1,
#          '引發': 3,
#          '不少': 3,
#          '爭議': 1,
#          '政治': 14,
#          '非經濟': 1,
#          '用詞': 2,
#          '這種': 4,
#          '情況': 8,
#          '不好': 2,
#          '引起': 1,
#          '疑慮': 2,
#          '例如': 4,
#          '方會': 1,
#          '擔心': 3,
#          '是從': 4,
#          '原廠': 1,
#          '層面': 5,
#          '顧慮': 2,
#          '外商': 1,
#          '從簽': 1,
#          '亞洲區': 1,
#          '處理': 5,
#          '從美中': 1,
#          '大國': 10,
#          '角力': 3,
#          '來看': 5,
#          '依據': 4,
#          '道': 1,
#          '考量': 2,
#          '但是': 10,
#          '普遍': 2,
#          '作為': 4,
#          '外交': 14,
#          '工具': 2,
#          '紅利': 1,
#          '以來': 6,
#          '中國': 133,
#          '率先': 1,
#          '展開': 4,
#          '戰': 5,
#          '逼': 1,
#          '跟上來': 1,
#          '雖不談': 1,
#          '賺回': 1,
#          '優勢': 1,
#          '相比之下': 1,
#          '質和量': 1,
#          '勝出': 1,
#          '許多': 5,
#          '兩劑': 2,
#          '東南亞': 4,
#          '因再': 1,
#          '已': 15,
#          '轉向': 2,
#          '美歐': 7,
#          '2021': 1,
#          '全面': 8,
#          '散播': 1,
#          '美中': 14,
#          '爭霸': 1,
#          '開出': 1,
#          '新戰場': 3,
#          '總統': 12,
#          '6': 14,
#          '10': 10,
#          '英國': 4,
#          '參加': 1,
#          'G7': 7,
#          '峰會時': 1,
#          '今': 1,
#          '明年': 4,
#          '無條件': 2,
#          '捐贈': 7,
#          '億支': 2,
#          '形容': 4,
#          '無獨有偶': 1,
#          '月底': 5,
#          '北京': 9,
#          '大興': 1,
#          '悄悄': 1,
#          '誕生': 1,
#          '一座': 1,
#          '三級': 1,
#          '防護': 1,
#          'P3': 1,
#          '標準': 4,
#          '等級': 1,
#          '產能': 3,
#          '設定': 1,
#          '國藥': 3,
#          '劉敬楨': 1,
#          '稱': 1,
#          '它': 2,
#          '全球': 17,
#          '『': 2,
#          '兵工廠': 2,
#          '』': 2,
#          '世衛': 2,
#          '組織': 3,
#          '才剛': 1,
#          '把': 9,
#          '生物製品': 1,
#          '研究所': 1,
#          '列入': 3,
#          '清單': 7,
#          '以新': 1,
#          '印太': 21,
#          '戰略': 21,
#          '圍堵': 6,
#          '促使': 1,
#          '這場': 1,
#          '霸權': 2,
#          '之爭': 1,
#          '變成': 3,
#          '軍火庫': 1,
#          '發威': 1,
#          '美': 27,
#          '邁入': 1,
#          '劑': 2,
#          '競賽': 2,
#          '鹿死誰手': 1,
#          '結局': 1,
#          '未定': 1,
#          '主辦': 1,
#          '亞洲': 5,
#          '大會': 1,
#          '上周': 1,
#          '閉幕': 1,
#          '主席': 6,
#          '李鍾熙': 2,
#          '分析': 10,
#          '兩國': 10,
#          '制度': 3,
#          '競爭': 9,
#          '只是': 4,
#          '科技': 45,
#          '前': 9,
#          '川普任': 1,
#          '荒腔': 1,
#          '走板': 1,
#          '行徑': 1,
#          '備受': 1,
#          '針對': 7,
#          '採取': 4,
#          '快速': 2,
#          '大膽': 1,
#          '計畫': 12,
#          '神速': 2,
#          '行動': 8,
#          'Operation': 1,
#          'Wrap': 1,
#          'Speed': 1,
#          '卻是': 2,
#          '今日': 1,
#          '穩居': 1,
#          '梯隊': 1,
#          '關鍵': 4,
#          '該計畫': 1,
#          '分銷': 1,
#          '訂出': 1,
#          '目標': 6,
#          '選出': 1,
#          '莫': 2,
#          '德納': 2,
#          'AZ': 1,
#          '嬌生': 2,
#          '廠商': 1,
#          '投注': 1,
#          '120': 1,
#          '億美元': 6,
#          '保證': 2,
#          '成功': 4,
#          '收購': 2,
#          '協助': 3,
#          '短時間': 1,
#          '招募': 1,
#          '萬到': 1,
#          '15': 2,
#          '萬名': 1,
#          '受試者': 1,
#          '實驗': 1,
#          '十個月': 1,
#          '食品': 1,
#          '藥物': 2,
#          '管理局': 1,
#          'FDA': 1,
#          '授權': 1,
#          '許可': 3,
#          'EUA': 2,
#          '創下': 1,
#          '歷史': 3,
#          '速度': 3,
#          '最快': 1,
#          '紀錄': 1,
#          '隨後': 4,
#          '一一': 1,
#          '如果': 15,
#          '加上': 2,
#          '第': 6,
#          '3': 13,
#          '季將': 1,
#          '申請': 2,
#          '諾瓦': 1,
#          '瓦克斯': 1,
#          'Novavax': 1,
#          '這': 14,
#          '四大': 1,
#          '奠定': 1,
#          '地位': 3,
#          '如果說': 1,
#          '戰一役': 1,
#          '發言權': 1,
#          '21': 2,
#          '武漢': 2,
#          '封城': 1,
#          '前兩天': 1,
#          '科技部': 2,
#          '召開': 2,
#          '一項': 2,
#          '會議': 9,
#          '重要性': 5,
#          '忽略': 1,
#          '全力': 1,
#          '當時': 2,
#          '注意': 1,
#          '確立': 2,
#          '五': 1,
#          '路線': 3,
#          '並行': 2,
#          '厚植': 1,
#          '得以': 1,
#          '突破': 5,
#          '強勢': 2,
#          '壓制': 1,
#          '本錢': 1,
#          '採行': 3,
#          '五種': 1,
#          '技術': 5,
#          '滅活': 1,
#          '核酸': 2,
#          '重組': 4,
#          '蛋白': 1,
#          '腺病毒': 1,
#          '載體': 2,
#          '減毒': 1,
#          '病體': 1,
#          '相': 1,
#          '較': 2,
#          '歐美國家': 1,
#          '押寶': 2,
#          'mRNA': 1,
#          '多路': 1,
#          '並進': 2,
#          '呢': 6,
#          '媒體': 6,
#          '解讀': 2,
#          '失敗率': 1,
#          '五路': 2,
#          '種類': 1,
#          '越': 1,
#          '可依': 1,
#          '接種': 2,
#          '且': 5,
#          '變異': 2,
#          '替代': 1,
#          '燒錢': 1,
#          '過去': 10,
#          '高科技': 2,
#          '領域': 7,
#          '卡脖子': 2,
#          '限制': 5,
#          '過太多': 1,
#          '自主': 4,
#          '面臨': 6,
#          '三大': 2,
#          '威脅': 3,
#          '買不到': 1,
#          '二': 3,
#          '只能': 1,
#          '買': 2,
#          '高價': 1,
#          '三': 1,
#          '買到': 1,
#          '還有': 4,
#          '委屈': 1,
#          '國格': 1,
#          '避免': 6,
#          '再': 5,
#          '掐住': 1,
#          '脖子': 1,
#          '科研': 1,
#          '攻關': 1,
#          '應急': 1,
#          '項目': 4,
#          '小組': 1,
#          '主導': 2,
#          '統籌': 1,
#          '科研單位': 1,
#          '國有企業': 1,
#          '提供': 6,
#          '助力': 1,
#          '國務院新聞辦': 1,
#          '宣布': 5,
#          '達': 1,
#          '50': 1,
#          '億劑': 6,
#          '並與': 1,
#          'WHO': 1,
#          '平台': 2,
#          'COVAX': 2,
#          '簽約': 1,
#          '將在': 1,
#          '前向': 1,
#          '1.1': 2,
#          '積極': 5,
#          '拓展': 1,
#          '出海口': 1,
#          '沒閒著': 1,
#          '中旬': 2,
#          '將分': 1,
#          '2': 4,
#          '億': 2,
#          '上半年': 3,
#          '給': 6,
#          '白宮': 3,
#          '盤點': 1,
#          '至今': 2,
#          '捐': 1,
#          '逾': 1,
#          '給台灣': 1,
#          '65': 1,
#          '亞太地區': 1,
#          '排名': 8,
#          '第四': 1,
#          '前三名': 1,
#          '目前': 8,
#          '嚴峻': 2,
#          '印尼': 2,
#          '菲律賓': 2,
#          '越南': 1,
#          '也將': 2,
#          '送': 2,
#          '規劃': 2,
#          '中低收入': 1,
#          '抗疫': 1,
#          '大規模': 1,
#          '釋苗': 1,
#          '搭配': 1,
#          '重返': 2,
#          '結盟': 2,
#          '單略': 1,
#          '頗受': 1,
#          '盟邦': 5,
#          '歡迎': 2,
#          '近來': 1,
#          '肆虐': 1,
#          '馬來西亞': 1,
#          '原來': 2,
#          '為主': 3,
#          '完': 1,
#          '案例': 1,
#          '大增': 2,
#          '歐美': 2,
#          '時有所聞': 1,
#          '新加坡': 4,
#          '總體': 3,
#          '統計': 1,
#          '外界': 4,
#          '議論': 1,
#          '看似': 2,
#          '遠': 3,
#          '實則': 1,
#          '上演': 1,
#          '一方面': 3,
#          '無法': 5,
#          '即時': 1,
#          '另一方面': 3,
#          '官方': 1,
#          '嚴拒': 1,
#          '連': 2,
#          '代理': 1,
#          '貼': 1,
#          '紅色': 2,
#          '標籤': 1,
#          '使得': 2,
#          '各': 2,
#          '遭遇': 3,
#          '層層': 1,
#          '一直': 3,
#          '美日': 2,
#          '等國': 1,
#          '抵台施': 1,
#          '機會': 2,
#          '完成': 4,
#          '充分': 1,
#          '凸顯': 1,
#          '島嶼': 1,
#          '隱然': 1,
#          '成形': 2,
#          '抗中': 13,
#          '進入': 3,
#          '回合': 3,
#          '賽': 1,
#          '兩大': 3,
#          '主力': 1,
#          '重心': 1,
#          '放在': 1,
#          '應對': 10,
#          '加強': 5,
#          '針': 1,
#          '口服': 1,
#          '噴劑': 1,
#          '因應': 1,
#          '而生': 1,
#          '香港媒體': 1,
#          '發現': 5,
#          '對抗': 12,
#          'Delta': 1,
#          '新型': 1,
#          '立即': 3,
#          '激勵': 1,
#          '旗下': 3,
#          '兩家': 1,
#          '香港': 6,
#          '上市公司': 3,
#          '股價': 1,
#          '尾盤': 1,
#          '直線': 1,
#          '拉升': 1,
#          '新一': 1,
#          '有超': 1,
#          '跑': 1,
#          '氣勢': 2,
#          '當務之急': 1,
#          '回到': 3,
#          '完善': 1,
#          '長期': 3,
#          '投資': 9,
#          '根本': 1,
#          '空談': 1,
#          '語重心長': 1,
#          ...})

# %%
#沒有處理stop words
wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate_from_frequencies(seg_counter)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#有處理stop words
wordcloud = WordCloud(background_color = 'white',font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate_from_frequencies(seg_stop_counter)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("./homework.png")

# %% [markdown]
# ### [其他] 用dataframe 處理數據

# %%
seg_df = pd.DataFrame(seg_words_list, columns=['seg_word'])
seg_df
# Out:
#      seg_word
# 0          白宮
# 1         幕僚長
# 2         梅杜斯
# 3           1
# 4           日
# ...       ...
# 3325       資源
# 3326        的
# 3327       行為
# 3328        。
# 3329        」
#
# [3330 rows x 1 columns]

# %%
seg_df['count'] = 1
seg_freq_df = seg_df.groupby('seg_word').sum()
seg_freq_df
# Out:
#           count
# seg_word
#              16
# ,             2
# --            2
# ----          1
# 1             5
# ...         ...
# （            24
# ）            24
# ，           225
# ：             7
# ；             6
#
# [1280 rows x 1 columns]

# %%
seg_df.groupby('seg_word').sum().plot.bar()
plt.xticks(rotation=50)
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12290 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12298 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12299 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12301 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12302 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12303 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20123 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20491 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20999 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26159 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27171 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27425 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27493 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31278 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32887 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38917 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19978 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20219 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21608 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28023 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26092 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28369 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38477 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19981 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26039 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26371 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30433 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28982 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36275 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36942 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 39000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19988 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 19989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20006 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23565 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20013 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20225 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22283 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35299 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25918 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36557 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25919 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24220 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24515 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33775 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20849 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20027 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27402 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20043 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24460 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31281 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20063 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23559 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23601 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35498 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20107 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20214 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24773 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20114 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21205 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24501 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20126 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22826 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24314 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36890 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22763 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24037 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23798 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26234 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24935 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20170 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22825 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20171 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38754 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20173 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20182 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20497 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20195 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29702 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30908 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 34920 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20197 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36084 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22294 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20294 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25818 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26757 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20316 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28858 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20351 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29992 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33258 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20363 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22914 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20379 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37832 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20381 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20405 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20419 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36914 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20420 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32645 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26031 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20445 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35703 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20462 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25913 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21029 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36039 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20570 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20986 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20659 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 34899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20663 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20677 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20740 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32654 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20803 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20760 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20778 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21218 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20786 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23384 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20806 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21069 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20818 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20839 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37096 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38656 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29699 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20841 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20844 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38272 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21496 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21578 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22577 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24067 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30526 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 40680 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20854 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20856 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22411 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20877 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35222 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20941 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32080 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20961 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21806 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25286 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37197 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21002 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20837 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30410 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21034 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28187 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21040 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35370 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21046 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32004 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35009 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21050 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28608 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21063 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21083 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21103 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24375 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25343 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36895 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21155 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21162 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 34892 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21253 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23416 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21407 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26009 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38598 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22296 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21271 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21319 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28331 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23566 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 39636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35576 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26089 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24230 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21363 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22240 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21443 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 33287 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38498 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36681 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31227 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36774 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36781 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36805 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36861 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36889 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39006 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40636 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36899 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36910 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25429 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36926 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 28193 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36969 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36973 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36935 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36981 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23432 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25799 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36992 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36996 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37027 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32626 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37326 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 26893 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 34701 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37341 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37504 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37559 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37610 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37679 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35492 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37782 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 27743 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23805 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22987 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20418 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 27880 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31237 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 37749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 28779 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 29254 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38459 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31001 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38519 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38568 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38614 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38617 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23736 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38627 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38642 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31471 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38750 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35028 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 33256 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38860 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38913 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38918 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38936 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22495 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38971 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38991 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39015 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39023 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39080 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 27934 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38570 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39318 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 24109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 28207 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39376 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39493 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40251 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 23431 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40613 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40654 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38931 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40655 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40657 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31821 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40848 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 28319 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65292 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65306 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65307 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### [其他] parse html 小筆記

# %%
import requests
from lxml import etree
import jieba
from io import StringIO
import pandas as pd

for e in newsFeed['entries']:
    url = e['links'][0]['href']
    print(url)
    r = requests.get(url)
    #print(r.status_code == 200)
    if r.status_code == 200:
        html_tree = etree.HTML(r.text)
        print(html_tree)
        html_ele = html_tree.xpath('//article//p')
        all_ele = [ (ele.text.strip()) for ele in html_ele if type(ele.text) is str ]
        all_ele_string = ''.join(all_ele)
        seg_words = jieba.lcut(all_ele_string)
        seg_df = pd.DataFrame(seg_words, columns=['seg_word'])
        seg_df['count'] = 1
        print(seg_df)
# Out:
# https://money.udn.com/money/story/10511/4827529
# <Element html at 0x7f78cae2d230>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4827373
# <Element html at 0x7f78c4f4cf00>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4825705
# <Element html at 0x7f78c5dedfa0>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4825558
# <Element html at 0x7f78c5de6960>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4821656
# <Element html at 0x7f78c4f559b0>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4821544
# <Element html at 0x7f78c5de6780>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4820610
# <Element html at 0x7f78cb6917d0>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4819075
# <Element html at 0x7f78c4f9e870>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4819072
# <Element html at 0x7f78cb68cb90>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4815072
# <Element html at 0x7f78c5dd9550>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4814082
# <Element html at 0x7f78c5ddcd20>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4813542
# <Element html at 0x7f78c5dede60>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4813244
# <Element html at 0x7f78c5dd9550>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
# https://money.udn.com/money/story/10511/4812936
# <Element html at 0x7f78c5dca640>
# Empty DataFrame
# Columns: [seg_word, count]
# Index: []
